# %% [markdown]
# # Obtaining Estimation and Simulation Results

# %%
import os
from matplotlib import pyplot as plt
from tools import models

# %% [markdown]
# We now create a base instance of the model (constant discount rates). This is useful for starting other specifications

# %%
sp = models.sp
base = sp('ref')
base.chgoption('iload','T')
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  T
# ibargaininghetero  =  F
# idischetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# ifixdisccorr  =  F
# dfixdiscrho  =  0.5
# inoestim  =  F
# changed item  iload  with value F  to  T  ...

# %% [markdown]
# We estimate parameters and simulate data post estimation

# %%
base.estimate()
base.loglike
# Out:
# -2649.0151581133237

# %%
base.params
# Out:
#                                        par                       se
# alpha_c                0.80060190291822764  6.0223057511947363E-002
# alpha_lm_cons          -2.1466983694662747       1.4367262601778712
# alpha_lm_age           0.51440908005937547      0.11483962872151703
# alpha_lm_hlim           1.5624136799931065      0.84148765821557514
# alpha_lm_college      -0.12698394412766792      0.45094314948006847
# alpha_lm_male          0.37332184106338367      0.67045272480501517
# alpha_lm_job           0.12983333300814751      0.63541724553585610
# alpha_lf                0.0000000000000000       0.0000000000000000
# alpha_lm_lf           -0.71268004304950205      0.10289677080788036
# beta_c                 0.56798480901198145  5.1356579040472743E-002
# beta_lf_cons          -0.16836226785617370       1.4328423429573784
# beta_lf_age            0.71291051126323202      0.13056494825240073
# beta_lf_hlim            1.5006868334888177      0.90209163669809089
# beta_lf_college       -0.37623112448070500      0.42800615511025780
# beta_lf_male            2.5410697750144542      0.73758036915172764
# beta_lf_job           -0.10010292042876627      0.47046928255264031
# beta_lm                 0.0000000000000000       0.0000000000000000
# beta_lm_lf            -0.66845647311694745  9.3609484896452058E-002
# mu                 4.6838426475170968E-002      0.82199133150639125
# wageratio               1.9105275026690476       1.7481659973179839
# log_rho_m         -5.1293294387550578E-002       0.0000000000000000
# log_rho_f         -5.1293294387550578E-002       0.0000000000000000
# tau_m_0                -3.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# tau_f_0                -3.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_sig_m               0.0000000000000000       0.0000000000000000
# log_sig_f               0.0000000000000000       0.0000000000000000
# L_nm_nm               -0.65263775803366042       2.3411745689311245
# L_nf_nm                0.16924491485207452       2.7524001570336818
# L_nf_nf               -0.63165312367727999       1.0991128885202115
# LJ_nm_nm                2.3559748555133142      0.17361211729194356
# LJ_nf_nm                1.7494260229200271      0.13465407443001801
# LJ_nf_nf          -1.8744991905253621E-002      0.10471845980806711
# LW                      0.0000000000000000       0.0000000000000000
# LDISC_nm_nm             0.0000000000000000       0.0000000000000000
# LDISC_nf_nm             0.0000000000000000       0.0000000000000000
# LDISC_nf_nf             0.0000000000000000       0.0000000000000000
# scale_m                 1.0000000000000000       0.0000000000000000
# scale_f                 1.0000000000000000       0.0000000000000000
# scale_h                 1.0000000000000000       0.0000000000000000

# %% [markdown]
# Here are some stats on the simulations:

# %%
base.sim.describe()
# Out:
#            hhidpn  insim       jprob  rexpret_sim  sexpret_sim   leisure_m  \
# count  464.000000  464.0  464.000000   464.000000   464.000000  464.000000
# mean   303.915948    1.0    0.096983    67.321121    63.101293   -0.328166
# std    174.229335    0.0    0.296254     7.569855     6.059860    0.038905
# min      1.000000    1.0    0.000000    51.000000    50.000000   -0.452549
# 25%    155.750000    1.0    0.000000    61.000000    59.000000   -0.352023
# 50%    300.500000    1.0    0.000000    67.000000    62.000000   -0.326512
# 75%    454.250000    1.0    0.000000    73.250000    67.000000   -0.307618
# max    604.000000    1.0    1.000000    80.000000    80.000000   -0.203001
#
#         leisure_f  leisure_joint_m  leisure_joint_f  uhbargain  ...  \
# count  464.000000       464.000000       464.000000      464.0  ...
# mean    -0.231517         1.197287         0.879685        0.0  ...
# std      0.100099         0.571304         0.424330        0.0  ...
# min     -0.440708         0.186787         0.131062        0.0  ...
# 25%     -0.319608         0.688484         0.504111        0.0  ...
# 50%     -0.229491         1.195647         0.878168        0.0  ...
# 75%     -0.144661         1.709676         1.261878        0.0  ...
# max     -0.014361         2.233205         1.649265        0.0  ...
#
#           rhlth62     shlth62     rliv75r     sliv75r       rwage       swage  \
# count  464.000000  464.000000  464.000000  464.000000  464.000000  464.000000
# mean     0.400431    0.395948    0.962090    0.912592   32.643196   25.571926
# std      0.277485    0.265845    0.322436    0.245628   35.602573   60.575684
# min      0.000000    0.000000    0.137999    0.062038    0.000000    0.000000
# 25%      0.200000    0.200000    0.720568    0.744456   16.060606   12.884816
# 50%      0.400000    0.400000    1.012476    0.968663   25.092495   17.923750
# 75%      0.500000    0.500000    1.175370    1.065559   36.888889   27.450981
# max      1.000000    1.000000    1.491040    1.291550  365.000000  916.666687
#
#            rhours      shours      rexpret      sexpret
# count  464.000000  464.000000   200.000000   257.000000
# mean    42.728448   35.831897  2019.150000  2019.669261
# std     10.666330   12.125414     5.325345     5.157249
# min      2.000000    1.000000  2010.000000  2010.000000
# 25%     40.000000   30.000000  2015.000000  2016.000000
# 50%     40.000000   40.000000  2019.000000  2019.000000
# 75%     50.000000   40.000000  2022.000000  2023.000000
# max     80.000000   75.000000  2040.000000  2034.000000
#
# [8 rows x 154 columns]

# %% [markdown]
# We will now create a model that estimates discount rates

# %%
disc = sp('discount')
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  T
# ibargaininghetero  =  F
# idischetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# ifixdisccorr  =  F
# dfixdiscrho  =  0.5
# inoestim  =  F

# %% [markdown]
# We need to flag that we want to estimate discount rates

# %%
disc.chgoption('idiscount','T')
disc.chgoption('iload','T')
# Out:
# changed item  idiscount  with value F  to  T  ...
# changed item  iload  with value F  to  T  ...

# %% [markdown]
# We now estimate parameters

# %%
disc.estimate()
disc.loglike
# Out:
# -2612.8160253465544

# %%
disc.params
# Out:
#                                        par                       se
# alpha_c                0.17420039935888931  4.1932443152332841E-002
# alpha_lm_cons          -1.3534825732920097      0.70607632968856326
# alpha_lm_age           0.35887460192300769  5.7280518878316207E-002
# alpha_lm_hlim           1.0106084503930428      0.44701198912630474
# alpha_lm_college  -4.3266941391926307E-002      0.22955032962855301
# alpha_lm_male          0.23822126139656552      0.34091006658058004
# alpha_lm_job           0.10417985884790237      0.30439167881204993
# alpha_lf                0.0000000000000000       0.0000000000000000
# alpha_lm_lf           -0.38261560000139339  5.3191997730849566E-002
# beta_c                 0.13626488951011345  4.3717393701089034E-002
# beta_lf_cons          -0.39598278718788954      0.74544508564380463
# beta_lf_age            0.38471945743497327  7.7977785711583869E-002
# beta_lf_hlim           0.86164888306290155      0.45784638957917317
# beta_lf_college       -0.13913655517601561      0.21966869217087115
# beta_lf_male            1.3952866370144539      0.43013017204441240
# beta_lf_job        7.7829717112750829E-002      0.23608483103283281
# beta_lm                 0.0000000000000000       0.0000000000000000
# beta_lm_lf            -0.37105083700815317  6.2330567307747907E-002
# mu                     0.28532125360613186      0.67570773369995285
# wageratio               1.5076897103384186       1.1350718162572559
# log_rho_m          3.1333327819270687E-002  9.8640941662147263E-003
# log_rho_f          2.0327683486406008E-002  1.2106246814976677E-002
# tau_m_0                -3.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# tau_f_0                -3.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_sig_m               0.0000000000000000       0.0000000000000000
# log_sig_f               0.0000000000000000       0.0000000000000000
# L_nm_nm               -0.63641010680699173       1.0302191959173375
# L_nf_nm            8.5891515839192564E-003       1.3790170801581880
# L_nf_nf           -5.5661957477540616E-002      0.58308054169077195
# LJ_nm_nm                1.1683750172926513      0.13102825229955464
# LJ_nf_nm               0.90369214727149194      0.12568535916622461
# LJ_nf_nf          -1.0364496044609693E-002  5.9513434627343813E-002
# LW                      0.0000000000000000       0.0000000000000000
# LDISC_nm_nm             0.0000000000000000       0.0000000000000000
# LDISC_nf_nm             0.0000000000000000       0.0000000000000000
# LDISC_nf_nf             0.0000000000000000       0.0000000000000000
# scale_m                 1.0000000000000000       0.0000000000000000
# scale_f                 1.0000000000000000       0.0000000000000000
# scale_h                 1.0000000000000000       0.0000000000000000

# %% [markdown]
# Some stats again on types

# %%
disc.sim.describe()
# Out:
#            hhidpn  insim       jprob  rexpret_sim  sexpret_sim   leisure_m  \
# count  464.000000  464.0  464.000000   464.000000   464.000000  464.000000
# mean   303.915948    1.0    0.118534    66.797414    63.405172   -0.320318
# std    174.229335    0.0    0.323589     6.165983     6.646233    0.039320
# min      1.000000    1.0    0.000000    51.000000    50.000000   -0.453471
# 25%    155.750000    1.0    0.000000    62.000000    58.750000   -0.343508
# 50%    300.500000    1.0    0.000000    67.000000    62.000000   -0.318578
# 75%    454.250000    1.0    0.000000    71.000000    68.000000   -0.298080
# max    604.000000    1.0    1.000000    80.000000    80.000000   -0.211169
#
#         leisure_f  leisure_joint_m  leisure_joint_f  uhbargain  ...  \
# count  464.000000       464.000000       464.000000      464.0  ...
# mean    -0.023527         0.594014         0.454248        0.0  ...
# std      0.008584         0.286590         0.221683        0.0  ...
# min     -0.041877         0.082809         0.059935        0.0  ...
# 25%     -0.031476         0.330852         0.249740        0.0  ...
# 50%     -0.023290         0.595061         0.454773        0.0  ...
# 75%     -0.016225         0.856512         0.656632        0.0  ...
# max     -0.006396         1.101027         0.847661        0.0  ...
#
#           rhlth62     shlth62     rliv75r     sliv75r       rwage       swage  \
# count  464.000000  464.000000  464.000000  464.000000  464.000000  464.000000
# mean     0.400431    0.395948    0.962090    0.912592   32.643196   25.571926
# std      0.277485    0.265845    0.322436    0.245628   35.602573   60.575684
# min      0.000000    0.000000    0.137999    0.062038    0.000000    0.000000
# 25%      0.200000    0.200000    0.720568    0.744456   16.060606   12.884816
# 50%      0.400000    0.400000    1.012476    0.968663   25.092495   17.923750
# 75%      0.500000    0.500000    1.175370    1.065559   36.888889   27.450981
# max      1.000000    1.000000    1.491040    1.291550  365.000000  916.666687
#
#            rhours      shours      rexpret      sexpret
# count  464.000000  464.000000   200.000000   257.000000
# mean    42.728448   35.831897  2019.150000  2019.669261
# std     10.666330   12.125414     5.325345     5.157249
# min      2.000000    1.000000  2010.000000  2010.000000
# 25%     40.000000   30.000000  2015.000000  2016.000000
# 50%     40.000000   40.000000  2019.000000  2019.000000
# 75%     50.000000   40.000000  2022.000000  2023.000000
# max     80.000000   75.000000  2040.000000  2034.000000
#
# [8 rows x 154 columns]

# %% [markdown]
# Now allowing for unobserved heterogeneity in discount rate

# %%
hdisc = sp('hdiscount')
hdisc.chgoption('idiscount','T')
hdisc.chgoption('idischetero','T')
hdisc.chgoption('iload','T')
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  T
# ibargaininghetero  =  F
# idischetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# ifixdisccorr  =  F
# dfixdiscrho  =  0.5
# inoestim  =  F
# changed item  idiscount  with value F  to  T  ...
# changed item  idischetero  with value F  to  T  ...
# changed item  iload  with value F  to  T  ...

# %%
hdisc.estimate()
hdisc.loglike
# Out:
# -2510.6348866626995

# %%
hdisc.params
# Out:
#                                        par                       se
# alpha_c                0.12425936298352043  4.0041180384765528E-002
# alpha_lm_cons          -2.4315440540174782      0.67837517073591813
# alpha_lm_age           0.52469784524633134      0.10177673289871914
# alpha_lm_hlim          0.79871480524966498      0.54612532156787497
# alpha_lm_college      -0.38475873953314887      0.27453764097310546
# alpha_lm_male           1.2887769880745472      0.41560666803021451
# alpha_lm_job           0.43426243345835708      0.35270342928604204
# alpha_lf                0.0000000000000000       0.0000000000000000
# alpha_lm_lf           -0.42162304803167350  6.3751532195053445E-002
# beta_c             5.4706282282932714E-002  2.7005025350771254E-002
# beta_lf_cons            1.5519800694739871      0.62664518009525771
# beta_lf_age            0.65337152870492154      0.13261921507447355
# beta_lf_hlim           0.35408456647458963      0.52866102299842688
# beta_lf_college       -0.14521105191234507      0.27640228255013854
# beta_lf_male            2.0248319779122181      0.56490171611358719
# beta_lf_job        8.7145012336540026E-002      0.28905884583771313
# beta_lm                 0.0000000000000000       0.0000000000000000
# beta_lm_lf            -0.56273610384583994  9.0156630519680467E-002
# mu                     0.12366248793764274      0.48006637174192396
# wageratio              0.91793369736680908      0.65143753342956423
# log_rho_m             -0.14865680015049759  2.2474065885056144E-002
# log_rho_f             -0.14740918296209993  2.4359819614902221E-002
# tau_m_0                -3.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# tau_f_0                -3.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_sig_m               0.0000000000000000       0.0000000000000000
# log_sig_f               0.0000000000000000       0.0000000000000000
# L_nm_nm                -1.5121037956733971      0.67174880764086942
# L_nf_nm                -2.8579219724903062      0.59913796913197903
# L_nf_nf           -8.3090968966951867E-002      0.59617724703972019
# LJ_nm_nm                1.6869899280995098      0.22731686283827043
# LJ_nf_nm                1.1385978319518943      0.17074268599983197
# LJ_nf_nf               0.11087124471333433  6.6029636909076664E-002
# LW                      0.0000000000000000       0.0000000000000000
# LDISC_nm_nm            0.33557409772564201  2.4820268057785557E-002
# LDISC_nf_nm            0.33004720201144966  2.5806421742871767E-002
# LDISC_nf_nf       -1.4635099220498276E-002  9.0867162507677762E-003
# scale_m                 1.0000000000000000       0.0000000000000000
# scale_f                 1.0000000000000000       0.0000000000000000
# scale_h                 1.0000000000000000       0.0000000000000000

# %% [markdown]
# ## Robustness of Specification

# %% [markdown]
# We will collect a few loglikelihoods to do LR tests (Table in main text). We will also present some results in the appendix for these alternative models.

# %% [markdown]
# ### Model with uncorrelated types

# %%
uncor = sp('nocorr')
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  T
# ibargaininghetero  =  F
# idischetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# ifixdisccorr  =  F
# dfixdiscrho  =  0.5
# inoestim  =  F

# %%
uncor.chgoption('icorr','F')
uncor.chgoption('idiscount','T')
uncor.chgoption('iload','T')
# Out:
# changed item  icorr  with value T  to  F  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  iload  with value F  to  T  ...

# %%
uncor.estimate()
uncor.loglike
# Out:
# -2612.8161082251845

# %%
uncor.params
# Out:
#                                        par                       se
# alpha_c                0.17410576496190280  4.1917444236030311E-002
# alpha_lm_cons          -1.3542096912462707      0.70548445899064882
# alpha_lm_age           0.35889979762076701  5.7275629831296179E-002
# alpha_lm_hlim           1.0105811175565640      0.44656127290004388
# alpha_lm_college  -4.3296427606425804E-002      0.22932069367829863
# alpha_lm_male          0.23832500510089838      0.33967505635611595
# alpha_lm_job           0.10433546017578300      0.30383875482201916
# alpha_lf                0.0000000000000000       0.0000000000000000
# alpha_lm_lf           -0.38257717585219247  5.3166891572854778E-002
# beta_c                 0.13626549406729965  4.3600766834450598E-002
# beta_lf_cons          -0.39185898978641431      0.40785388870383255
# beta_lf_age            0.38468243188981854  7.7966577617971169E-002
# beta_lf_hlim           0.86159846674252272      0.45776785855474350
# beta_lf_college       -0.13894894969840721      0.21567729839709421
# beta_lf_male            1.3953497333175668      0.42860652161688573
# beta_lf_job        7.7894878194340572E-002      0.23463671343067599
# beta_lm                 0.0000000000000000       0.0000000000000000
# beta_lm_lf            -0.37106325871750107  6.2312877440415283E-002
# mu                     0.28457303770187686      0.67230114989638157
# wageratio               1.5070292665409619       1.1344269286415016
# log_rho_m          3.1351228101571593E-002  9.8601596582820594E-003
# log_rho_f          2.0320113254063191E-002  1.2053106965950423E-002
# tau_m_0                -3.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# tau_f_0                -3.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_sig_m               0.0000000000000000       0.0000000000000000
# log_sig_f               0.0000000000000000       0.0000000000000000
# L_nm_nm               -0.63556140997062172       1.0244807722829596
# L_nf_nm                 0.0000000000000000       0.0000000000000000
# L_nf_nf           -5.4926595341045249E-002      0.57483260761068222
# LJ_nm_nm                1.1682809333149109      0.13101969964321591
# LJ_nf_nm               0.90369697667846227      0.12536989185029176
# LJ_nf_nf          -1.0345857073921197E-002  5.8917407553579056E-002
# LW                      0.0000000000000000       0.0000000000000000
# LDISC_nm_nm             0.0000000000000000       0.0000000000000000
# LDISC_nf_nm             0.0000000000000000       0.0000000000000000
# LDISC_nf_nf             0.0000000000000000       0.0000000000000000
# scale_m                 1.0000000000000000       0.0000000000000000
# scale_f                 1.0000000000000000       0.0000000000000000
# scale_h                 1.0000000000000000       0.0000000000000000

# %%
uncor.sim.describe()
# Out:
#            hhidpn  insim       jprob  rexpret_sim  sexpret_sim   leisure_m  \
# count  464.000000  464.0  464.000000   464.000000   464.000000  464.000000
# mean   303.915948    1.0    0.118534    66.799569    63.407328   -0.319893
# std    174.229335    0.0    0.323589     6.163075     6.643338    0.039247
# min      1.000000    1.0    0.000000    51.000000    50.000000   -0.452858
# 25%    155.750000    1.0    0.000000    62.000000    58.750000   -0.343061
# 50%    300.500000    1.0    0.000000    67.000000    62.000000   -0.318208
# 75%    454.250000    1.0    0.000000    71.000000    68.000000   -0.297752
# max    604.000000    1.0    1.000000    80.000000    80.000000   -0.210891
#
#         leisure_f  leisure_joint_m  leisure_joint_f  uhbargain  ...  \
# count  464.000000       464.000000       464.000000      464.0  ...
# mean    -0.027482         0.593939         0.454239        0.0  ...
# std      0.008522         0.286565         0.221682        0.0  ...
# min     -0.045280         0.082807         0.059947        0.0  ...
# 25%     -0.035198         0.330810         0.249759        0.0  ...
# 50%     -0.027244         0.595013         0.454785        0.0  ...
# 75%     -0.020207         0.856418         0.656628        0.0  ...
# max     -0.010160         1.100922         0.847660        0.0  ...
#
#           rhlth62     shlth62     rliv75r     sliv75r       rwage       swage  \
# count  464.000000  464.000000  464.000000  464.000000  464.000000  464.000000
# mean     0.400431    0.395948    0.962090    0.912592   32.643196   25.571926
# std      0.277485    0.265845    0.322436    0.245628   35.602573   60.575684
# min      0.000000    0.000000    0.137999    0.062038    0.000000    0.000000
# 25%      0.200000    0.200000    0.720568    0.744456   16.060606   12.884816
# 50%      0.400000    0.400000    1.012476    0.968663   25.092495   17.923750
# 75%      0.500000    0.500000    1.175370    1.065559   36.888889   27.450981
# max      1.000000    1.000000    1.491040    1.291550  365.000000  916.666687
#
#            rhours      shours      rexpret      sexpret
# count  464.000000  464.000000   200.000000   257.000000
# mean    42.728448   35.831897  2019.150000  2019.669261
# std     10.666330   12.125414     5.325345     5.157249
# min      2.000000    1.000000  2010.000000  2010.000000
# 25%     40.000000   30.000000  2015.000000  2016.000000
# 50%     40.000000   40.000000  2019.000000  2019.000000
# 75%     50.000000   40.000000  2022.000000  2023.000000
# max     80.000000   75.000000  2040.000000  2034.000000
#
# [8 rows x 154 columns]

# %% [markdown]
# ### Model without Survival Risk

# %%
nosurv = sp('nosurv')
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  T
# ibargaininghetero  =  F
# idischetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# ifixdisccorr  =  F
# dfixdiscrho  =  0.5
# inoestim  =  F

# %%
nosurv.chgoption('isurvival','F')
nosurv.chgoption('idiscount','T')
nosurv.chgoption('iload','T')
# Out:
# changed item  isurvival  with value T  to  F  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  iload  with value F  to  T  ...

# %%
nosurv.estimate()
nosurv.loglike
# Out:
# -2607.030536475722

# %%
nosurv.params
# Out:
#                                        par                       se
# alpha_c            5.3820085539254894E-002  1.7962668815630776E-002
# alpha_lm_cons          -1.0452801049921756      0.53519645632173751
# alpha_lm_age           0.29494918548786825  5.4877539618310843E-002
# alpha_lm_hlim          0.76036411734127618      0.36919928318012180
# alpha_lm_college  -2.5801077078522857E-002      0.18439842014964830
# alpha_lm_male          0.17163027339830864      0.27226953720750702
# alpha_lm_job           0.15117842655787800      0.23960354509002157
# alpha_lf                0.0000000000000000       0.0000000000000000
# alpha_lm_lf           -0.32781066167209894  4.7661444444616674E-002
# beta_c             6.6653080398794848E-002  2.5098544435425283E-002
# beta_lf_cons          -0.38403163186221434      0.65983654790621149
# beta_lf_age            0.33730308166501427  7.3534163060627392E-002
# beta_lf_hlim           0.71155857008826506      0.41099099663838634
# beta_lf_college       -0.10871724332703839      0.19765157129641847
# beta_lf_male            1.1854522215891690      0.37095149416349332
# beta_lf_job        7.5028722711931409E-002      0.21263000292837439
# beta_lm                 0.0000000000000000       0.0000000000000000
# beta_lm_lf            -0.35281109133885191  5.5376648761600186E-002
# mu                     0.32022241748223124      0.79977102110682363
# wageratio               1.6945805242616983       1.4093758631646593
# log_rho_m          3.9401139473199738E-002  1.0318886129001177E-002
# log_rho_f          2.4467972520385232E-002  1.1771299294969444E-002
# tau_m_0                -3.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# tau_f_0                -3.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_sig_m               0.0000000000000000       0.0000000000000000
# log_sig_f               0.0000000000000000       0.0000000000000000
# L_nm_nm               -0.71351294365045970      0.73949706259723791
# L_nf_nm            9.4614647813011793E-002       1.1534745111793872
# L_nf_nf            3.6847197950316498E-003      0.51450388224165999
# LJ_nm_nm               0.95971399764430998      0.11589270371979828
# LJ_nf_nm               0.83403573320102597      0.11350908316408072
# LJ_nf_nf          -4.1373859080107286E-003  5.3566286908859229E-002
# LW                      0.0000000000000000       0.0000000000000000
# LDISC_nm_nm             0.0000000000000000       0.0000000000000000
# LDISC_nf_nm             0.0000000000000000       0.0000000000000000
# LDISC_nf_nf             0.0000000000000000       0.0000000000000000
# scale_m                 1.0000000000000000       0.0000000000000000
# scale_f                 1.0000000000000000       0.0000000000000000
# scale_h                 1.0000000000000000       0.0000000000000000

# %%
nosurv.sim.describe()
# Out:
#            hhidpn  insim       jprob  rexpret_sim  sexpret_sim   leisure_m  \
# count  464.000000  464.0  464.000000   464.000000   464.000000  464.000000
# mean   303.915948    1.0    0.127155    66.566810    63.450431   -0.358701
# std    174.229335    0.0    0.333506     6.368783     7.062030    0.047204
# min      1.000000    1.0    0.000000    51.000000    50.000000   -0.513159
# 25%    155.750000    1.0    0.000000    61.750000    58.000000   -0.386291
# 50%    300.500000    1.0    0.000000    66.000000    62.000000   -0.356949
# 75%    454.250000    1.0    0.000000    71.000000    68.000000   -0.332534
# max    604.000000    1.0    1.000000    80.000000    80.000000   -0.198778
#
#         leisure_f  leisure_joint_m  leisure_joint_f  uhbargain  ...  \
# count  464.000000       464.000000       464.000000      464.0  ...
# mean     0.049411         0.487986         0.422006        0.0  ...
# std      0.006352         0.235452         0.204619        0.0  ...
# min      0.028251         0.066622         0.056267        0.0  ...
# 25%      0.045822         0.269982         0.232617        0.0  ...
# 50%      0.049213         0.488059         0.421931        0.0  ...
# 75%      0.053200         0.706616         0.612533        0.0  ...
# max      0.069672         0.902344         0.782617        0.0  ...
#
#           rhlth62     shlth62     rliv75r     sliv75r       rwage       swage  \
# count  464.000000  464.000000  464.000000  464.000000  464.000000  464.000000
# mean     0.400431    0.395948    0.962090    0.912592   32.643196   25.571926
# std      0.277485    0.265845    0.322436    0.245628   35.602573   60.575684
# min      0.000000    0.000000    0.137999    0.062038    0.000000    0.000000
# 25%      0.200000    0.200000    0.720568    0.744456   16.060606   12.884816
# 50%      0.400000    0.400000    1.012476    0.968663   25.092495   17.923750
# 75%      0.500000    0.500000    1.175370    1.065559   36.888889   27.450981
# max      1.000000    1.000000    1.491040    1.291550  365.000000  916.666687
#
#            rhours      shours      rexpret      sexpret
# count  464.000000  464.000000   200.000000   257.000000
# mean    42.728448   35.831897  2019.150000  2019.669261
# std     10.666330   12.125414     5.325345     5.157249
# min      2.000000    1.000000  2010.000000  2010.000000
# 25%     40.000000   30.000000  2015.000000  2016.000000
# 50%     40.000000   40.000000  2019.000000  2019.000000
# 75%     50.000000   40.000000  2022.000000  2023.000000
# max     80.000000   75.000000  2040.000000  2034.000000
#
# [8 rows x 154 columns]

# %% [markdown]
# ### Model without Complementarity

# %%
nocomp = sp('nocomp')
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  T
# ibargaininghetero  =  F
# idischetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# ifixdisccorr  =  F
# dfixdiscrho  =  0.5
# inoestim  =  F

# %%
nocomp.chgoption('idiscount','T')
nocomp.chgoption('icomplement','F')
nocomp.chgoption('ijointhetero','F')
nocomp.chgoption('iload','F')
# Out:
# changed item  idiscount  with value F  to  T  ...
# changed item  icomplement  with value T  to  F  ...
# changed item  ijointhetero  with value T  to  F  ...
# value already set to  F

# %%
nocomp.estimate()
# Out:
# /Users/lubis/Documents/github/joint/runtime/tools/models.py:155: RuntimeWarning: invalid value encountered in double_scalars
#   cov[1,0] = cov[1,0]/np.sqrt(cov[0,0]*cov[1,1])

# %%
nocomp.loglike
# Out:
# -2851.3223747654774

# %%
nocomp.params
# Out:
#                                        par                       se
# alpha_c            6.2718339629313807E-002  1.9270412816901648E-002
# alpha_lm_cons          -4.7043827696825220      0.70181011157124884
# alpha_lm_age           0.45482973784363279  6.5906130656610135E-002
# alpha_lm_hlim          0.95291999099038072      0.51520287873757387
# alpha_lm_college   6.6540966498513113E-002      0.26145631365752792
# alpha_lm_male          0.82174236960498259      0.33652915122484173
# alpha_lm_job          -0.10985690572647831      0.32292655461351710
# alpha_lf                0.0000000000000000       0.0000000000000000
# alpha_lm_lf             0.0000000000000000       0.0000000000000000
# beta_c             6.9560418295187915E-002  2.2047133928251372E-002
# beta_lf_cons           -2.4872927635000117      0.56881955604900170
# beta_lf_age            0.47014088160541723  8.2948406211564782E-002
# beta_lf_hlim           0.93912819458708374      0.43788455657490705
# beta_lf_college       -0.18455665272038219      0.21226241142036556
# beta_lf_male           0.98633879974432903      0.31847612337306175
# beta_lf_job           -0.23193148474523034      0.23505414502113559
# beta_lm                 0.0000000000000000       0.0000000000000000
# beta_lm_lf              0.0000000000000000       0.0000000000000000
# mu                -3.6758198138932996E-002      0.31399157451086729
# wageratio              0.50802477738231899      0.28129046263674284
# log_rho_m          4.6463543947800008E-002  1.1308096574195899E-002
# log_rho_f          2.5342423453888603E-002  1.2265061147481025E-002
# tau_m_0                -3.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# tau_f_0                -3.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_sig_m               0.0000000000000000       0.0000000000000000
# log_sig_f               0.0000000000000000       0.0000000000000000
# L_nm_nm                 7.0862066024487689      0.92348846440293431
# L_nf_nm                 5.2136574256406307      0.78343259833412093
# L_nf_nf               -0.67651704186939510      0.66531751170553644
# LJ_nm_nm                0.0000000000000000       0.0000000000000000
# LJ_nf_nm                0.0000000000000000       0.0000000000000000
# LJ_nf_nf                0.0000000000000000       0.0000000000000000
# LW                      0.0000000000000000       0.0000000000000000
# LDISC_nm_nm             0.0000000000000000       0.0000000000000000
# LDISC_nf_nm             0.0000000000000000       0.0000000000000000
# LDISC_nf_nf             0.0000000000000000       0.0000000000000000
# scale_m                 1.0000000000000000       0.0000000000000000
# scale_f                 1.0000000000000000       0.0000000000000000
# scale_h                 1.0000000000000000       0.0000000000000000

# %%
nocomp.sim.describe()
# Out:
#            hhidpn  insim       jprob  rexpret_sim  sexpret_sim   leisure_m  \
# count  464.000000  464.0  464.000000   464.000000   464.000000  464.000000
# mean   303.915948    1.0    0.125000    66.135776    64.267241    3.580435
# std    174.229335    0.0    0.331076     3.727328     2.673307    1.745212
# min      1.000000    1.0    0.000000    59.000000    58.000000    0.724979
# 25%    155.750000    1.0    0.000000    62.000000    62.000000    1.869033
# 50%    300.500000    1.0    0.000000    66.000000    64.000000    3.474123
# 75%    454.250000    1.0    0.000000    70.000000    67.000000    5.352635
# max    604.000000    1.0    1.000000    80.000000    79.000000    6.405791
#
#         leisure_f  leisure_joint_m  leisure_joint_f  uhbargain  ...  \
# count  464.000000            464.0            464.0      464.0  ...
# mean     2.298636              0.0              0.0        0.0  ...
# std      1.291780              0.0              0.0        0.0  ...
# min      0.142303              0.0              0.0        0.0  ...
# 25%      1.028032              0.0              0.0        0.0  ...
# 50%      2.225131              0.0              0.0        0.0  ...
# 75%      3.582014              0.0              0.0        0.0  ...
# max      4.431297              0.0              0.0        0.0  ...
#
#           rhlth62     shlth62     rliv75r     sliv75r       rwage       swage  \
# count  464.000000  464.000000  464.000000  464.000000  464.000000  464.000000
# mean     0.400431    0.395948    0.962090    0.912592   32.643196   25.571926
# std      0.277485    0.265845    0.322436    0.245628   35.602573   60.575684
# min      0.000000    0.000000    0.137999    0.062038    0.000000    0.000000
# 25%      0.200000    0.200000    0.720568    0.744456   16.060606   12.884816
# 50%      0.400000    0.400000    1.012476    0.968663   25.092495   17.923750
# 75%      0.500000    0.500000    1.175370    1.065559   36.888889   27.450981
# max      1.000000    1.000000    1.491040    1.291550  365.000000  916.666687
#
#            rhours      shours      rexpret      sexpret
# count  464.000000  464.000000   200.000000   257.000000
# mean    42.728448   35.831897  2019.150000  2019.669261
# std     10.666330   12.125414     5.325345     5.157249
# min      2.000000    1.000000  2010.000000  2010.000000
# 25%     40.000000   30.000000  2015.000000  2016.000000
# 50%     40.000000   40.000000  2019.000000  2019.000000
# 75%     50.000000   40.000000  2022.000000  2023.000000
# max     80.000000   75.000000  2040.000000  2034.000000
#
# [8 rows x 154 columns]

# %% [markdown]
# ### Unitary Model

# %%
unitary = sp('unitary')
unitary.chgoption('iunitary','T')
unitary.chgoption('idiscount','T')
unitary.chgoption('iload','T')
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  T
# ibargaininghetero  =  F
# idischetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# ifixdisccorr  =  F
# dfixdiscrho  =  0.5
# inoestim  =  F
# changed item  iunitary  with value F  to  T  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  iload  with value F  to  T  ...

# %%
unitary.estimate()
unitary.loglike
# Out:
# -2615.278186317392

# %%
unitary.params
# Out:
#                                        par                       se
# alpha_c                0.16487042498041601  4.2415618451931633E-002
# alpha_lm_cons          -1.3709280458783071      0.72068750288575878
# alpha_lm_age           0.38266593295105389  6.0964194648011637E-002
# alpha_lm_hlim           1.0194388694455851      0.45020958682977658
# alpha_lm_college  -9.8800100290089322E-003      0.23462306622681511
# alpha_lm_male          0.25338931994805985      0.33280080998499778
# alpha_lm_job       1.4423170118084168E-002      0.30831324507346153
# alpha_lf                0.0000000000000000       0.0000000000000000
# alpha_lm_lf           -0.37475235869141471  5.3168040957621877E-002
# beta_c                 0.14188872012320494  4.6870520136221873E-002
# beta_lf_cons          -0.31066101314516387      0.75934769577706551
# beta_lf_age            0.39355406622666395  8.4852756702316470E-002
# beta_lf_hlim           0.75571137311433123      0.46296283167485747
# beta_lf_college       -0.13448708473001869      0.23218552884268595
# beta_lf_male            1.2770982630741896      0.42964665932953433
# beta_lf_job        8.6914062349365828E-002      0.24471910646765371
# beta_lm                 0.0000000000000000       0.0000000000000000
# beta_lm_lf            -0.36186766355004479  6.2887800658160242E-002
# mu                     0.32331655897886402      0.58207741009312519
# wageratio               0.0000000000000000       0.0000000000000000
# log_rho_m          3.3736442402878743E-002  1.0182025414858334E-002
# log_rho_f          1.8514889364510272E-002  1.2314102389396953E-002
# tau_m_0                -3.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# tau_f_0                -3.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_sig_m               0.0000000000000000       0.0000000000000000
# log_sig_f               0.0000000000000000       0.0000000000000000
# L_nm_nm               -0.66052076340428945       1.0647530030527559
# L_nf_nm               -0.10815113569122058       1.3923641425971489
# L_nf_nf           -6.8522475574773895E-002      0.60818537063810230
# LJ_nm_nm                1.1519521676582747      0.13565585114196174
# LJ_nf_nm               0.90261650264962134      0.13123360910654086
# LJ_nf_nf          -1.8113119524916815E-002  5.9977050775319715E-002
# LW                      0.0000000000000000       0.0000000000000000
# LDISC_nm_nm             0.0000000000000000       0.0000000000000000
# LDISC_nf_nm             0.0000000000000000       0.0000000000000000
# LDISC_nf_nf             0.0000000000000000       0.0000000000000000
# scale_m                 1.0000000000000000       0.0000000000000000
# scale_f                 1.0000000000000000       0.0000000000000000
# scale_h                 1.0000000000000000       0.0000000000000000

# %%
unitary.sim.describe()
# Out:
#            hhidpn  insim       jprob  rexpret_sim  sexpret_sim   leisure_m  \
# count  464.000000  464.0  464.000000   464.000000   464.000000  464.000000
# mean   303.915948    1.0    0.140086    66.245690    63.129310   -0.332482
# std    174.229335    0.0    0.347451     4.832394     6.166208    0.040668
# min      1.000000    1.0    0.000000    55.000000    50.000000   -0.457580
# 25%    155.750000    1.0    0.000000    62.000000    58.000000   -0.356589
# 50%    300.500000    1.0    0.000000    67.000000    62.000000   -0.331019
# 75%    454.250000    1.0    0.000000    71.000000    68.000000   -0.309374
# max    604.000000    1.0    1.000000    80.000000    80.000000   -0.220774
#
#         leisure_f  leisure_joint_m  leisure_joint_f  uhbargain  ...  \
# count  464.000000       464.000000       464.000000      464.0  ...
# mean    -0.088744         0.584812         0.449156        0.0  ...
# std      0.013261         0.282454         0.221360        0.0  ...
# min     -0.129398         0.083953         0.058563        0.0  ...
# 25%     -0.098984         0.326620         0.247622        0.0  ...
# 50%     -0.088665         0.586697         0.450439        0.0  ...
# 75%     -0.079306         0.845804         0.654024        0.0  ...
# max     -0.053368         1.085998         0.844048        0.0  ...
#
#           rhlth62     shlth62     rliv75r     sliv75r       rwage       swage  \
# count  464.000000  464.000000  464.000000  464.000000  464.000000  464.000000
# mean     0.400431    0.395948    0.962090    0.912592   32.643196   25.571926
# std      0.277485    0.265845    0.322436    0.245628   35.602573   60.575684
# min      0.000000    0.000000    0.137999    0.062038    0.000000    0.000000
# 25%      0.200000    0.200000    0.720568    0.744456   16.060606   12.884816
# 50%      0.400000    0.400000    1.012476    0.968663   25.092495   17.923750
# 75%      0.500000    0.500000    1.175370    1.065559   36.888889   27.450981
# max      1.000000    1.000000    1.491040    1.291550  365.000000  916.666687
#
#            rhours      shours      rexpret      sexpret
# count  464.000000  464.000000   200.000000   257.000000
# mean    42.728448   35.831897  2019.150000  2019.669261
# std     10.666330   12.125414     5.325345     5.157249
# min      2.000000    1.000000  2010.000000  2010.000000
# 25%     40.000000   30.000000  2015.000000  2016.000000
# 50%     40.000000   40.000000  2019.000000  2019.000000
# 75%     50.000000   40.000000  2022.000000  2023.000000
# max     80.000000   75.000000  2040.000000  2034.000000
#
# [8 rows x 154 columns]

# %% [markdown]
# ### Table with LR Tests

# %%
import pandas as pd
data = [disc.loglike,base.loglike,uncor.loglike,nocomp.loglike,unitary.loglike]
lr = [0]
for i in range(1,len(data)):
    lr.append(-2.0*(data[i]-data[0]))
names = ['Baseline','Fixed Discount Rates (2)','No Correlation UH (1)','No Complementarity (5)','Unitary (1)']
table = pd.DataFrame(data=list(zip(data,lr)),index=names,columns=['Loglikehood Value','LR Statistic'])
def f(x):
    return '{:1.3f}'.format(x)
with open('../tex/tables/lrtests.tex','w') as tf:
    tf.write(table.to_latex(formatters=[f,f]))
table
# Out:
#                           Loglikehood Value  LR Statistic
# Baseline                       -2510.634887      0.000000
# Fixed Discount Rates (2)       -2649.015158    276.760543
# No Correlation UH (1)          -2612.816108    204.362443
# No Complementarity (5)         -2851.322375    681.374976
# Unitary (1)                    -2615.278186    209.286599

# %% [markdown]
# Critical values at 5% for these tests:

# %%
from scipy.stats import chi2
[chi2(1).ppf(0.95),chi2(2).ppf(0.95),chi2(5).ppf(0.95)]
# Out:
# [3.841458820694124, 5.991464547107979, 11.070497693516351]

# %% [markdown]
# ## Correlation with Expected Retirement in HRS

# %%
disc.sim['rexpret'] = disc.sim['rage_mod'] + (disc.sim['rexpret']-2011)
disc.sim['sexpret'] = disc.sim['sage_mod'] + (disc.sim['sexpret']-2011)

# %%
disc.sim[['rexpret','sexpret']].describe()
# Out:
#           rexpret     sexpret
# count  200.000000  257.000000
# mean    64.870000   64.459144
# std      4.203743    4.221328
# min     54.000000   54.000000
# 25%     62.000000   62.000000
# 50%     65.000000   64.000000
# 75%     68.000000   66.000000
# max     84.000000   80.000000

# %% [markdown]
# Correlations with simulated expected retirement age

# %%
print('Males   : ',disc.sim[['rexpret','rexpret_sim']].corr())
print('Females : ',disc.sim[['sexpret','sexpret_sim']].corr())
# Out:
# Males   :                rexpret  rexpret_sim
# rexpret      1.000000     0.193568
# rexpret_sim  0.193568     1.000000
# Females :                sexpret  sexpret_sim
# sexpret      1.000000     0.287079
# sexpret_sim  0.287079     1.000000

# %% [markdown]
# We will do a figure to check correlation

# %%
from scipy.stats import linregress
data = disc.sim[['rexpret_sim','rexpret']].dropna()
x = data['rexpret_sim']
y = data['rexpret']
slope, intercept, r_value, p_value, std_err = linregress(x,y)
line = slope*x+intercept
plt.figure()
plt.scatter(x,y,label='')
plt.plot(x, line, 'r', label='y={:.2f}x+{:.2f}: $R^2$={:.2f}'.format(slope,intercept,r_value))
plt.xlabel('expected retirement age (Model)')
plt.ylabel('expected retirement age (HRS)')
plt.legend(loc=4)
plt.savefig('../tex/figures/match_males.eps')
plt.show()

# %%
from scipy.stats import linregress
data = disc.sim[['sexpret_sim','sexpret']].dropna()
x = data['sexpret_sim']
y = data['sexpret']
slope, intercept, r_value, p_value, std_err = linregress(x,y)
line = slope*x+intercept
plt.figure()
plt.scatter(x,y,label='')
plt.plot(x, line, 'r', label='y={:.2f}x+{:.2f}: $R^2$={:.2f}'.format(slope,intercept,r_value))
plt.xlabel('expected retirement age (Model)')
plt.ylabel('expected retirement age (HRS)')
plt.legend(loc=4)
plt.savefig('../tex/figures/match_females.eps')
plt.show()

# %% [markdown]
# ## Distribution of Retirement Ages

# %%
# %matplotlib inline
from scipy.stats import gaussian_kde
from numba import jit
import numpy as np
x = disc.sim['rexpret_sim'].tolist()
y = disc.sim['sexpret_sim'].tolist()
print(disc.sim[['rexpret_sim','sexpret_sim']].describe())
print('correlation : ', disc.sim[['rexpret_sim','sexpret_sim']].corr())
X, Y = np.mgrid[60:69:10j, 60:69:10j]
positions = np.vstack([X.ravel(), Y.ravel()])
values = np.vstack([x, y])
kernel = gaussian_kde(values)
Z = np.reshape(kernel(positions).T, X.shape)
plt.figure()
plt.contour(X,Y,Z)
plt.xlabel('Expected Retirement Age Husband')
plt.ylabel('Expected Retirement Age Wife')
plt.savefig('../tex/figures/retages.eps')
# Out:
#        rexpret_sim  sexpret_sim
# count   464.000000   464.000000
# mean     65.635776    60.650862
# std       6.034001     4.487910
# min      51.000000    50.000000
# 25%      61.000000    58.000000
# 50%      65.000000    60.000000
# 75%      70.000000    64.000000
# max      80.000000    77.000000
# correlation :               rexpret_sim  sexpret_sim
# rexpret_sim     1.000000     0.810731
# sexpret_sim     0.810731     1.000000

# %%
disc.sim['distance_m'] = disc.sim['rexpret_sim'] - disc.sim['rage_mod']
disc.sim['distance_f'] = disc.sim['sexpret_sim'] - disc.sim['sage_mod']
print(disc.sim[['distance_m','distance_f']].describe())
print('correlation: ', disc.sim[['distance_m','distance_f']].corr())

# %matplotlib inline
from scipy.stats import gaussian_kde
from numba import jit
import numpy as np
x = disc.sim['distance_m'].tolist()
y = disc.sim['distance_f'].tolist()

X, Y = np.mgrid[0:20:20j, 0:20:20j]
positions = np.vstack([X.ravel(), Y.ravel()])
values = np.vstack([x, y])
kernel = gaussian_kde(values)
Z = np.reshape(kernel(positions).T, X.shape)
plt.figure()
plt.contour(X,Y,Z)
xx = np.linspace(0,20,20)
plt.fill_between(xx, xx-1, xx+1, color='grey', alpha='0.1')
plt.xlim([0,20])
plt.ylim([0,20])
plt.xlabel('Expected Distance (yrs) to Retirement Husband')
plt.ylabel('Expected Distance (yrs) to Retirement Wife')
plt.savefig('../tex/figures/distances.eps',dpi=600)
# Out:
#        distance_m  distance_f
# count  464.000000  464.000000
# mean     9.000000    4.989224
# std      6.696764    5.039144
# min      0.000000    0.000000
# 25%      4.000000    0.000000
# 50%      8.000000    4.000000
# 75%     14.000000    8.000000
# max     28.000000   21.000000
# correlation:              distance_m  distance_f
# distance_m     1.00000     0.81328
# distance_f     0.81328     1.00000

# %% [markdown]
# ## Joint Retirement

# %% [markdown]
# We will now re-rerun the discount model (baseline) with three scenarios: reshuffling heterogeneity, reshuffling wages and shutting down complementarity.

# %%
wages = sp('discount')
wages.chgoption('iload','T')
wages.chgoption('idiscount','T')
wages.chgoption('ishufwages','T')
wages.estimate()
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  T
# ibargaininghetero  =  F
# idischetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# ifixdisccorr  =  F
# dfixdiscrho  =  0.5
# inoestim  =  F
# changed item  iload  with value F  to  T  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  ishufwages  with value F  to  T  ...

# %%
heter = sp('discount')
heter.chgoption('iload','T')
heter.chgoption('idiscount','T')
heter.chgoption('ishufheter','T')
heter.estimate()
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  T
# ibargaininghetero  =  F
# idischetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# ifixdisccorr  =  F
# dfixdiscrho  =  0.5
# inoestim  =  F
# changed item  iload  with value F  to  T  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  ishufheter  with value F  to  T  ...

# %%
comp = sp('discount')
comp.chgoption('iload','T')
comp.chgoption('idiscount','T')
comp.chgoption('iblockcomp','T')
comp.estimate()
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  T
# ibargaininghetero  =  F
# idischetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# ifixdisccorr  =  F
# dfixdiscrho  =  0.5
# inoestim  =  F
# changed item  iload  with value F  to  T  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  iblockcomp  with value F  to  T  ...

# %%
specs = [disc,wages,heter,comp]
names =  ['Baseline','Shuffling Wages','Shuffling UH','No Complementarity']
data = []
plt.figure()
for i,s in enumerate(specs):
    s.sim['distance_m'] = s.sim['rexpret_sim'] - s.sim['rage_mod']
    s.sim['distance_f'] = s.sim['sexpret_sim'] - s.sim['sage_mod']
    s.sim['joint'] = np.abs(s.sim['distance_m'] - s.sim['distance_f'])<=1.0
    s.sim['joint_yrs'] = s.sim['distance_m'] - s.sim['distance_f']
    x = s.sim['joint_yrs'].values
    x.sort()
    ff = gaussian_kde(x)
    plt.plot(x,ff(x),label=names[i])
    data.append([s.sim['rexpret_sim'].mean(),s.sim['sexpret_sim'].mean(),s.sim['joint'].mean()])
table = pd.DataFrame(data=data,index=names,columns=['Ret Age Males','Ret Age Females','Fraction Joint'])  
def f(x):
    return '{:1.3f}'.format(x)
with open('../tex/tables/joint.tex','w') as tf:
    tf.write(table.to_latex(formatters=[f,f,f]))
plt.legend(loc=2)
plt.xlabel('difference in distance to retirement')
plt.ylabel('density')
plt.xlim([-15,15])
plt.savefig('../tex/figures/compare_distances.eps')
plt.show()
table
# Out:
#                     Ret Age Males  Ret Age Females  Fraction Joint
# Baseline                65.635776        60.650862        0.230603
# Shuffling Wages         66.894397        63.364224        0.209052
# Shuffling UH            66.780172        63.439655        0.243534
# No Complementarity      67.273707        63.866379        0.206897

# %%
# %matplotlib inline
from scipy.stats import gaussian_kde
from numba import jit
import numpy as np
x = comp.sim['distance_m'].tolist()
y = comp.sim['distance_f'].tolist()

X, Y = np.mgrid[0:20:20j, 0:20:20j]
positions = np.vstack([X.ravel(), Y.ravel()])
values = np.vstack([x, y])
kernel = gaussian_kde(values)
Z = np.reshape(kernel(positions).T, X.shape)
plt.figure()
plt.contour(X,Y,Z)
xx = np.linspace(0,20,20)
plt.fill_between(xx, xx-1, xx+1, color='grey', alpha='0.1')
plt.xlim([0,20])
plt.ylim([0,20])
plt.xlabel('Expected Distance (yrs) to Retirement Husband')
plt.ylabel('Expected Distance (yrs) to Retirement Wife')
plt.savefig('../tex/figures/distances_nocomp.eps',dpi=600)

# %%
disc.sim['agediff'] = disc.sim['rage_mod']- disc.sim['sage_mod']
print(comp.sim[['distance_m','distance_f']].describe())
print(disc.sim[['distance_m','distance_f']].describe())
# Out:
#        distance_m  distance_f
# count  464.000000  464.000000
# mean    10.637931    8.204741
# std      4.337085    4.804055
# min      0.000000    0.000000
# 25%      8.000000    5.000000
# 50%     10.000000    8.000000
# 75%     13.000000   11.000000
# max     28.000000   23.000000
#        distance_m  distance_f
# count  464.000000  464.000000
# mean     9.000000    4.989224
# std      6.696764    5.039144
# min      0.000000    0.000000
# 25%      4.000000    0.000000
# 50%      8.000000    4.000000
# 75%     14.000000    8.000000
# max     28.000000   21.000000

# %% [markdown]
# # Policy Simulation

# %% [markdown]
# Finally, we have to check what happens when we do policy simulations. We will do policy simulations over two parameters, the ARF (actuarial reduction factor) and the generosity of the pension (replacement rate).

# %%
arf = [0,0.09]
drc = [0,0.11]
rep = [0.4,0.8]
factors = zip(arf,drc)
experiments = [disc]
for a,d in factors:
    this = sp('discount')
    this.chgoption('iload','T')
    this.chgoption('idiscount','T')
    this.chgoption('arf',a)
    this.chgoption('drc',d)
    this.estimate()
    this.sim['distance_m'] = this.sim['rexpret_sim'] - this.sim['rage_mod']
    this.sim['distance_f'] = this.sim['sexpret_sim'] - this.sim['sage_mod']
    this.sim['joint'] = np.abs(this.sim['distance_m'] - this.sim['distance_f'])<=1.0    
    experiments.append(this)
for r in rep:
    this = sp('discount')
    this.chgoption('iload','T')
    this.chgoption('idiscount','T')
    this.chgoption('reprate',r)
    this.estimate()
    this.sim['distance_m'] = this.sim['rexpret_sim'] - this.sim['rage_mod']
    this.sim['distance_f'] = this.sim['sexpret_sim'] - this.sim['sage_mod']
    this.sim['joint'] = np.abs(this.sim['distance_m'] - this.sim['distance_f'])<=1.0    
    experiments.append(this)
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  T
# ibargaininghetero  =  F
# idischetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# ifixdisccorr  =  F
# dfixdiscrho  =  0.5
# inoestim  =  F
# changed item  iload  with value F  to  T  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  arf  with value 0.06  to  0  ...
# changed item  drc  with value 0.08  to  0  ...
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  T
# ibargaininghetero  =  F
# idischetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# ifixdisccorr  =  F
# dfixdiscrho  =  0.5
# inoestim  =  F
# changed item  iload  with value F  to  T  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  arf  with value 0.06  to  0.09  ...
# changed item  drc  with value 0.08  to  0.11  ...
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  T
# ibargaininghetero  =  F
# idischetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# ifixdisccorr  =  F
# dfixdiscrho  =  0.5
# inoestim  =  F
# changed item  iload  with value F  to  T  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  reprate  with value 0.6  to  0.4  ...
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  T
# ibargaininghetero  =  F
# idischetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# ifixdisccorr  =  F
# dfixdiscrho  =  0.5
# inoestim  =  F
# changed item  iload  with value F  to  T  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  reprate  with value 0.6  to  0.8  ...

# %%
data = [[e.sim['rexpret_sim'].mean(),e.sim['sexpret_sim'].mean(),e.sim['joint'].mean()] for e in experiments]
names = ['Baseline','No Penalty','High Penalty','Low Generosity','High Generosity']
table = pd.DataFrame(data=data,columns=['Ret Age Males','Ret Age Females','Fraction Retiring Jointly'],index=names)
print(table)
def f(x):
    return '{:1.3f}'.format(x)
with open('../tex/tables/policy.tex','w') as tf:
    tf.write(table.to_latex(formatters=[f,f,f]))
# Out:
#                  Ret Age Males  Ret Age Females  Fraction Retiring Jointly
# Baseline             65.635776        60.650862                   0.230603
# No Penalty           64.405172        61.573276                   0.293103
# High Penalty         67.747845        64.066810                   0.193966
# Low Generosity       67.357759        63.728448                   0.183190
# High Generosity      66.394397        63.153017                   0.284483
