# %% [markdown]
# # Obtaining Estimation and Simulation Results

# %%
import os
from matplotlib import pyplot as plt
from tools import models

# %% [markdown]
# We now create a base instance of the model (constant discount rates). This is useful for starting other specifications

# %%
sp = models.sp
base = sp('ref')
base.chgoption('iload','T')
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  T
# ibargaininghetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F
# changed item  iload  with value F  to  T  ...

# %% [markdown]
# We estimate parameters and simulate data post estimation

# %%
base.estimate()
base.loglike
# Out:
# -2649.015153019638

# %%
base.params
# Out:
#                                        par                       se
# alpha_c                0.80057030454582156  6.0214259476137726E-002
# alpha_lm_cons          -2.1454945007380468       1.4362778907740936
# alpha_lm_age           0.51438423456885518      0.11482700868665693
# alpha_lm_hlim           1.5624621852308844      0.84148829863925467
# alpha_lm_college      -0.12690720816289089      0.45091596754136548
# alpha_lm_male          0.37345481281766396      0.67035432024733588
# alpha_lm_job           0.12953983024864166      0.63536352963650156
# alpha_lf                0.0000000000000000       0.0000000000000000
# alpha_lm_lf           -0.71263323741496698      0.10288510967359916
# beta_c                 0.56796998176439306  5.1360102444795948E-002
# beta_lf_cons          -0.16859184554781098       1.4328994018130916
# beta_lf_age            0.71293204388686471      0.13057871160442594
# beta_lf_hlim            1.5014535508758973      0.90208849608097108
# beta_lf_college       -0.37643768290989110      0.42799896492776363
# beta_lf_male            2.5406690592006154      0.73758329080307883
# beta_lf_job           -0.10002539797802849      0.47046400803552674
# beta_lm                 0.0000000000000000       0.0000000000000000
# beta_lm_lf            -0.66841242981750704  9.3614960686142543E-002
# mu                 4.7570111429930909E-002      0.82211313628299520
# wageratio               1.9109354783126244       1.7487877793056299
# log_rho_m         -5.1293294387550578E-002       0.0000000000000000
# log_rho_f         -5.1293294387550578E-002       0.0000000000000000
# tau_m_0                -3.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# tau_f_0                -3.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_sig_m               0.0000000000000000       0.0000000000000000
# log_sig_f               0.0000000000000000       0.0000000000000000
# L_nm_nm               -0.65424076744506110       2.3404382781820137
# L_nf_nm                0.16885035073318722       2.7524455880866383
# L_nf_nf               -0.63120028104198311       1.0991704498077983
# LJ_nm_nm                2.3557499429915900      0.17358380038570065
# LJ_nf_nm                1.7492285329780473      0.13465598447221241
# LJ_nf_nf          -1.8682190351507193E-002      0.10473355799964196
# LW                      0.0000000000000000       0.0000000000000000
# scale_m                 1.0000000000000000       0.0000000000000000
# scale_f                 1.0000000000000000       0.0000000000000000
# scale_h                 1.0000000000000000       0.0000000000000000

# %% [markdown]
# Here are some stats on the simulations:

# %%
base.sim.describe()
# Out:
#            hhidpn  insim       jprob  rexpret_sim  sexpret_sim   leisure_m  \
# count  464.000000  464.0  464.000000   464.000000   464.000000  464.000000
# mean   303.915948    1.0    0.096983    67.321121    63.101293   -0.328972
# std    174.229335    0.0    0.296254     7.569855     6.059860    0.039004
# min      1.000000    1.0    0.000000    51.000000    50.000000   -0.453632
# 25%    155.750000    1.0    0.000000    61.000000    59.000000   -0.352895
# 50%    300.500000    1.0    0.000000    67.000000    62.000000   -0.327318
# 75%    454.250000    1.0    0.000000    73.250000    67.000000   -0.308320
# max    604.000000    1.0    1.000000    80.000000    80.000000   -0.203494
#
#         leisure_f  leisure_joint_m  leisure_joint_f  uhbargain     ...       \
# count  464.000000       464.000000       464.000000      464.0     ...
# mean    -0.231489         1.197188         0.879628        0.0     ...
# std      0.100025         0.571259         0.424288        0.0     ...
# min     -0.440553         0.186775         0.131077        0.0     ...
# 25%     -0.319544         0.688409         0.504087        0.0     ...
# 50%     -0.229455         1.195533         0.878127        0.0     ...
# 75%     -0.144709         1.709554         1.261790        0.0     ...
# max     -0.014492         2.233007         1.649106        0.0     ...
#
#           rhlth62     shlth62     rliv75r     sliv75r       rwage       swage  \
# count  464.000000  464.000000  464.000000  464.000000  464.000000  464.000000
# mean     0.400431    0.395948    0.962090    0.912592   32.643196   25.571926
# std      0.277485    0.265845    0.322436    0.245628   35.602573   60.575684
# min      0.000000    0.000000    0.137999    0.062038    0.000000    0.000000
# 25%      0.200000    0.200000    0.720568    0.744456   16.060606   12.884816
# 50%      0.400000    0.400000    1.012476    0.968663   25.092495   17.923750
# 75%      0.500000    0.500000    1.175370    1.065559   36.888889   27.450981
# max      1.000000    1.000000    1.491040    1.291550  365.000000  916.666687
#
#            rhours      shours      rexpret      sexpret
# count  464.000000  464.000000   200.000000   257.000000
# mean    42.728448   35.831897  2019.150000  2019.669261
# std     10.666330   12.125414     5.325345     5.157249
# min      2.000000    1.000000  2010.000000  2010.000000
# 25%     40.000000   30.000000  2015.000000  2016.000000
# 50%     40.000000   40.000000  2019.000000  2019.000000
# 75%     50.000000   40.000000  2022.000000  2023.000000
# max     80.000000   75.000000  2040.000000  2034.000000
#
# [8 rows x 152 columns]

# %% [markdown]
# We will now create a model that estimates discount rates

# %%
disc = sp('discount')
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  T
# ibargaininghetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F

# %% [markdown]
# We need to flag that we want to estimate discount rates

# %%
disc.chgoption('idiscount','T')
disc.chgoption('iload','T')
# Out:
# changed item  idiscount  with value F  to  T  ...
# changed item  iload  with value F  to  T  ...

# %% [markdown]
# We now estimate parameters

# %%
disc.estimate()
disc.loglike
# Out:
# -2612.8160226081745

# %%
disc.params
# Out:
#                                        par                       se
# alpha_c                0.17422939859478470  4.1937486397362264E-002
# alpha_lm_cons          -1.3534112783371843      0.70608610652425408
# alpha_lm_age           0.35885326780379967  5.7280160595148968E-002
# alpha_lm_hlim           1.0105480207905324      0.44702511303192161
# alpha_lm_college  -4.3307691418963547E-002      0.22955679231730056
# alpha_lm_male          0.23836191062677620      0.34091443962729345
# alpha_lm_job           0.10421152544627856      0.30439889482683335
# alpha_lf                0.0000000000000000       0.0000000000000000
# alpha_lm_lf           -0.38262220647897571  5.3192208731950144E-002
# beta_c                 0.13627505753073285  4.3718510540780853E-002
# beta_lf_cons          -0.39607017151339913      0.74539903996801204
# beta_lf_age            0.38474564438925313  7.7980970042632838E-002
# beta_lf_hlim           0.86187721471446765      0.45785727816068023
# beta_lf_college       -0.13914305484572598      0.21967058825333163
# beta_lf_male            1.3951710323944568      0.43012394925670183
# beta_lf_job        7.7871501968487328E-002      0.23608329928686653
# beta_lm                 0.0000000000000000       0.0000000000000000
# beta_lm_lf            -0.37103931879896068  6.2328413543393524E-002
# mu                     0.28540461514063614      0.67570031998501268
# wageratio               1.5074357285856141       1.1348656497104754
# log_rho_m          3.1329135597658715E-002  9.8638642271433874E-003
# log_rho_f          2.0328616935272818E-002  1.2105588915909576E-002
# tau_m_0                -3.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# tau_f_0                -3.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_sig_m               0.0000000000000000       0.0000000000000000
# log_sig_f               0.0000000000000000       0.0000000000000000
# L_nm_nm               -0.63644560236808434       1.0302518340636533
# L_nf_nm            8.1948725973813325E-003       1.3789385210463971
# L_nf_nf           -5.5244934638131557E-002      0.58316125368466332
# LJ_nm_nm                1.1684162674994178      0.13102951119929798
# LJ_nf_nm               0.90369962880469379      0.12568253050262918
# LJ_nf_nf          -1.0372006106697326E-002  5.9513843596039173E-002
# LW                      0.0000000000000000       0.0000000000000000
# scale_m                 1.0000000000000000       0.0000000000000000
# scale_f                 1.0000000000000000       0.0000000000000000
# scale_h                 1.0000000000000000       0.0000000000000000

# %% [markdown]
# Some stats again on types

# %%
disc.sim.describe()
# Out:
#            hhidpn  insim       jprob  rexpret_sim  sexpret_sim   leisure_m  \
# count  464.000000  464.0  464.000000   464.000000   464.000000  464.000000
# mean   303.915948    1.0    0.118534    66.799569    63.405172   -0.320336
# std    174.229335    0.0    0.323589     6.163075     6.646233    0.039321
# min      1.000000    1.0    0.000000    51.000000    50.000000   -0.453495
# 25%    155.750000    1.0    0.000000    62.000000    58.750000   -0.343528
# 50%    300.500000    1.0    0.000000    67.000000    62.000000   -0.318599
# 75%    454.250000    1.0    0.000000    71.000000    68.000000   -0.298101
# max    604.000000    1.0    1.000000    80.000000    80.000000   -0.211176
#
#         leisure_f  leisure_joint_m  leisure_joint_f  uhbargain     ...       \
# count  464.000000       464.000000       464.000000      464.0     ...
# mean    -0.023517         0.594035         0.454248        0.0     ...
# std      0.008520         0.286601         0.221685        0.0     ...
# min     -0.041709         0.082809         0.059931        0.0     ...
# 25%     -0.031384         0.330872         0.249733        0.0     ...
# 50%     -0.023278         0.595082         0.454774        0.0     ...
# 75%     -0.016260         0.856541         0.656634        0.0     ...
# max     -0.006497         1.101069         0.847667        0.0     ...
#
#           rhlth62     shlth62     rliv75r     sliv75r       rwage       swage  \
# count  464.000000  464.000000  464.000000  464.000000  464.000000  464.000000
# mean     0.400431    0.395948    0.962090    0.912592   32.643196   25.571926
# std      0.277485    0.265845    0.322436    0.245628   35.602573   60.575684
# min      0.000000    0.000000    0.137999    0.062038    0.000000    0.000000
# 25%      0.200000    0.200000    0.720568    0.744456   16.060606   12.884816
# 50%      0.400000    0.400000    1.012476    0.968663   25.092495   17.923750
# 75%      0.500000    0.500000    1.175370    1.065559   36.888889   27.450981
# max      1.000000    1.000000    1.491040    1.291550  365.000000  916.666687
#
#            rhours      shours      rexpret      sexpret
# count  464.000000  464.000000   200.000000   257.000000
# mean    42.728448   35.831897  2019.150000  2019.669261
# std     10.666330   12.125414     5.325345     5.157249
# min      2.000000    1.000000  2010.000000  2010.000000
# 25%     40.000000   30.000000  2015.000000  2016.000000
# 50%     40.000000   40.000000  2019.000000  2019.000000
# 75%     50.000000   40.000000  2022.000000  2023.000000
# max     80.000000   75.000000  2040.000000  2034.000000
#
# [8 rows x 152 columns]

# %% [markdown]
# ## Robustness of Specification

# %% [markdown]
# We will collect a few loglikelihoods to do LR tests (Table in main text). We will also present some results in the appendix for these alternative models.

# %% [markdown]
# ### Model with uncorrelated types

# %%
uncor = sp('nocorr')
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  T
# ibargaininghetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F

# %%
uncor.chgoption('icorr','F')
uncor.chgoption('idiscount','T')
uncor.chgoption('iload','T')
# Out:
# changed item  icorr  with value T  to  F  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  iload  with value F  to  T  ...

# %%
uncor.estimate()
uncor.loglike
# Out:
# -2612.8161205714764

# %%
uncor.params
# Out:
#                                        par                       se
# alpha_c                0.17412201201264493  4.1920285754745441E-002
# alpha_lm_cons          -1.3535945489576604      0.70530470592440242
# alpha_lm_age           0.35886406208841298  5.7268020752138743E-002
# alpha_lm_hlim           1.0104045570986202      0.44658510432549259
# alpha_lm_college  -4.3411212054101013E-002      0.22930896780556378
# alpha_lm_male          0.23825868311265547      0.33962245908675759
# alpha_lm_job           0.10409511883543919      0.30382248270222312
# alpha_lf                0.0000000000000000       0.0000000000000000
# alpha_lm_lf           -0.38256645918906013  5.3160917267116553E-002
# beta_c                 0.13619337555656788  4.3583876287367644E-002
# beta_lf_cons          -0.39210137568007758      0.40788736885786153
# beta_lf_age            0.38473044500151576  7.7989343115513213E-002
# beta_lf_hlim           0.86193116660589519      0.45778796454237713
# beta_lf_college       -0.13903011116225281      0.21567719339539759
# beta_lf_male            1.3951145514921557      0.42859022280725589
# beta_lf_job        7.8010792731656287E-002      0.23463902142623247
# beta_lm                 0.0000000000000000       0.0000000000000000
# beta_lm_lf            -0.37106419834142201  6.2321394799198175E-002
# mu                     0.28674970458045285      0.67277913474544238
# wageratio               1.5066437480303934       1.1346475725964902
# log_rho_m          3.1337104887995397E-002  9.8599119726408332E-003
# log_rho_f          2.0337328512096259E-002  1.2055350013346604E-002
# tau_m_0                -3.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# tau_f_0                -3.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_sig_m               0.0000000000000000       0.0000000000000000
# log_sig_f               0.0000000000000000       0.0000000000000000
# L_nm_nm               -0.63604963569027873       1.0241998923995774
# L_nf_nm                 0.0000000000000000       0.0000000000000000
# L_nf_nf           -5.4947822859262890E-002      0.57482551222051581
# LJ_nm_nm                1.1682627262928862      0.13101125707417027
# LJ_nf_nm               0.90358752453601632      0.12538595188471927
# LJ_nf_nf          -1.0317519284829673E-002  5.8921437899665509E-002
# LW                      0.0000000000000000       0.0000000000000000
# scale_m                 1.0000000000000000       0.0000000000000000
# scale_f                 1.0000000000000000       0.0000000000000000
# scale_h                 1.0000000000000000       0.0000000000000000

# %%
uncor.sim.describe()
# Out:
#            hhidpn  insim       jprob  rexpret_sim  sexpret_sim   leisure_m  \
# count  464.000000  464.0  464.000000   464.000000   464.000000  464.000000
# mean   303.915948    1.0    0.118534    66.799569    63.405172   -0.320139
# std    174.229335    0.0    0.323589     6.163075     6.646233    0.039282
# min      1.000000    1.0    0.000000    51.000000    50.000000   -0.453195
# 25%    155.750000    1.0    0.000000    62.000000    58.750000   -0.343337
# 50%    300.500000    1.0    0.000000    67.000000    62.000000   -0.318465
# 75%    454.250000    1.0    0.000000    71.000000    68.000000   -0.297979
# max    604.000000    1.0    1.000000    80.000000    80.000000   -0.211075
#
#         leisure_f  leisure_joint_m  leisure_joint_f  uhbargain     ...       \
# count  464.000000       464.000000       464.000000      464.0     ...
# mean    -0.027493         0.593926         0.454195        0.0     ...
# std      0.008525         0.286560         0.221655        0.0     ...
# min     -0.045296         0.082814         0.059956        0.0     ...
# 25%     -0.035212         0.330796         0.249746        0.0     ...
# 50%     -0.027254         0.595004         0.454744        0.0     ...
# 75%     -0.020214         0.856409         0.656570        0.0     ...
# max     -0.010164         1.100906         0.847569        0.0     ...
#
#           rhlth62     shlth62     rliv75r     sliv75r       rwage       swage  \
# count  464.000000  464.000000  464.000000  464.000000  464.000000  464.000000
# mean     0.400431    0.395948    0.962090    0.912592   32.643196   25.571926
# std      0.277485    0.265845    0.322436    0.245628   35.602573   60.575684
# min      0.000000    0.000000    0.137999    0.062038    0.000000    0.000000
# 25%      0.200000    0.200000    0.720568    0.744456   16.060606   12.884816
# 50%      0.400000    0.400000    1.012476    0.968663   25.092495   17.923750
# 75%      0.500000    0.500000    1.175370    1.065559   36.888889   27.450981
# max      1.000000    1.000000    1.491040    1.291550  365.000000  916.666687
#
#            rhours      shours      rexpret      sexpret
# count  464.000000  464.000000   200.000000   257.000000
# mean    42.728448   35.831897  2019.150000  2019.669261
# std     10.666330   12.125414     5.325345     5.157249
# min      2.000000    1.000000  2010.000000  2010.000000
# 25%     40.000000   30.000000  2015.000000  2016.000000
# 50%     40.000000   40.000000  2019.000000  2019.000000
# 75%     50.000000   40.000000  2022.000000  2023.000000
# max     80.000000   75.000000  2040.000000  2034.000000
#
# [8 rows x 152 columns]

# %% [markdown]
# ### Model without Survival Risk

# %%
nosurv = sp('nosurv')
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  T
# ibargaininghetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F

# %%
nosurv.chgoption('isurvival','F')
nosurv.chgoption('idiscount','T')
nosurv.chgoption('iload','T')
# Out:
# changed item  isurvival  with value T  to  F  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  iload  with value F  to  T  ...

# %%
nosurv.estimate()
nosurv.loglike
# Out:
# -2607.0305379008005

# %%
nosurv.params
# Out:
#                                        par                       se
# alpha_c            5.3821881422984226E-002  1.7962863923253868E-002
# alpha_lm_cons          -1.0452364467710451      0.53518203606830916
# alpha_lm_age           0.29494143523267569  5.4872448556127190E-002
# alpha_lm_hlim          0.76040629708769003      0.36919779910431411
# alpha_lm_college  -2.5833491014059053E-002      0.18439373664323250
# alpha_lm_male          0.17161140961820415      0.27226176444729033
# alpha_lm_job           0.15113451213546999      0.23959754095550978
# alpha_lf                0.0000000000000000       0.0000000000000000
# alpha_lm_lf           -0.32780587549147766  4.7658811191297903E-002
# beta_c             6.6649992651556009E-002  2.5099055855955447E-002
# beta_lf_cons          -0.38398760857820208      0.65985859416422676
# beta_lf_age            0.33731423941818173  7.3538765551594956E-002
# beta_lf_hlim           0.71160173786911851      0.41100439303172787
# beta_lf_college       -0.10873745088212793      0.19765949690651133
# beta_lf_male            1.1854774781219888      0.37096848588734238
# beta_lf_job        7.5032739523447967E-002      0.21263893646426160
# beta_lm                 0.0000000000000000       0.0000000000000000
# beta_lm_lf            -0.35282463370734451  5.5380661516662315E-002
# mu                     0.32067647405759325      0.79994204294258764
# wageratio               1.6951759570548912       1.4100711937512702
# log_rho_m          3.9398149461611430E-002  1.0318553479903413E-002
# log_rho_f          2.4467964723087533E-002  1.1772261976396647E-002
# tau_m_0                -3.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# tau_f_0                -3.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_sig_m               0.0000000000000000       0.0000000000000000
# log_sig_f               0.0000000000000000       0.0000000000000000
# L_nm_nm               -0.71354910309437669      0.73949049898118813
# L_nf_nm            9.4478645176490406E-002       1.1534851164664131
# L_nf_nf            3.5956195759374305E-003      0.51449545231674643
# LJ_nm_nm               0.95971143916813351      0.11588652060646200
# LJ_nf_nm               0.83404012939858418      0.11351664268170208
# LJ_nf_nf          -4.1221313172245984E-003  5.3569376612801846E-002
# LW                      0.0000000000000000       0.0000000000000000
# scale_m                 1.0000000000000000       0.0000000000000000
# scale_f                 1.0000000000000000       0.0000000000000000
# scale_h                 1.0000000000000000       0.0000000000000000

# %%
nosurv.sim.describe()
# Out:
#            hhidpn  insim       jprob  rexpret_sim  sexpret_sim   leisure_m  \
# count  464.000000  464.0  464.000000   464.000000   464.000000  464.000000
# mean   303.915948    1.0    0.127155    66.566810    63.450431   -0.358719
# std    174.229335    0.0    0.333506     6.368783     7.062030    0.047207
# min      1.000000    1.0    0.000000    51.000000    50.000000   -0.513190
# 25%    155.750000    1.0    0.000000    61.750000    58.000000   -0.386309
# 50%    300.500000    1.0    0.000000    66.000000    62.000000   -0.356969
# 75%    454.250000    1.0    0.000000    71.000000    68.000000   -0.332555
# max    604.000000    1.0    1.000000    80.000000    80.000000   -0.198796
#
#         leisure_f  leisure_joint_m  leisure_joint_f  uhbargain     ...       \
# count  464.000000       464.000000       464.000000      464.0     ...
# mean     0.049298         0.487984         0.422015        0.0     ...
# std      0.006340         0.235451         0.204619        0.0     ...
# min      0.028168         0.066623         0.056275        0.0     ...
# 25%      0.045715         0.269981         0.232623        0.0     ...
# 50%      0.049088         0.488057         0.421941        0.0     ...
# 75%      0.053077         0.706609         0.612544        0.0     ...
# max      0.069535         0.902341         0.782626        0.0     ...
#
#           rhlth62     shlth62     rliv75r     sliv75r       rwage       swage  \
# count  464.000000  464.000000  464.000000  464.000000  464.000000  464.000000
# mean     0.400431    0.395948    0.962090    0.912592   32.643196   25.571926
# std      0.277485    0.265845    0.322436    0.245628   35.602573   60.575684
# min      0.000000    0.000000    0.137999    0.062038    0.000000    0.000000
# 25%      0.200000    0.200000    0.720568    0.744456   16.060606   12.884816
# 50%      0.400000    0.400000    1.012476    0.968663   25.092495   17.923750
# 75%      0.500000    0.500000    1.175370    1.065559   36.888889   27.450981
# max      1.000000    1.000000    1.491040    1.291550  365.000000  916.666687
#
#            rhours      shours      rexpret      sexpret
# count  464.000000  464.000000   200.000000   257.000000
# mean    42.728448   35.831897  2019.150000  2019.669261
# std     10.666330   12.125414     5.325345     5.157249
# min      2.000000    1.000000  2010.000000  2010.000000
# 25%     40.000000   30.000000  2015.000000  2016.000000
# 50%     40.000000   40.000000  2019.000000  2019.000000
# 75%     50.000000   40.000000  2022.000000  2023.000000
# max     80.000000   75.000000  2040.000000  2034.000000
#
# [8 rows x 152 columns]

# %% [markdown]
# ### Model without Complementarity

# %%
nocomp = sp('nocomp')
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  T
# ibargaininghetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F

# %%
nocomp.chgoption('idiscount','T')
nocomp.chgoption('icomplement','F')
nocomp.chgoption('ijointhetero','F')
nocomp.chgoption('iload','F')
# Out:
# changed item  idiscount  with value F  to  T  ...
# changed item  icomplement  with value T  to  F  ...
# changed item  ijointhetero  with value T  to  F  ...
# value already set to  F

# %%
nocomp.estimate()
# Out:
# /Users/loulou/joint/runtime/tools/models.py:152: RuntimeWarning: invalid value encountered in double_scalars
#   cov[1,0] = cov[1,0]/np.sqrt(cov[0,0]*cov[1,1])

# %%
nocomp.loglike
# Out:
# -2851.3223747655634

# %%
nocomp.params
# Out:
#                                        par                       se
# alpha_c            6.2718350726179387E-002  1.9270415064323598E-002
# alpha_lm_cons          -4.7043831334922119      0.70181017302466653
# alpha_lm_age           0.45482977915816192  6.5906136477586294E-002
# alpha_lm_hlim          0.95291990226327483      0.51520292397589351
# alpha_lm_college   6.6540954922306189E-002      0.26145633712673766
# alpha_lm_male          0.82174242461832825      0.33652917047615027
# alpha_lm_job          -0.10985689039529092      0.32292658479069836
# alpha_lf                0.0000000000000000       0.0000000000000000
# alpha_lm_lf             0.0000000000000000       0.0000000000000000
# beta_c             6.9560410436644668E-002  2.2047131400188377E-002
# beta_lf_cons           -2.4872926876339547      0.56881950748996435
# beta_lf_age            0.47014085716391985  8.2948401223735563E-002
# beta_lf_hlim           0.93912822221637104      0.43788453575718711
# beta_lf_college       -0.18455663910052370      0.21226240167372240
# beta_lf_male           0.98633872447928461      0.31847610588898317
# beta_lf_job           -0.23193147548363049      0.23505413317682838
# beta_lm                 0.0000000000000000       0.0000000000000000
# beta_lm_lf              0.0000000000000000       0.0000000000000000
# mu                -3.6758233514444710E-002      0.31399156891509283
# wageratio              0.50802476111030981      0.28129045659766017
# log_rho_m          4.6463536286988974E-002  1.1308096559579497E-002
# log_rho_f          2.5342427698438641E-002  1.2265060730749731E-002
# tau_m_0                -3.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# tau_f_0                -3.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_sig_m               0.0000000000000000       0.0000000000000000
# log_sig_f               0.0000000000000000       0.0000000000000000
# L_nm_nm                 7.0862071818380086      0.92348851862648695
# L_nf_nm                 5.2136571041490853      0.78343252195002389
# L_nf_nf               -0.67651693118191203      0.66531749514127203
# LJ_nm_nm                0.0000000000000000       0.0000000000000000
# LJ_nf_nm                0.0000000000000000       0.0000000000000000
# LJ_nf_nf                0.0000000000000000       0.0000000000000000
# LW                      0.0000000000000000       0.0000000000000000
# scale_m                 1.0000000000000000       0.0000000000000000
# scale_f                 1.0000000000000000       0.0000000000000000
# scale_h                 1.0000000000000000       0.0000000000000000

# %%
nocomp.sim.describe()
# Out:
#            hhidpn  insim       jprob  rexpret_sim  sexpret_sim   leisure_m  \
# count  464.000000  464.0  464.000000   464.000000   464.000000  464.000000
# mean   303.915948    1.0    0.125000    66.135776    64.267241    3.580435
# std    174.229335    0.0    0.331076     3.727328     2.673307    1.745212
# min      1.000000    1.0    0.000000    59.000000    58.000000    0.724979
# 25%    155.750000    1.0    0.000000    62.000000    62.000000    1.869033
# 50%    300.500000    1.0    0.000000    66.000000    64.000000    3.474123
# 75%    454.250000    1.0    0.000000    70.000000    67.000000    5.352636
# max    604.000000    1.0    1.000000    80.000000    79.000000    6.405792
#
#         leisure_f  leisure_joint_m  leisure_joint_f  uhbargain     ...       \
# count  464.000000            464.0            464.0      464.0     ...
# mean     2.298636              0.0              0.0        0.0     ...
# std      1.291779              0.0              0.0        0.0     ...
# min      0.142303              0.0              0.0        0.0     ...
# 25%      1.028032              0.0              0.0        0.0     ...
# 50%      2.225131              0.0              0.0        0.0     ...
# 75%      3.582014              0.0              0.0        0.0     ...
# max      4.431297              0.0              0.0        0.0     ...
#
#           rhlth62     shlth62     rliv75r     sliv75r       rwage       swage  \
# count  464.000000  464.000000  464.000000  464.000000  464.000000  464.000000
# mean     0.400431    0.395948    0.962090    0.912592   32.643196   25.571926
# std      0.277485    0.265845    0.322436    0.245628   35.602573   60.575684
# min      0.000000    0.000000    0.137999    0.062038    0.000000    0.000000
# 25%      0.200000    0.200000    0.720568    0.744456   16.060606   12.884816
# 50%      0.400000    0.400000    1.012476    0.968663   25.092495   17.923750
# 75%      0.500000    0.500000    1.175370    1.065559   36.888889   27.450981
# max      1.000000    1.000000    1.491040    1.291550  365.000000  916.666687
#
#            rhours      shours      rexpret      sexpret
# count  464.000000  464.000000   200.000000   257.000000
# mean    42.728448   35.831897  2019.150000  2019.669261
# std     10.666330   12.125414     5.325345     5.157249
# min      2.000000    1.000000  2010.000000  2010.000000
# 25%     40.000000   30.000000  2015.000000  2016.000000
# 50%     40.000000   40.000000  2019.000000  2019.000000
# 75%     50.000000   40.000000  2022.000000  2023.000000
# max     80.000000   75.000000  2040.000000  2034.000000
#
# [8 rows x 152 columns]

# %% [markdown]
# ### Unitary Model

# %%
unitary = sp('unitary')
unitary.chgoption('iunitary','T')
unitary.chgoption('idiscount','T')
unitary.chgoption('iload','T')
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  T
# ibargaininghetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F
# changed item  iunitary  with value F  to  T  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  iload  with value F  to  T  ...

# %%
unitary.estimate()
unitary.loglike
# Out:
# -2615.2781958012274

# %%
unitary.params
# Out:
#                                        par                       se
# alpha_c                0.16483882573238465  4.2406588760897375E-002
# alpha_lm_cons          -1.3709045925393537      0.72059445499488617
# alpha_lm_age           0.38260958329349309  6.0950507144891274E-002
# alpha_lm_hlim           1.0193688319259169      0.45018727597362068
# alpha_lm_college  -1.0014801698599569E-002      0.23459296618064798
# alpha_lm_male          0.25343123653051336      0.33274324533623945
# alpha_lm_job       1.4454837474692638E-002      0.30827485687621570
# alpha_lf                0.0000000000000000       0.0000000000000000
# alpha_lm_lf           -0.37475081860758697  5.3160574180927705E-002
# beta_c                 0.14187395422752075  4.6870993867241355E-002
# beta_lf_cons          -0.31081225757739295      0.75933523695303118
# beta_lf_age            0.39360804144314837  8.4874870545724318E-002
# beta_lf_hlim           0.75607242354951387      0.46300451235467588
# beta_lf_college       -0.13452454264522132      0.23219570260937708
# beta_lf_male            1.2768832571595974      0.42966074618323530
# beta_lf_job        8.7017640572906230E-002      0.24473149762785051
# beta_lm                 0.0000000000000000       0.0000000000000000
# beta_lm_lf            -0.36186819602323017  6.2894851606027452E-002
# mu                     0.32444536628800447      0.58235126023580563
# wageratio               0.0000000000000000       0.0000000000000000
# log_rho_m          3.3735589898114857E-002  1.0181841455701677E-002
# log_rho_f          1.8517322905689117E-002  1.2315697546855374E-002
# tau_m_0                -3.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# tau_f_0                -3.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_sig_m               0.0000000000000000       0.0000000000000000
# log_sig_f               0.0000000000000000       0.0000000000000000
# L_nm_nm               -0.66036638609445841       1.0646692329344427
# L_nf_nm               -0.10895567142946137       1.3922504721408906
# L_nf_nf           -6.7931081425526105E-002      0.60832783248633771
# LJ_nm_nm                1.1518944884503781      0.13563518516529810
# LJ_nf_nm               0.90257449409234236      0.13124706516116486
# LJ_nf_nf          -1.8077029057435488E-002  5.9987816808867944E-002
# LW                      0.0000000000000000       0.0000000000000000
# scale_m                 1.0000000000000000       0.0000000000000000
# scale_f                 1.0000000000000000       0.0000000000000000
# scale_h                 1.0000000000000000       0.0000000000000000

# %%
unitary.sim.describe()
# Out:
#            hhidpn  insim       jprob  rexpret_sim  sexpret_sim   leisure_m  \
# count  464.000000  464.0  464.000000   464.000000   464.000000  464.000000
# mean   303.915948    1.0    0.140086    66.245690    63.129310   -0.332404
# std    174.229335    0.0    0.347451     4.832394     6.166208    0.040657
# min      1.000000    1.0    0.000000    55.000000    50.000000   -0.457541
# 25%    155.750000    1.0    0.000000    62.000000    58.000000   -0.356508
# 50%    300.500000    1.0    0.000000    67.000000    62.000000   -0.330938
# 75%    454.250000    1.0    0.000000    71.000000    68.000000   -0.309301
# max    604.000000    1.0    1.000000    80.000000    80.000000   -0.220736
#
#         leisure_f  leisure_joint_m  leisure_joint_f  uhbargain     ...       \
# count  464.000000       464.000000       464.000000      464.0     ...
# mean    -0.088853         0.584781         0.449151        0.0     ...
# std      0.013211         0.282440         0.221349        0.0     ...
# min     -0.129481         0.083951         0.058576        0.0     ...
# 25%     -0.099044         0.326601         0.247626        0.0     ...
# 50%     -0.088739         0.586667         0.450443        0.0     ...
# 75%     -0.079407         0.845760         0.654018        0.0     ...
# max     -0.053493         1.085939         0.844019        0.0     ...
#
#           rhlth62     shlth62     rliv75r     sliv75r       rwage       swage  \
# count  464.000000  464.000000  464.000000  464.000000  464.000000  464.000000
# mean     0.400431    0.395948    0.962090    0.912592   32.643196   25.571926
# std      0.277485    0.265845    0.322436    0.245628   35.602573   60.575684
# min      0.000000    0.000000    0.137999    0.062038    0.000000    0.000000
# 25%      0.200000    0.200000    0.720568    0.744456   16.060606   12.884816
# 50%      0.400000    0.400000    1.012476    0.968663   25.092495   17.923750
# 75%      0.500000    0.500000    1.175370    1.065559   36.888889   27.450981
# max      1.000000    1.000000    1.491040    1.291550  365.000000  916.666687
#
#            rhours      shours      rexpret      sexpret
# count  464.000000  464.000000   200.000000   257.000000
# mean    42.728448   35.831897  2019.150000  2019.669261
# std     10.666330   12.125414     5.325345     5.157249
# min      2.000000    1.000000  2010.000000  2010.000000
# 25%     40.000000   30.000000  2015.000000  2016.000000
# 50%     40.000000   40.000000  2019.000000  2019.000000
# 75%     50.000000   40.000000  2022.000000  2023.000000
# max     80.000000   75.000000  2040.000000  2034.000000
#
# [8 rows x 152 columns]

# %% [markdown]
# ### Table with LR Tests

# %%
import pandas as pd
data = [disc.loglike,base.loglike,uncor.loglike,nocomp.loglike,unitary.loglike]
lr = [0]
for i in range(1,len(data)):
    lr.append(-2.0*(data[i]-data[0]))
names = ['Baseline','Fixed Discount Rates (2)','No Correlation UH (1)','No Complementarity (5)','Unitary (1)']
table = pd.DataFrame(data=list(zip(data,lr)),index=names,columns=['Loglikehood Value','LR Statistic'])
def f(x):
    return '{:1.3f}'.format(x)
with open('../tex/tables/lrtests.tex','w') as tf:
    tf.write(table.to_latex(formatters=[f,f]))
table
# Out:
#                           Loglikehood Value  LR Statistic
# Baseline                       -2612.816023      0.000000
# Fixed Discount Rates (2)       -2649.015153     72.398261
# No Correlation UH (1)          -2612.816121      0.000196
# No Complementarity (5)         -2851.322375    477.012704
# Unitary (1)                    -2615.278196      4.924346

# %% [markdown]
# Critical values at 5% for these tests:

# %%
from scipy.stats import chi2
[chi2(1).ppf(0.95),chi2(2).ppf(0.95),chi2(5).ppf(0.95)]
# Out:
# [3.8414588206941236, 5.99146454710798, 11.070497693516351]

# %% [markdown]
# ## Correlation with Expected Retirement in HRS

# %%
disc.sim['rexpret'] = disc.sim['rage_mod'] + (disc.sim['rexpret']-2011)
disc.sim['sexpret'] = disc.sim['sage_mod'] + (disc.sim['sexpret']-2011)

# %%
disc.sim[['rexpret','sexpret']].describe()
# Out:
#           rexpret     sexpret
# count  200.000000  257.000000
# mean    64.870000   64.459144
# std      4.203743    4.221328
# min     54.000000   54.000000
# 25%     62.000000   62.000000
# 50%     65.000000   64.000000
# 75%     68.000000   66.000000
# max     84.000000   80.000000

# %% [markdown]
# Correlations with simulated expected retirement age

# %%
print('Males   : ',disc.sim[['rexpret','rexpret_sim']].corr())
print('Females : ',disc.sim[['sexpret','sexpret_sim']].corr())
# Out:
# Males   :                rexpret  rexpret_sim
# rexpret      1.000000     0.200013
# rexpret_sim  0.200013     1.000000
# Females :                sexpret  sexpret_sim
# sexpret      1.000000     0.262503
# sexpret_sim  0.262503     1.000000

# %% [markdown]
# We will do a figure to check correlation

# %%
from scipy.stats import linregress
data = disc.sim[['rexpret_sim','rexpret']].dropna()
x = data['rexpret_sim']
y = data['rexpret']
slope, intercept, r_value, p_value, std_err = linregress(x,y)
line = slope*x+intercept
plt.figure()
plt.scatter(x,y,label='')
plt.plot(x, line, 'r', label='y={:.2f}x+{:.2f}: $R^2$={:.2f}'.format(slope,intercept,r_value))
plt.xlabel('expected retirement age (Model)')
plt.ylabel('expected retirement age (HRS)')
plt.legend(loc=4)
plt.savefig('../tex/figures/match_males.eps')
plt.show()

# %%
from scipy.stats import linregress
data = disc.sim[['sexpret_sim','sexpret']].dropna()
x = data['sexpret_sim']
y = data['sexpret']
slope, intercept, r_value, p_value, std_err = linregress(x,y)
line = slope*x+intercept
plt.figure()
plt.scatter(x,y,label='')
plt.plot(x, line, 'r', label='y={:.2f}x+{:.2f}: $R^2$={:.2f}'.format(slope,intercept,r_value))
plt.xlabel('expected retirement age (Model)')
plt.ylabel('expected retirement age (HRS)')
plt.legend(loc=4)
plt.savefig('../tex/figures/match_females.eps')
plt.show()

# %% [markdown]
# ## Distribution of Retirement Ages

# %%
# %matplotlib inline
from scipy.stats import gaussian_kde
from numba import jit
import numpy as np
x = disc.sim['rexpret_sim'].tolist()
y = disc.sim['sexpret_sim'].tolist()
print(disc.sim[['rexpret_sim','sexpret_sim']].describe())
print('correlation : ', disc.sim[['rexpret_sim','sexpret_sim']].corr())
X, Y = np.mgrid[60:69:10j, 60:69:10j]
positions = np.vstack([X.ravel(), Y.ravel()])
values = np.vstack([x, y])
kernel = gaussian_kde(values)
Z = np.reshape(kernel(positions).T, X.shape)
plt.figure()
plt.contour(X,Y,Z)
plt.xlabel('Expected Retirement Age Husband')
plt.ylabel('Expected Retirement Age Wife')
plt.savefig('../tex/figures/retages.eps')
# Out:
#        rexpret_sim  sexpret_sim
# count   464.000000   464.000000
# mean     66.799569    63.405172
# std       6.163075     6.646233
# min      51.000000    50.000000
# 25%      62.000000    58.750000
# 50%      67.000000    62.000000
# 75%      71.000000    68.000000
# max      80.000000    80.000000
# correlation :               rexpret_sim  sexpret_sim
# rexpret_sim     1.000000     0.661674
# sexpret_sim     0.661674     1.000000

# %%
disc.sim['distance_m'] = disc.sim['rexpret_sim'] - disc.sim['rage_mod']
disc.sim['distance_f'] = disc.sim['sexpret_sim'] - disc.sim['sage_mod']
print(disc.sim[['distance_m','distance_f']].describe())
print('correlation: ', disc.sim[['distance_m','distance_f']].corr())

# %matplotlib inline
from scipy.stats import gaussian_kde
from numba import jit
import numpy as np
x = disc.sim['distance_m'].tolist()
y = disc.sim['distance_f'].tolist()

X, Y = np.mgrid[0:20:20j, 0:20:20j]
positions = np.vstack([X.ravel(), Y.ravel()])
values = np.vstack([x, y])
kernel = gaussian_kde(values)
Z = np.reshape(kernel(positions).T, X.shape)
plt.figure()
plt.contour(X,Y,Z)
xx = np.linspace(0,20,20)
plt.fill_between(xx, xx-1, xx+1, color='grey', alpha='0.1')
plt.xlim([0,20])
plt.ylim([0,20])
plt.xlabel('Expected Distance (yrs) to Retirement Husband')
plt.ylabel('Expected Distance (yrs) to Retirement Wife')
plt.savefig('../tex/figures/distances.eps',dpi=600)
# Out:
#        distance_m  distance_f
# count  464.000000  464.000000
# mean    10.163793    7.743534
# std      6.832073    7.032857
# min      0.000000    0.000000
# 25%      5.000000    1.000000
# 50%     10.000000    7.000000
# 75%     15.000000   13.000000
# max     29.000000   31.000000
# correlation:              distance_m  distance_f
# distance_m    1.000000    0.684529
# distance_f    0.684529    1.000000

# %% [markdown]
# ## Joint Retirement

# %% [markdown]
# We will now re-rerun the discount model (baseline) with three scenarios: reshuffling heterogeneity, reshuffling wages and shutting down complementarity.

# %%
wages = sp('discount')
wages.chgoption('iload','T')
wages.chgoption('idiscount','T')
wages.chgoption('ishufwages','T')
wages.estimate()
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  T
# ibargaininghetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F
# changed item  iload  with value F  to  T  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  ishufwages  with value F  to  T  ...

# %%
heter = sp('discount')
heter.chgoption('iload','T')
heter.chgoption('idiscount','T')
heter.chgoption('ishufheter','T')
heter.estimate()
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  T
# ibargaininghetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F
# changed item  iload  with value F  to  T  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  ishufheter  with value F  to  T  ...

# %%
comp = sp('discount')
comp.chgoption('iload','T')
comp.chgoption('idiscount','T')
comp.chgoption('iblockcomp','T')
comp.estimate()
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  T
# ibargaininghetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F
# changed item  iload  with value F  to  T  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  iblockcomp  with value F  to  T  ...

# %%
specs = [disc,wages,heter,comp]
names =  ['Baseline','Shuffling Wages','Shuffling UH','No Complementarity']
data = []
plt.figure()
for i,s in enumerate(specs):
    s.sim['distance_m'] = s.sim['rexpret_sim'] - s.sim['rage_mod']
    s.sim['distance_f'] = s.sim['sexpret_sim'] - s.sim['sage_mod']
    s.sim['joint'] = np.abs(s.sim['distance_m'] - s.sim['distance_f'])<=1.0
    s.sim['joint_yrs'] = s.sim['distance_m'] - s.sim['distance_f']
    x = s.sim['joint_yrs'].values
    x.sort()
    ff = gaussian_kde(x)
    plt.plot(x,ff(x),label=names[i])
    data.append([s.sim['rexpret_sim'].mean(),s.sim['sexpret_sim'].mean(),s.sim['joint'].mean()])
table = pd.DataFrame(data=data,index=names,columns=['Ret Age Males','Ret Age Females','Fraction Joint'])  
def f(x):
    return '{:1.3f}'.format(x)
with open('../tex/tables/joint.tex','w') as tf:
    tf.write(table.to_latex(formatters=[f,f,f]))
plt.legend(loc=2)
plt.xlabel('difference in distance to retirement')
plt.ylabel('density')
plt.xlim([-15,15])
plt.savefig('../tex/figures/compare_distances.eps')
plt.show()
table
# Out:
#                     Ret Age Males  Ret Age Females  Fraction Joint
# Baseline                66.799569        63.405172        0.267241
# Shuffling Wages         66.767241        63.441810        0.193966
# Shuffling UH            66.711207        63.431034        0.245690
# No Complementarity      67.273707        63.866379        0.206897

# %%
# %matplotlib inline
from scipy.stats import gaussian_kde
from numba import jit
import numpy as np
x = comp.sim['distance_m'].tolist()
y = comp.sim['distance_f'].tolist()

X, Y = np.mgrid[0:20:20j, 0:20:20j]
positions = np.vstack([X.ravel(), Y.ravel()])
values = np.vstack([x, y])
kernel = gaussian_kde(values)
Z = np.reshape(kernel(positions).T, X.shape)
plt.figure()
plt.contour(X,Y,Z)
xx = np.linspace(0,20,20)
plt.fill_between(xx, xx-1, xx+1, color='grey', alpha='0.1')
plt.xlim([0,20])
plt.ylim([0,20])
plt.xlabel('Expected Distance (yrs) to Retirement Husband')
plt.ylabel('Expected Distance (yrs) to Retirement Wife')
plt.savefig('../tex/figures/distances_nocomp.eps',dpi=600)

# %%
disc.sim['agediff'] = disc.sim['rage_mod']- disc.sim['sage_mod']
print(comp.sim[['distance_m','distance_f']].describe())
print(disc.sim[['distance_m','distance_f']].describe())
# Out:
#        distance_m  distance_f
# count  464.000000  464.000000
# mean    10.637931    8.204741
# std      4.337085    4.804055
# min      0.000000    0.000000
# 25%      8.000000    5.000000
# 50%     10.000000    8.000000
# 75%     13.000000   11.000000
# max     28.000000   23.000000
#        distance_m  distance_f
# count  464.000000  464.000000
# mean    10.163793    7.743534
# std      6.832073    7.032857
# min      0.000000    0.000000
# 25%      5.000000    1.000000
# 50%     10.000000    7.000000
# 75%     15.000000   13.000000
# max     29.000000   31.000000

# %% [markdown]
# # Policy Simulation

# %% [markdown]
# Finally, we have to check what happens when we do policy simulations. We will do policy simulations over two parameters, the ARF (actuarial reduction factor) and the generosity of the pension (replacement rate).

# %%
arf = [0,0.09]
drc = [0,0.11]
rep = [0.4,0.8]
factors = zip(arf,drc)
experiments = [disc]
for a,d in factors:
    this = sp('discount')
    this.chgoption('iload','T')
    this.chgoption('idiscount','T')
    this.chgoption('arf',a)
    this.chgoption('drc',d)
    this.estimate()
    this.sim['distance_m'] = this.sim['rexpret_sim'] - this.sim['rage_mod']
    this.sim['distance_f'] = this.sim['sexpret_sim'] - this.sim['sage_mod']
    this.sim['joint'] = np.abs(this.sim['distance_m'] - this.sim['distance_f'])<=1.0    
    experiments.append(this)
for r in rep:
    this = sp('discount')
    this.chgoption('iload','T')
    this.chgoption('idiscount','T')
    this.chgoption('reprate',r)
    this.estimate()
    this.sim['distance_m'] = this.sim['rexpret_sim'] - this.sim['rage_mod']
    this.sim['distance_f'] = this.sim['sexpret_sim'] - this.sim['sage_mod']
    this.sim['joint'] = np.abs(this.sim['distance_m'] - this.sim['distance_f'])<=1.0    
    experiments.append(this)
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  T
# ibargaininghetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F
# changed item  iload  with value F  to  T  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  arf  with value 0.06  to  0  ...
# changed item  drc  with value 0.08  to  0  ...
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  T
# ibargaininghetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F
# changed item  iload  with value F  to  T  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  arf  with value 0.06  to  0.09  ...
# changed item  drc  with value 0.08  to  0.11  ...
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  T
# ibargaininghetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F
# changed item  iload  with value F  to  T  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  reprate  with value 0.6  to  0.4  ...
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  T
# ibargaininghetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F
# changed item  iload  with value F  to  T  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  reprate  with value 0.6  to  0.8  ...

# %%
data = [[e.sim['rexpret_sim'].mean(),e.sim['sexpret_sim'].mean(),e.sim['joint'].mean()] for e in experiments]
names = ['Baseline','No Penalty','High Penalty','Low Generosity','High Generosity']
table = pd.DataFrame(data=data,columns=['Ret Age Males','Ret Age Females','Fraction Retiring Jointly'],index=names)
print(table)
def f(x):
    return '{:1.3f}'.format(x)
with open('../tex/tables/policy.tex','w') as tf:
    tf.write(table.to_latex(formatters=[f,f,f]))
# Out:
#                  Ret Age Males  Ret Age Females  Fraction Retiring Jointly
# Baseline             66.799569        63.405172                   0.267241
# No Penalty           64.405172        61.573276                   0.293103
# High Penalty         67.747845        64.066810                   0.193966
# Low Generosity       67.357759        63.728448                   0.183190
# High Generosity      66.394397        63.150862                   0.284483
