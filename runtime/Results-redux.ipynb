# %% [markdown]
# # Obtaining Estimation and Simulation Results

# %%
import os
from matplotlib import pyplot as plt
from tools import models
import pandas as pd

# %% [markdown]
# We now create a base instance of the model (constant discount rates). This is useful for starting other specifications

# %% [markdown]
# We will now create a model that estimates discount rates

# %%
sp = models.sp
disc = sp('discount')
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  T
# ibargaininghetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F

# %% [markdown]
# We need to flag that we want to estimate discount rates

# %%
disc.chgoption('idiscount','T')
disc.chgoption('iload','T')
#disc.chgoption('inoestim','T')
# Out:
# changed item  idiscount  with value F  to  T  ...
# changed item  iload  with value F  to  T  ...

# %% [markdown]
# We now estimate parameters

# %%
disc.estimate()
disc.loglike
# Out:
# -2612.8160248178824

# %%
disc.params
# Out:
#                                        par                       se
# alpha_c                0.17426104668552983  4.1946880181401011E-002
# alpha_lm_cons          -1.3539382904691126      0.70627398181987178
# alpha_lm_age           0.35889457786435625  5.7289870935702890E-002
# alpha_lm_hlim           1.0106922187416827      0.44707019601941544
# alpha_lm_college  -4.3339871827018400E-002      0.22958353464219436
# alpha_lm_male          0.23841283334873556      0.34096478139101777
# alpha_lm_job           0.10435206366964651      0.30443509828448662
# alpha_lf                0.0000000000000000       0.0000000000000000
# alpha_lm_lf           -0.38266637935499470  5.3201515843647414E-002
# beta_c                 0.13629763305527459  4.3724332912631898E-002
# beta_lf_cons          -0.39629890068651474      0.74549272037809700
# beta_lf_age            0.38478108220370311  7.7981885920742663E-002
# beta_lf_hlim           0.86196501226782429      0.45787404936865300
# beta_lf_college       -0.13915150150543365      0.21967146149179009
# beta_lf_male            1.3952444978639813      0.43013606952302075
# beta_lf_job        7.7871188064954994E-002      0.23608930354729063
# beta_lm                 0.0000000000000000       0.0000000000000000
# beta_lm_lf            -0.37104937722591352  6.2328758646892683E-002
# mu                     0.28490645182130170      0.67562794316775709
# wageratio               1.5076511428462283       1.1349370001038157
# log_rho_m          3.1319633125201203E-002  9.8648733043143165E-003
# log_rho_f          2.0320780108240316E-002  1.2105454972366675E-002
# tau_m_0                -3.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# tau_f_0                -3.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_sig_m               0.0000000000000000       0.0000000000000000
# log_sig_f               0.0000000000000000       0.0000000000000000
# L_nm_nm               -0.63595659954276995       1.0306061595972282
# L_nf_nm            8.4474041464758162E-003       1.3791714665901798
# L_nf_nf           -5.5237070297669277E-002      0.58318095757201793
# LJ_nm_nm                1.1685241712182994      0.13105039517007611
# LJ_nf_nm               0.90373024607821417      0.12568235788983201
# LJ_nf_nf          -1.0363956713135825E-002  5.9516510030681972E-002
# LW                      0.0000000000000000       0.0000000000000000
# scale_m                 1.0000000000000000       0.0000000000000000
# scale_f                 1.0000000000000000       0.0000000000000000
# scale_h                 1.0000000000000000       0.0000000000000000

# %% [markdown]
# Some stats again on types

# %%
disc.sim.describe()
# Out:
#            hhidpn  insim       jprob  rexpret_sim  sexpret_sim   leisure_m  \
# count  464.000000  464.0  464.000000   464.000000   464.000000  464.000000
# mean   303.915948    1.0    0.118534    66.797414    63.403017   -0.320089
# std    174.229335    0.0    0.323589     6.165983     6.643276    0.039286
# min      1.000000    1.0    0.000000    51.000000    50.000000   -0.453151
# 25%    155.750000    1.0    0.000000    62.000000    58.750000   -0.343253
# 50%    300.500000    1.0    0.000000    67.000000    62.000000   -0.318341
# 75%    454.250000    1.0    0.000000    71.000000    68.000000   -0.297871
# max    604.000000    1.0    1.000000    80.000000    80.000000   -0.211011
#
#         leisure_f  leisure_joint_m  leisure_joint_f  uhbargain  ...  \
# count  464.000000       464.000000       464.000000      464.0  ...
# mean    -0.023386         0.594092         0.454269        0.0  ...
# std      0.008518         0.286628         0.221693        0.0  ...
# min     -0.041590         0.082814         0.059934        0.0  ...
# 25%     -0.031271         0.330904         0.249746        0.0  ...
# 50%     -0.023149         0.595137         0.454796        0.0  ...
# 75%     -0.016137         0.856621         0.656659        0.0  ...
# max     -0.006381         1.101166         0.847696        0.0  ...
#
#           rhlth62     shlth62     rliv75r     sliv75r       rwage       swage  \
# count  464.000000  464.000000  464.000000  464.000000  464.000000  464.000000
# mean     0.400431    0.395948    0.962090    0.912592   32.643196   25.571926
# std      0.277485    0.265845    0.322436    0.245628   35.602573   60.575684
# min      0.000000    0.000000    0.137999    0.062038    0.000000    0.000000
# 25%      0.200000    0.200000    0.720568    0.744456   16.060606   12.884816
# 50%      0.400000    0.400000    1.012476    0.968663   25.092495   17.923750
# 75%      0.500000    0.500000    1.175370    1.065559   36.888889   27.450981
# max      1.000000    1.000000    1.491040    1.291550  365.000000  916.666687
#
#            rhours      shours      rexpret      sexpret
# count  464.000000  464.000000   200.000000   257.000000
# mean    42.728448   35.831897  2019.150000  2019.669261
# std     10.666330   12.125414     5.325345     5.157249
# min      2.000000    1.000000  2010.000000  2010.000000
# 25%     40.000000   30.000000  2015.000000  2016.000000
# 50%     40.000000   40.000000  2019.000000  2019.000000
# 75%     50.000000   40.000000  2022.000000  2023.000000
# max     80.000000   75.000000  2040.000000  2034.000000
#
# [8 rows x 152 columns]

# %% [markdown]
# ## Correlation with Expected Retirement in HRS

# %%
disc.sim['rexpret'] = disc.sim['rage_mod'] + (disc.sim['rexpret']-2011)
disc.sim['sexpret'] = disc.sim['sage_mod'] + (disc.sim['sexpret']-2011)

# %%
disc.sim[['rexpret','sexpret']].describe()
# Out:
#           rexpret     sexpret
# count  200.000000  257.000000
# mean    64.870000   64.459144
# std      4.203743    4.221328
# min     54.000000   54.000000
# 25%     62.000000   62.000000
# 50%     65.000000   64.000000
# 75%     68.000000   66.000000
# max     84.000000   80.000000

# %% [markdown]
# Correlations with simulated expected retirement age

# %%
print('Males   : ',disc.sim[['rexpret','rexpret_sim']].corr())
print('Females : ',disc.sim[['sexpret','sexpret_sim']].corr())
# Out:
# Males   :                rexpret  rexpret_sim
# rexpret      1.000000     0.198948
# rexpret_sim  0.198948     1.000000
# Females :                sexpret  sexpret_sim
# sexpret      1.000000     0.262639
# sexpret_sim  0.262639     1.000000

# %% [markdown]
# We will do a figure to check correlation

# %%
from scipy.stats import linregress
data = disc.sim[['rexpret_sim','rexpret']].dropna()
x = data['rexpret_sim']
y = data['rexpret']
slope, intercept, r_value, p_value, std_err = linregress(x,y)
line = slope*x+intercept
plt.figure()
plt.scatter(x,y,label='')
plt.plot(x, line, 'r', label='y={:.2f}x+{:.2f}: $R^2$={:.2f}'.format(slope,intercept,r_value))
plt.xlabel('expected retirement age (Model)')
plt.ylabel('expected retirement age (HRS)')
plt.legend(loc=4)
plt.savefig('../tex/figures/match_males.eps')
plt.show()

# %%
from scipy.stats import linregress
data = disc.sim[['sexpret_sim','sexpret']].dropna()
x = data['sexpret_sim']
y = data['sexpret']
slope, intercept, r_value, p_value, std_err = linregress(x,y)
line = slope*x+intercept
plt.figure()
plt.scatter(x,y,label='')
plt.plot(x, line, 'r', label='y={:.2f}x+{:.2f}: $R^2$={:.2f}'.format(slope,intercept,r_value))
plt.xlabel('expected retirement age (Model)')
plt.ylabel('expected retirement age (HRS)')
plt.legend(loc=4)
plt.savefig('../tex/figures/match_females.eps')
plt.show()

# %% [markdown]
# ## Distribution of Retirement Ages

# %%
# %matplotlib inline
from scipy.stats import gaussian_kde
from numba import jit
import numpy as np
x = disc.sim['rexpret_sim'].tolist()
y = disc.sim['sexpret_sim'].tolist()
print(disc.sim[['rexpret_sim','sexpret_sim']].describe())
print('correlation : ', disc.sim[['rexpret_sim','sexpret_sim']].corr())
X, Y = np.mgrid[60:69:10j, 60:69:10j]
positions = np.vstack([X.ravel(), Y.ravel()])
values = np.vstack([x, y])
kernel = gaussian_kde(values)
Z = np.reshape(kernel(positions).T, X.shape)
plt.figure()
plt.contour(X,Y,Z)
plt.xlabel('Expected Retirement Age Husband')
plt.ylabel('Expected Retirement Age Wife')
plt.savefig('../tex/figures/retages.eps')
# Out:
#        rexpret_sim  sexpret_sim
# count   464.000000   464.000000
# mean     66.797414    63.403017
# std       6.165983     6.643276
# min      51.000000    50.000000
# 25%      62.000000    58.750000
# 50%      67.000000    62.000000
# 75%      71.000000    68.000000
# max      80.000000    80.000000
# correlation :               rexpret_sim  sexpret_sim
# rexpret_sim     1.000000     0.661456
# sexpret_sim     0.661456     1.000000

# %%
disc.sim['distance_m'] = disc.sim['rexpret_sim'] - disc.sim['rage_mod']
disc.sim['distance_f'] = disc.sim['sexpret_sim'] - disc.sim['sage_mod']
print(disc.sim[['distance_m','distance_f']].describe())
print('correlation: ', disc.sim[['distance_m','distance_f']].corr())

# %matplotlib inline
from scipy.stats import gaussian_kde
from numba import jit
import numpy as np
x = disc.sim['distance_m'].tolist()
y = disc.sim['distance_f'].tolist()

X, Y = np.mgrid[0:20:20j, 0:20:20j]
positions = np.vstack([X.ravel(), Y.ravel()])
values = np.vstack([x, y])
kernel = gaussian_kde(values)
Z = np.reshape(kernel(positions).T, X.shape)
plt.figure()
plt.contour(X,Y,Z)
xx = np.linspace(0,20,20)
plt.fill_between(xx, xx-1, xx+1, color='grey', alpha='0.1')
plt.xlim([0,20])
plt.ylim([0,20])
plt.xlabel('Expected Distance (yrs) to Retirement Husband')
plt.ylabel('Expected Distance (yrs) to Retirement Wife')
plt.savefig('../tex/figures/distances.eps',dpi=600)
# Out:
#        distance_m  distance_f
# count  464.000000  464.000000
# mean    10.161638    7.741379
# std      6.834495    7.028016
# min      0.000000    0.000000
# 25%      5.000000    1.000000
# 50%     10.000000    7.000000
# 75%     15.000000   13.000000
# max     29.000000   31.000000
# correlation:              distance_m  distance_f
# distance_m    1.000000    0.684303
# distance_f    0.684303    1.000000

# %% [markdown]
# ## Joint Retirement

# %% [markdown]
# We will now re-rerun the discount model (baseline) with three scenarios: reshuffling heterogeneity, reshuffling wages and shutting down complementarity.

# %%
wages = sp('discount')
wages.chgoption('iload','T')
wages.chgoption('idiscount','T')
wages.chgoption('ishufwages','T')
wages.estimate()
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  T
# ibargaininghetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F
# changed item  iload  with value F  to  T  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  ishufwages  with value F  to  T  ...

# %%
heter = sp('discount')
heter.chgoption('iload','T')
heter.chgoption('idiscount','T')
heter.chgoption('ishufheter','T')
heter.estimate()
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  T
# ibargaininghetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F
# changed item  iload  with value F  to  T  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  ishufheter  with value F  to  T  ...

# %%
comp = sp('discount')
comp.chgoption('iload','T')
comp.chgoption('idiscount','T')
comp.chgoption('iblockcomp','T')
comp.estimate()
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  T
# ibargaininghetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F
# changed item  iload  with value F  to  T  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  iblockcomp  with value F  to  T  ...

# %%
specs = [disc,wages,heter,comp]
names =  ['Baseline','Shuffling Wages','Shuffling UH','No Complementarity']
data = []
plt.figure()
for i,s in enumerate(specs):
    s.sim['distance_m'] = s.sim['rexpret_sim'] - s.sim['rage_mod']
    s.sim['distance_f'] = s.sim['sexpret_sim'] - s.sim['sage_mod']
    s.sim['joint'] = np.abs(s.sim['distance_m'] - s.sim['distance_f'])<=1.0
    s.sim['joint_yrs'] = s.sim['distance_m'] - s.sim['distance_f']
    x = s.sim['joint_yrs'].values
    x.sort()
    ff = gaussian_kde(x)
    plt.plot(x,ff(x),label=names[i])
    data.append([s.sim['rexpret_sim'].mean(),s.sim['sexpret_sim'].mean(),s.sim['joint'].mean()])
table = pd.DataFrame(data=data,index=names,columns=['Ret Age Males','Ret Age Females','Fraction Joint'])  
def f(x):
    return '{:1.3f}'.format(x)
with open('../tex/tables/joint.tex','w') as tf:
    tf.write(table.to_latex(formatters=[f,f,f]))
plt.legend(loc=2)
plt.xlabel('difference in distance to retirement')
plt.ylabel('density')
plt.xlim([-15,15])
plt.savefig('../tex/figures/compare_distances.eps')
plt.show()
table
# Out:
#                     Ret Age Males  Ret Age Females  Fraction Joint
# Baseline                66.797414        63.403017        0.267241
# Shuffling Wages         66.674569        63.232759        0.200431
# Shuffling UH            66.827586        63.646552        0.245690
# No Complementarity      67.187500        64.760776        0.232759

# %%
# %matplotlib inline
from scipy.stats import gaussian_kde
from numba import jit
import numpy as np
x = comp.sim['distance_m'].tolist()
y = comp.sim['distance_f'].tolist()

X, Y = np.mgrid[0:20:20j, 0:20:20j]
positions = np.vstack([X.ravel(), Y.ravel()])
values = np.vstack([x, y])
kernel = gaussian_kde(values)
Z = np.reshape(kernel(positions).T, X.shape)
plt.figure()
plt.contour(X,Y,Z)
xx = np.linspace(0,20,20)
plt.fill_between(xx, xx-1, xx+1, color='grey', alpha='0.1')
plt.xlim([0,20])
plt.ylim([0,20])
plt.xlabel('Expected Distance (yrs) to Retirement Husband')
plt.ylabel('Expected Distance (yrs) to Retirement Wife')
plt.savefig('../tex/figures/distances_nocomp.eps',dpi=600)

# %%
disc.sim['agediff'] = disc.sim['rage_mod']- disc.sim['sage_mod']
print(comp.sim[['distance_m','distance_f']].describe())
print(disc.sim[['distance_m','distance_f']].describe())
# Out:
#        distance_m  distance_f
# count  464.000000  464.000000
# mean    10.551724    9.099138
# std      6.000137    6.245420
# min      0.000000    0.000000
# 25%      6.000000    4.000000
# 50%     10.000000    9.000000
# 75%     15.000000   13.250000
# max     28.000000   31.000000
#        distance_m  distance_f
# count  464.000000  464.000000
# mean    10.161638    7.741379
# std      6.834495    7.028016
# min      0.000000    0.000000
# 25%      5.000000    1.000000
# 50%     10.000000    7.000000
# 75%     15.000000   13.000000
# max     29.000000   31.000000

# %% [markdown]
# # Policy Simulation

# %% [markdown]
# Finally, we have to check what happens when we do policy simulations. We will do policy simulations over two parameters, the ARF (actuarial reduction factor) and the generosity of the pension (replacement rate).

# %%
arf = [0,0.09]
drc = [0,0.11]
rep = [0.4,0.8]
factors = zip(arf,drc)
experiments = [disc]
for a,d in factors:
    this = sp('discount')
    this.chgoption('iload','T')
    this.chgoption('idiscount','T')
    this.chgoption('arf',a)
    this.chgoption('drc',d)
    this.estimate()
    this.sim['distance_m'] = this.sim['rexpret_sim'] - this.sim['rage_mod']
    this.sim['distance_f'] = this.sim['sexpret_sim'] - this.sim['sage_mod']
    this.sim['joint'] = np.abs(this.sim['distance_m'] - this.sim['distance_f'])<=1.0    
    experiments.append(this)
for r in rep:
    this = sp('discount')
    this.chgoption('iload','T')
    this.chgoption('idiscount','T')
    this.chgoption('reprate',r)
    this.estimate()
    this.sim['distance_m'] = this.sim['rexpret_sim'] - this.sim['rage_mod']
    this.sim['distance_f'] = this.sim['sexpret_sim'] - this.sim['sage_mod']
    this.sim['joint'] = np.abs(this.sim['distance_m'] - this.sim['distance_f'])<=1.0    
    experiments.append(this)
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  T
# ibargaininghetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F
# changed item  iload  with value F  to  T  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  arf  with value 0.06  to  0  ...
# changed item  drc  with value 0.08  to  0  ...
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  T
# ibargaininghetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F
# changed item  iload  with value F  to  T  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  arf  with value 0.06  to  0.09  ...
# changed item  drc  with value 0.08  to  0.11  ...
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  T
# ibargaininghetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F
# changed item  iload  with value F  to  T  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  reprate  with value 0.6  to  0.4  ...
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  T
# ibargaininghetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F
# changed item  iload  with value F  to  T  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  reprate  with value 0.6  to  0.8  ...

# %%
data = [[e.sim['rexpret_sim'].mean(),e.sim['sexpret_sim'].mean(),e.sim['joint'].mean()] for e in experiments]
names = ['Baseline','No Penalty','High Penalty','Low Generosity','High Generosity']
table = pd.DataFrame(data=data,columns=['Ret Age Males','Ret Age Females','Fraction Retiring Jointly'],index=names)
print(table)
def f(x):
    return '{:1.3f}'.format(x)
with open('../tex/tables/policy.tex','w') as tf:
    tf.write(table.to_latex(formatters=[f,f,f]))
# Out:
#                  Ret Age Males  Ret Age Females  Fraction Retiring Jointly
# Baseline             66.797414        63.403017                   0.267241
# No Penalty           64.405172        61.573276                   0.293103
# High Penalty         67.747845        64.066810                   0.193966
# Low Generosity       67.357759        63.728448                   0.183190
# High Generosity      66.394397        63.150862                   0.284483

# %% [markdown]
# ## Testing fixed correlation coefficients

# %%
listofrho = np.linspace(0,1.1,12)
listofrho[listofrho==1.] = 0.995
listofrho[listofrho==1.1] = 0.9999


#listofrho = [0,0.1,0.25,0.5,0.75,0.9]

# %%
# %matplotlib inline
from scipy.stats import gaussian_kde
from numba import jit
import numpy as np
import copy as cp

fixed = sp('fixcorr')
fixed.chgoption('idiscount','T')
fixed.chgoption('iload','T')
fixed.chgoption('ifixcorr','T')
fixed.chgoption('icomplement','F')

lsloglik = []
#lsparams = []

dctresults = {}

for rho in listofrho:    
    print(rho)
    fixed.chgoption('dfixrho',rho)
    fixed.estimate()
    dctresults[rho] = cp.copy(fixed)
    lsloglik.append(fixed.loglike)
    #lsparams.append(fixed.params)
    
    #Graph of the joint distance
    fixed.sim['distance_m'] = fixed.sim['rexpret_sim'] - fixed.sim['rage_mod']
    fixed.sim['distance_f'] = fixed.sim['sexpret_sim'] - fixed.sim['sage_mod']
    fixed.sim['joint'] = np.abs(fixed.sim['distance_m'] - fixed.sim['distance_f'])<=1.0  
    x = fixed.sim['distance_m'].tolist()
    y = fixed.sim['distance_f'].tolist()

    X, Y = np.mgrid[0:20:20j, 0:20:20j]
    positions = np.vstack([X.ravel(), Y.ravel()])
    values = np.vstack([x, y])
    kernel = gaussian_kde(values)
    Z = np.reshape(kernel(positions).T, X.shape)
    plt.figure()
    plt.contour(X,Y,Z)
    xx = np.linspace(0,20,20)
    plt.fill_between(xx, xx-1, xx+1, color='grey', alpha='0.1')
    plt.xlim([0,20])
    plt.ylim([0,20])
    plt.xlabel('Expected Distance (yrs) to Retirement Husband')
    plt.ylabel('Expected Distance (yrs) to Retirement Wife')
    plt.savefig('../tex/figures/distances_nocomp%d.eps' %rho,dpi=600)
    plt.show()
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  T
# ibargaininghetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F
# changed item  idiscount  with value F  to  T  ...
# changed item  iload  with value F  to  T  ...
# changed item  ifixcorr  with value F  to  T  ...
# changed item  icomplement  with value T  to  F  ...
# 0.0
# changed item  dfixrho  with value 0.5  to  0.0  ...
# 0.1
# changed item  dfixrho  with value 0.0  to  0.1  ...
# 0.2
# changed item  dfixrho  with value 0.1  to  0.2  ...
# 0.30000000000000004
# changed item  dfixrho  with value 0.2  to  0.30000000000000004  ...
# 0.4
# changed item  dfixrho  with value 0.30000000000000004  to  0.4  ...
# 0.5
# changed item  dfixrho  with value 0.4  to  0.5  ...
# 0.6000000000000001
# changed item  dfixrho  with value 0.5  to  0.6000000000000001  ...
# 0.7000000000000001
# changed item  dfixrho  with value 0.6000000000000001  to  0.7000000000000001  ...
# 0.8
# changed item  dfixrho  with value 0.7000000000000001  to  0.8  ...
# 0.9
# changed item  dfixrho  with value 0.8  to  0.9  ...
# 0.995
# changed item  dfixrho  with value 0.9  to  0.995  ...
# 0.9999
# changed item  dfixrho  with value 0.995  to  0.9999  ...

# %%
listofdens = []
listofx    = []

data = []
plt.figure()

for key in dctresults:
    this = dctresults[key]
    #print(this.sim.describe())
    this.sim['distance_m'] = this.sim['rexpret_sim'] - this.sim['rage_mod']
    this.sim['distance_f'] = this.sim['sexpret_sim'] - this.sim['sage_mod']
    this.sim['joint'] = np.abs(this.sim['distance_m'] - this.sim['distance_f'])<=1.0
    this.sim['joint_yrs'] = this.sim['distance_m'] - this.sim['distance_f']
    x = this.sim['joint_yrs'].values
    x.sort()
    ff = gaussian_kde(x)
    listofx.append(x)
    listofdens.append(ff(x))
    plt.plot(x,ff(x)) #,label=key)
        #data.append([this.sim['rexpret_sim'].mean(),this.sim['sexpret_sim'].mean(),this.sim['joint'].mean()])
        #table = pd.DataFrame(data=data,index=names,columns=['Ret Age Males','Ret Age Females','Fraction Joint'])  
        #def f(x):
        #    return '{:1.3f}'.format(x)
        #with open('../tex/tables/joint.tex','w') as tf:
        #    tf.write(table.to_latex(formatters=[f,f,f]))

# plt.plot(listofx,listofdens, label=dctresults.keys())

plt.legend(loc=2, labels=dctresults.keys())
plt.xlabel('difference in distance to retirement')
plt.ylabel('density')
plt.xlim([-15,15])
plt.savefig('../tex/figures/compare_distances_multiples_rho.eps')
#plt.show()
#table

plt.show()

# %%
listofjoin = []
listofval = []
for key in dctresults:
    this = dctresults[key]
    listofjoin.append(this.sim['joint'].mean())
    listofval.append(key)
    
plt.plot(listofval, listofjoin)

# %% [markdown]
# ### No complementarity, moving correlation.

# %%
comp = sp('discount')
comp.chgoption('iload','T')
comp.chgoption('idiscount','T')
#comp.chgoption('icomplement','F')
comp.chgoption('iblockcomp','T')
comp.estimate()
comp.sim.describe()
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  T
# ibargaininghetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F
# changed item  iload  with value F  to  T  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  iblockcomp  with value F  to  T  ...
#            hhidpn  insim       jprob  rexpret_sim  sexpret_sim   leisure_m  \
# count  464.000000  464.0  464.000000   464.000000   464.000000  464.000000
# mean   303.915948    1.0    0.073276    67.187500    64.762931   -0.320287
# std    174.229335    0.0    0.260870     5.121565     5.651109    0.039314
# min      1.000000    1.0    0.000000    55.000000    51.000000   -0.453427
# 25%    155.750000    1.0    0.000000    62.750000    61.000000   -0.343473
# 50%    300.500000    1.0    0.000000    67.000000    65.000000   -0.318549
# 75%    454.250000    1.0    0.000000    71.000000    68.000000   -0.298055
# max    604.000000    1.0    1.000000    80.000000    80.000000   -0.211142
#
#         leisure_f  leisure_joint_m  leisure_joint_f  uhbargain  ...  \
# count  464.000000       464.000000       464.000000      464.0  ...
# mean    -0.023489         0.594042         0.454253        0.0  ...
# std      0.008519         0.286604         0.221686        0.0  ...
# min     -0.041681         0.082810         0.059932        0.0  ...
# 25%     -0.031358         0.330876         0.249736        0.0  ...
# 50%     -0.023251         0.595089         0.454779        0.0  ...
# 75%     -0.016233         0.856550         0.656639        0.0  ...
# max     -0.006475         1.101081         0.847673        0.0  ...
#
#           rhlth62     shlth62     rliv75r     sliv75r       rwage       swage  \
# count  464.000000  464.000000  464.000000  464.000000  464.000000  464.000000
# mean     0.400431    0.395948    0.962090    0.912592   32.643196   25.571926
# std      0.277485    0.265845    0.322436    0.245628   35.602573   60.575684
# min      0.000000    0.000000    0.137999    0.062038    0.000000    0.000000
# 25%      0.200000    0.200000    0.720568    0.744456   16.060606   12.884816
# 50%      0.400000    0.400000    1.012476    0.968663   25.092495   17.923750
# 75%      0.500000    0.500000    1.175370    1.065559   36.888889   27.450981
# max      1.000000    1.000000    1.491040    1.291550  365.000000  916.666687
#
#            rhours      shours      rexpret      sexpret
# count  464.000000  464.000000   200.000000   257.000000
# mean    42.728448   35.831897  2019.150000  2019.669261
# std     10.666330   12.125414     5.325345     5.157249
# min      2.000000    1.000000  2010.000000  2010.000000
# 25%     40.000000   30.000000  2015.000000  2016.000000
# 50%     40.000000   40.000000  2019.000000  2019.000000
# 75%     50.000000   40.000000  2022.000000  2023.000000
# max     80.000000   75.000000  2040.000000  2034.000000
#
# [8 rows x 152 columns]

# %%
### Creating a fake scenario and escaping estimation ####
drho = 0.5

lsloglik = []
#lsparams = []

dct_new_results = {}

nocomp_varrho = cp.copy(comp)
nocomp_varrho.scenario = "nocomp_varrho"
nocomp_varrho.chgoption('inoestim','T')

for drho in listofrho:

    ## Computing the var cov matrix
    M11 = pd.to_numeric(nocomp_varrho.params['par'].loc['L_nm_nm'])
    M12 = pd.to_numeric(nocomp_varrho.params['par'].loc['L_nf_nm'])
    M22 = pd.to_numeric(nocomp_varrho.params['par'].loc['L_nf_nf'])

    M = np.array([[M11, 0],[M12,  M22]])
    varcov = np.matmul(M,M.T)

    # Maintaining var cst, changing only the correlation. 
    newvarcov = varcov
    newvarcov[0,1] = drho * (np.sqrt(varcov[0,0])*np.sqrt(varcov[1,1]))
    newvarcov[1,0] = newvarcov[0,1]

    # Writing in the table.
    newchol = np.linalg.cholesky(newvarcov)
    
    print(newchol)

    nocomp_varrho.params['par'].loc['L_nf_nm'] = newchol[1,0] 
    nocomp_varrho.params['par'].loc['L_nf_nf'] = newchol[1,1] 

    ## Dumping the table first
    nocomp_varrho.params.to_csv('../params/temp.csv', header = False, sep = '\t')
    
    # Putting the content back in memory
    f = open('../params/'+ 'temp' +'.csv')
    buff = f.read()
    f.close()
    buff = buff.split('\n')

    # Adding the two lines
    f = open('../params/parms_%s.csv'%nocomp_varrho.scenario, "w+")
    f.write(str(comp.loglike)+"\n")
    f.write('48')

    ##Rewriting the parameters
    for line in buff:
        f.write("\n" + line)

    f.close()
    nocomp_varrho.estimate()
    nocomp_varrho.sim['distance_m'] = nocomp_varrho.sim['rexpret_sim'] - nocomp_varrho.sim['rage_mod']
    nocomp_varrho.sim['distance_f'] = nocomp_varrho.sim['sexpret_sim'] - nocomp_varrho.sim['sage_mod']
    nocomp_varrho.sim['joint'] = np.abs(nocomp_varrho.sim['distance_m'] - nocomp_varrho.sim['distance_f'])<=1.0
    nocomp_varrho.sim['joint_yrs'] = nocomp_varrho.sim['distance_m'] - nocomp_varrho.sim['distance_f']
    dct_new_results[drho] = cp.copy(nocomp_varrho)
# Out:
# changed item  inoestim  with value F  to  T  ...
# [[0.6363477  0.        ]
#  [0.         0.05584656]]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-27-24a89550482d> in <module>
#      53
#      54     f.close()
# ---> 55     nocomp_varrho.estimate()
#      56     nocomp_varrho.sim['distance_m'] = nocomp_varrho.sim['rexpret_sim'] - nocomp_varrho.sim['rage_mod']
#      57     nocomp_varrho.sim['distance_f'] = nocomp_varrho.sim['sexpret_sim'] - nocomp_varrho.sim['sage_mod']
#
# ~/Documents/github/joint/runtime/tools/models.py in estimate(self)
#      53     def estimate(self):
#      54         self.buff = subprocess.check_output(['./runestimation',self.scenario])
# ---> 55         self.write()
#      56         self.getsim()
#      57
#
# ~/Documents/github/joint/runtime/tools/models.py in write(self)
#      67         se = [None] * npar
#      68         for i,line in enumerate(buff[2:-1]):
# ---> 69             labels[i],par[i],se[i] = line.split()
#      70             labels[i],par[i],se[i] = line.split()
#      71         self.params = pd.DataFrame(data={'par': par,'se': se},index=labels)
#
# IndexError: list assignment index out of range

# %%
listofjoin = []
listofval = []
for key in dct_new_results:
    this = dct_new_results[key]
    listofjoin.append(this.sim['joint'].mean())
    listofval.append(key)
    
plt.plot(listofval, listofjoin)

# %%
comp.params

# %%
dct_new_results[0.995].sim['joint_num'] = dct_new_results[0.995].sim['joint']*1.0
dct_new_results[0.995].sim[['joint_yrs', 'joint_num']].groupby('joint_yrs').sum()

# %%
try:
    del dfbyage
except:
    pass

for key in dct_new_results:
    dct_new_results[key].sim['diffage'] = np.abs(dct_new_results[key].sim['rage_mod'] 
                                               - dct_new_results[key].sim['sage_mod'])
    thisdict = dct_new_results[key].sim[['diffage', 'joint']].groupby('diffage').mean()
    thisdict['rho'] = key
    
    try:
        dfbyage = dfbyage.append(thisdict)
    except:
        dfbyage = thisdict.copy()

# %%
dfbyage.pivot(columns='rho').plot()
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
dfbyage.pivot(columns='rho')
