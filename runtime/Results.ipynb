# %% [markdown]
# # Obtaining Estimation and Simulation Results

# %%
import os
from matplotlib import pyplot as plt
from tools import models

# %% [markdown]
# We now create a base instance of the model (constant discount rates). This is useful for starting other specifications

# %%
sp = models.sp
base = sp('ref')
base.chgoption('iload','T')
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F
# changed item  iload  with value F  to  T  ...

# %% [markdown]
# We estimate parameters and simulate data post estimation

# %%
base.estimate()
base.loglike
# Out:
# -2846.7197366150785

# %%
base.params
# Out:
#                                        par                       se
# alpha_c                0.66577894648853442  5.6115952644042032E-002
# alpha_lm_cons          -3.0008746639854209      0.90455787581028846
# alpha_lm_age           0.69657402471782537      0.11056584725738521
# alpha_lm_hlim           2.9456227441856657       1.0226454618533634
# alpha_lm_college       0.35882916239603341      0.55528592837930746
# alpha_lm_male          0.44012465194619449      0.68702201935910057
# alpha_lm_job           0.20789447880671824      0.68950996447641333
# alpha_lf                0.0000000000000000       0.0000000000000000
# alpha_lm_lf            0.30956949328623962  3.8084610497995372E-002
# beta_c                 0.42912552348711952  4.2110431301014009E-002
# beta_lf_cons           -1.0259248719787868      0.69128824743343276
# beta_lf_age            0.90627688491571823      0.12554443688508182
# beta_lf_hlim            2.5276643990708427      0.94498251867869620
# beta_lf_college       -0.44287274415423555      0.46672072233701906
# beta_lf_male            1.7533108627745317      0.64109129932546705
# beta_lf_job           -0.61271309430472087      0.51097517788155566
# beta_lm                 0.0000000000000000       0.0000000000000000
# beta_lm_lf             0.16762660596731410  3.3466074398381611E-002
# mu                 6.2886795031021937E-003      0.32773112248349662
# wageratio              0.52065384428800243      0.29428735797179140
# log_rho_m         -5.1293294387550578E-002       0.0000000000000000
# log_rho_f         -5.1293294387550578E-002       0.0000000000000000
# tau_m_0                -3.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# tau_f_0                -3.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_sig_m               0.0000000000000000       0.0000000000000000
# log_sig_f               0.0000000000000000       0.0000000000000000
# L_nm_nm                 5.1788252609394760      0.45641618139375895
# L_nf_nm                 3.7583653855046077      0.34964248837630663
# L_nf_nf                0.19033273901525452      0.80158089081477502
# LJ_nm_nm                0.0000000000000000       0.0000000000000000
# LJ_nf_nm                0.0000000000000000       0.0000000000000000
# LJ_nf_nf                0.0000000000000000       0.0000000000000000
# scale_m                 1.0000000000000000       0.0000000000000000
# scale_f                 1.0000000000000000       0.0000000000000000
# scale_h                 1.0000000000000000       0.0000000000000000

# %% [markdown]
# Here are some stats on the simulations:

# %%
base.sim.describe()
# Out:
#            hhidpn  insim       jprob  rexpret_sim  sexpret_sim   leisure_m  \
# count  464.000000  464.0  464.000000   464.000000   464.000000  464.000000
# mean   303.915948    1.0    0.084052    65.974138    63.663793    0.094450
# std    174.229335    0.0    0.277765     4.989771     3.130548    4.308175
# min      1.000000    1.0    0.000000    54.000000    54.000000   -9.092998
# 25%    155.750000    1.0    0.000000    62.000000    62.000000   -3.402184
# 50%    300.500000    1.0    0.000000    67.000000    64.000000   -0.073819
# 75%    454.250000    1.0    0.000000    70.000000    66.000000    3.325357
# max    604.000000    1.0    1.000000    80.000000    78.000000   15.358397
#
#         leisure_f   rage    rcollege      hwho_m  ...     rhlth62     shlth62  \
# count  464.000000  464.0  464.000000  464.000000  ...  464.000000  464.000000
# mean     0.070059    0.0    0.441810    0.538793  ...    0.400431    0.395948
# std      3.133611    0.0    0.497139    0.499031  ...    0.277485    0.265845
# min     -6.580990    0.0    0.000000    0.000000  ...    0.000000    0.000000
# 25%     -2.461229    0.0    0.000000    0.000000  ...    0.200000    0.200000
# 50%     -0.024309    0.0    0.000000    1.000000  ...    0.400000    0.400000
# 75%      2.391873    0.0    1.000000    1.000000  ...    0.500000    0.500000
# max     11.169368    0.0    1.000000    1.000000  ...    1.000000    1.000000
#
#           rliv75r     sliv75r       rwage       swage      rhours      shours  \
# count  464.000000  464.000000  464.000000  464.000000  464.000000  464.000000
# mean     0.962090    0.912592   32.615540   25.620789   42.728448   35.831897
# std      0.322436    0.245628   35.582619   60.577724   10.666330   12.125414
# min      0.137999    0.062038    0.000000    0.000000    2.000000    1.000000
# 25%      0.720568    0.744456   16.347501   12.967500   40.000000   30.000000
# 50%      1.012476    0.968663   25.092495   18.000000   40.000000   40.000000
# 75%      1.175370    1.065559   36.758401   27.415630   50.000000   40.000000
# max      1.491040    1.291550  365.000000  916.666687   80.000000   75.000000
#
#            rexpret      sexpret
# count   200.000000   257.000000
# mean   2019.150000  2019.669261
# std       5.325345     5.157249
# min    2010.000000  2010.000000
# 25%    2015.000000  2016.000000
# 50%    2019.000000  2019.000000
# 75%    2022.000000  2023.000000
# max    2040.000000  2034.000000
#
# [8 rows x 147 columns]

# %% [markdown]
# As per referee request, the same model with discount rate fixed to 1.

# %%
sp = models.sp
base = sp('ref')
base.chgoption('iload','T')
base.chgoption('ddiscount',1.0)
base.estimate()
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F
# changed item  iload  with value F  to  T  ...
# changed item  ddiscount  with value 0.95  to  1.0  ...

# %%
base.loglike
# Out:
# -2821.7675814484755

# %%
base.sim.describe()
# Out:
#            hhidpn  insim       jprob  rexpret_sim  sexpret_sim   leisure_m  \
# count  464.000000  464.0  464.000000   464.000000   464.000000  464.000000
# mean   303.915948    1.0    0.094828    65.834052    63.726293    0.029240
# std    174.229335    0.0    0.293293     4.775347     3.139740    2.917858
# min      1.000000    1.0    0.000000    54.000000    54.000000   -6.035248
# 25%    155.750000    1.0    0.000000    62.000000    62.000000   -2.404164
# 50%    300.500000    1.0    0.000000    66.000000    64.000000   -0.067123
# 75%    454.250000    1.0    0.000000    70.000000    66.000000    2.386686
# max    604.000000    1.0    1.000000    80.000000    79.000000    9.757121
#
#         leisure_f   rage    rcollege      hwho_m  ...     rhlth62     shlth62  \
# count  464.000000  464.0  464.000000  464.000000  ...  464.000000  464.000000
# mean     0.021122    0.0    0.441810    0.538793  ...    0.400431    0.395948
# std      1.941459    0.0    0.497139    0.499031  ...    0.277485    0.265845
# min     -3.988958    0.0    0.000000    0.000000  ...    0.000000    0.000000
# 25%     -1.582040    0.0    0.000000    0.000000  ...    0.200000    0.200000
# 50%     -0.032956    0.0    0.000000    1.000000  ...    0.400000    0.400000
# 75%      1.573731    0.0    1.000000    1.000000  ...    0.500000    0.500000
# max      6.495802    0.0    1.000000    1.000000  ...    1.000000    1.000000
#
#           rliv75r     sliv75r       rwage       swage      rhours      shours  \
# count  464.000000  464.000000  464.000000  464.000000  464.000000  464.000000
# mean     0.962090    0.912592   32.615540   25.620789   42.728448   35.831897
# std      0.322436    0.245628   35.582619   60.577724   10.666330   12.125414
# min      0.137999    0.062038    0.000000    0.000000    2.000000    1.000000
# 25%      0.720568    0.744456   16.347501   12.967500   40.000000   30.000000
# 50%      1.012476    0.968663   25.092495   18.000000   40.000000   40.000000
# 75%      1.175370    1.065559   36.758401   27.415630   50.000000   40.000000
# max      1.491040    1.291550  365.000000  916.666687   80.000000   75.000000
#
#            rexpret      sexpret
# count   200.000000   257.000000
# mean   2019.150000  2019.669261
# std       5.325345     5.157249
# min    2010.000000  2010.000000
# 25%    2015.000000  2016.000000
# 50%    2019.000000  2019.000000
# 75%    2022.000000  2023.000000
# max    2040.000000  2034.000000
#
# [8 rows x 147 columns]

# %% [markdown]
# We will now create a model that estimates discount rates

# %%
disc = sp('discount')
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F

# %% [markdown]
# We need to flag that we want to estimate discount rates

# %%
disc.chgoption('idiscount','T')
disc.chgoption('iload','T')
# Out:
# changed item  idiscount  with value F  to  T  ...
# changed item  iload  with value F  to  T  ...

# %% [markdown]
# We now estimate parameters

# %%
disc.estimate()
disc.loglike
# Out:
# -2818.3450960939763

# %%
disc.params
# Out:
#                                       par                       se
# alpha_c               0.15410536218464560  3.6922061381831864E-002
# alpha_lm_cons         -1.6851413249635874      0.47625966450140639
# alpha_lm_age          0.43293316724394554  6.4665997639376471E-002
# alpha_lm_hlim          1.6095258281896501      0.58103229180060989
# alpha_lm_college      0.16811266904887190      0.29411311909074844
# alpha_lm_male         0.18847187309118979      0.35010436697291497
# alpha_lm_job      9.4851000622775808E-002      0.34834825323106028
# alpha_lf               0.0000000000000000       0.0000000000000000
# alpha_lm_lf           0.13457141954465174  2.2591108181664373E-002
# beta_c                0.11489656352459991  3.6719028273038572E-002
# beta_lf_cons         -0.73794465687745681      0.35313391902492730
# beta_lf_age           0.47258456155344858  8.4964250461563057E-002
# beta_lf_hlim           1.4115683672418664      0.50177448458157325
# beta_lf_college      -0.19835726020850900      0.23852097076669074
# beta_lf_male          0.98657089936195852      0.35698869275039158
# beta_lf_job          -0.20895118396290266      0.25761222332890482
# beta_lm                0.0000000000000000       0.0000000000000000
# beta_lm_lf        8.0414683269743201E-002  2.1843251381760968E-002
# mu                1.4719664233777735E-002      0.33015112245766659
# wageratio             0.51796790730673137      0.30812984726052617
# log_rho_m         2.9841376648020734E-002  9.8533230448672755E-003
# log_rho_f         1.8262280661564746E-002  1.2307283347354838E-002
# tau_m_0               -3.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# tau_f_0               -3.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_sig_m              0.0000000000000000       0.0000000000000000
# log_sig_f              0.0000000000000000       0.0000000000000000
# L_nm_nm                2.8008367130958267      0.33082610602424611
# L_nf_nm                1.9215920560108457      0.29137477083424013
# L_nf_nf               0.19417067532720980      0.38539409652025913
# LJ_nm_nm               0.0000000000000000       0.0000000000000000
# LJ_nf_nm               0.0000000000000000       0.0000000000000000
# LJ_nf_nf               0.0000000000000000       0.0000000000000000
# scale_m                1.0000000000000000       0.0000000000000000
# scale_f                1.0000000000000000       0.0000000000000000
# scale_h                1.0000000000000000       0.0000000000000000

# %% [markdown]
# Some stats again on types

# %%
disc.sim.describe()
# Out:
#            hhidpn  insim       jprob  rexpret_sim  sexpret_sim   leisure_m  \
# count  464.000000  464.0  464.000000   464.000000   464.000000  464.000000
# mean   303.915948    1.0    0.099138    65.730603    63.831897    0.002727
# std    174.229335    0.0    0.299170     4.676887     3.127557    2.323406
# min      1.000000    1.0    0.000000    55.000000    54.000000   -4.755094
# 25%    155.750000    1.0    0.000000    62.000000    62.000000   -1.980888
# 50%    300.500000    1.0    0.000000    65.000000    64.000000   -0.072987
# 75%    454.250000    1.0    0.000000    70.000000    66.000000    1.905479
# max    604.000000    1.0    1.000000    80.000000    80.000000    7.265455
#
#         leisure_f   rage    rcollege      hwho_m  ...     rhlth62     shlth62  \
# count  464.000000  464.0  464.000000  464.000000  ...  464.000000  464.000000
# mean     0.003819    0.0    0.441810    0.538793  ...    0.400431    0.395948
# std      1.604531    0.0    0.497139    0.499031  ...    0.277485    0.265845
# min     -3.288774    0.0    0.000000    0.000000  ...    0.000000    0.000000
# 25%     -1.329786    0.0    0.000000    0.000000  ...    0.200000    0.200000
# 50%     -0.036296    0.0    0.000000    1.000000  ...    0.400000    0.400000
# 75%      1.307575    0.0    1.000000    1.000000  ...    0.500000    0.500000
# max      5.029947    0.0    1.000000    1.000000  ...    1.000000    1.000000
#
#           rliv75r     sliv75r       rwage       swage      rhours      shours  \
# count  464.000000  464.000000  464.000000  464.000000  464.000000  464.000000
# mean     0.962090    0.912592   32.615540   25.620789   42.728448   35.831897
# std      0.322436    0.245628   35.582619   60.577724   10.666330   12.125414
# min      0.137999    0.062038    0.000000    0.000000    2.000000    1.000000
# 25%      0.720568    0.744456   16.347501   12.967500   40.000000   30.000000
# 50%      1.012476    0.968663   25.092495   18.000000   40.000000   40.000000
# 75%      1.175370    1.065559   36.758401   27.415630   50.000000   40.000000
# max      1.491040    1.291550  365.000000  916.666687   80.000000   75.000000
#
#            rexpret      sexpret
# count   200.000000   257.000000
# mean   2019.150000  2019.669261
# std       5.325345     5.157249
# min    2010.000000  2010.000000
# 25%    2015.000000  2016.000000
# 50%    2019.000000  2019.000000
# 75%    2022.000000  2023.000000
# max    2040.000000  2034.000000
#
# [8 rows x 147 columns]

# %% [markdown]
# ## Robustness of Specification

# %% [markdown]
# We will collect a few loglikelihoods to do LR tests (Table in main text). We will also present some results in the appendix for these alternative models.

# %% [markdown]
# ### Model with uncorrelated types

# %%
uncor = sp('nocorr')
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F

# %%
uncor.chgoption('icorr','F')
uncor.chgoption('idiscount','T')
uncor.chgoption('iload','T')
# Out:
# changed item  icorr  with value T  to  F  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  iload  with value F  to  T  ...

# %%
uncor.estimate()
uncor.loglike
# Out:
# -2899.353096264837

# %%
uncor.params
# Out:
#                                        par                       se
# alpha_c                0.12819792655085302  3.0959532167474744E-002
# alpha_lm_cons          -1.5388348000222645      0.48031009170620070
# alpha_lm_age           0.40004134410521791  5.8740534173742122E-002
# alpha_lm_hlim           1.4831494480574623      0.60820665133959273
# alpha_lm_college       0.21951654613673008      0.29912726646709520
# alpha_lm_male          0.22477027993427939      0.35223899626920602
# alpha_lm_job           0.12865858021188217      0.34228816991460792
# alpha_lf                0.0000000000000000       0.0000000000000000
# alpha_lm_lf            0.11965209623572355  2.1183730918894791E-002
# beta_c             9.4456763762513024E-002  3.1507164097262119E-002
# beta_lf_cons          -0.84430857446620244      0.37809205844219190
# beta_lf_age            0.44638624645981456  8.1419927099349823E-002
# beta_lf_hlim            1.2720698045569319      0.49519809805772091
# beta_lf_college   -7.5899106730241916E-002      0.22836019885307274
# beta_lf_male           0.80724783156103364      0.33914848517177765
# beta_lf_job           -0.22006991985691660      0.26174228232843444
# beta_lm                 0.0000000000000000       0.0000000000000000
# beta_lm_lf         7.5415453533846641E-002  2.0595402517074844E-002
# mu                 9.1499506859120935E-002      0.33495476174923217
# wageratio              0.38996176102816654      0.29047981206743856
# log_rho_m          3.7589007416025222E-002  9.3426351759078024E-003
# log_rho_f          2.5775703321748340E-002  1.2132382459678041E-002
# tau_m_0                -3.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# tau_f_0                -3.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_sig_m               0.0000000000000000       0.0000000000000000
# log_sig_f               0.0000000000000000       0.0000000000000000
# L_nm_nm                 2.6925797236543851      0.32293607678896774
# L_nf_nm                 0.0000000000000000       0.0000000000000000
# L_nf_nf                 1.7619418134431835      0.27800386117140269
# LJ_nm_nm                0.0000000000000000       0.0000000000000000
# LJ_nf_nm                0.0000000000000000       0.0000000000000000
# LJ_nf_nf                0.0000000000000000       0.0000000000000000
# scale_m                 1.0000000000000000       0.0000000000000000
# scale_f                 1.0000000000000000       0.0000000000000000
# scale_h                 1.0000000000000000       0.0000000000000000

# %%
uncor.sim.describe()
# Out:
#            hhidpn  insim       jprob  rexpret_sim  sexpret_sim   leisure_m  \
# count  464.000000  464.0  464.000000   464.000000   464.000000  464.000000
# mean   303.915948    1.0    0.088362    65.646552    63.900862   -0.079050
# std    174.229335    0.0    0.284127     4.561089     2.685631    2.046344
# min      1.000000    1.0    0.000000    54.000000    58.000000   -4.385564
# 25%    155.750000    1.0    0.000000    62.000000    62.000000   -1.759388
# 50%    300.500000    1.0    0.000000    65.000000    64.000000   -0.070166
# 75%    454.250000    1.0    0.000000    70.000000    65.000000    1.504744
# max    604.000000    1.0    1.000000    80.000000    80.000000    5.769034
#
#         leisure_f   rage    rcollege      hwho_m  ...     rhlth62     shlth62  \
# count  464.000000  464.0  464.000000  464.000000  ...  464.000000  464.000000
# mean     0.059861    0.0    0.441810    0.538793  ...    0.400431    0.395948
# std      1.104717    0.0    0.497139    0.499031  ...    0.277485    0.265845
# min     -2.491890    0.0    0.000000    0.000000  ...    0.000000    0.000000
# 25%     -0.689411    0.0    0.000000    0.000000  ...    0.200000    0.200000
# 50%      0.045275    0.0    0.000000    1.000000  ...    0.400000    0.400000
# 75%      0.794922    0.0    1.000000    1.000000  ...    0.500000    0.500000
# max      2.778845    0.0    1.000000    1.000000  ...    1.000000    1.000000
#
#           rliv75r     sliv75r       rwage       swage      rhours      shours  \
# count  464.000000  464.000000  464.000000  464.000000  464.000000  464.000000
# mean     0.962090    0.912592   32.615540   25.620789   42.728448   35.831897
# std      0.322436    0.245628   35.582619   60.577724   10.666330   12.125414
# min      0.137999    0.062038    0.000000    0.000000    2.000000    1.000000
# 25%      0.720568    0.744456   16.347501   12.967500   40.000000   30.000000
# 50%      1.012476    0.968663   25.092495   18.000000   40.000000   40.000000
# 75%      1.175370    1.065559   36.758401   27.415630   50.000000   40.000000
# max      1.491040    1.291550  365.000000  916.666687   80.000000   75.000000
#
#            rexpret      sexpret
# count   200.000000   257.000000
# mean   2019.150000  2019.669261
# std       5.325345     5.157249
# min    2010.000000  2010.000000
# 25%    2015.000000  2016.000000
# 50%    2019.000000  2019.000000
# 75%    2022.000000  2023.000000
# max    2040.000000  2034.000000
#
# [8 rows x 147 columns]

# %% [markdown]
# ### Model without Survival Risk

# %%
nosurv = sp('nosurv')
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F

# %%
nosurv.chgoption('isurvival','F')
nosurv.chgoption('idiscount','T')
nosurv.chgoption('iload','T')
# Out:
# changed item  isurvival  with value T  to  F  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  iload  with value F  to  T  ...

# %%
nosurv.estimate()
nosurv.loglike
# Out:
# -2818.1201541091705

# %%
nosurv.params
# Out:
#                                       par                       se
# alpha_c           5.7958652799303997E-002  1.8685554827549921E-002
# alpha_lm_cons         -1.5569987590147922      0.44535641769995388
# alpha_lm_age          0.39753760263498739  6.3776622072959824E-002
# alpha_lm_hlim          1.3339024286783567      0.52873262866376036
# alpha_lm_college      0.18760670744300811      0.26594818545283194
# alpha_lm_male         0.14618847534384624      0.30973714577415246
# alpha_lm_job          0.12591210504570730      0.31752770980325301
# alpha_lf               0.0000000000000000       0.0000000000000000
# alpha_lm_lf           0.10555124141777014  1.9629024191582582E-002
# beta_c            6.7626204292322953E-002  2.5586113180907963E-002
# beta_lf_cons         -0.68142352848219689      0.33387612554309731
# beta_lf_age           0.44134349287081281  8.1730219005907323E-002
# beta_lf_hlim           1.2825212834407886      0.47505905240024066
# beta_lf_college      -0.15842646650085299      0.22228177776091346
# beta_lf_male          0.90446234280815496      0.32953728068699450
# beta_lf_job          -0.19153923142001752      0.24125758837796857
# beta_lm                0.0000000000000000       0.0000000000000000
# beta_lm_lf        7.3959811022378724E-002  1.9623795011750111E-002
# mu                1.3839352810088648E-002      0.32614804001808045
# wageratio             0.46015793194268823      0.29602323761234522
# log_rho_m         3.0346627080168994E-002  1.0381723814496506E-002
# log_rho_f         1.6698039149939278E-002  1.2432209550959795E-002
# tau_m_0               -3.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# tau_f_0               -3.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_sig_m              0.0000000000000000       0.0000000000000000
# log_sig_f              0.0000000000000000       0.0000000000000000
# L_nm_nm                2.5519577497265362      0.31067014154652989
# L_nf_nm                1.8030348365079214      0.27670336315903843
# L_nf_nf               0.18435479618208908      0.35154889486972107
# LJ_nm_nm               0.0000000000000000       0.0000000000000000
# LJ_nf_nm               0.0000000000000000       0.0000000000000000
# LJ_nf_nf               0.0000000000000000       0.0000000000000000
# scale_m                1.0000000000000000       0.0000000000000000
# scale_f                1.0000000000000000       0.0000000000000000
# scale_h                1.0000000000000000       0.0000000000000000

# %%
nosurv.sim.describe()
# Out:
#            hhidpn  insim       jprob  rexpret_sim  sexpret_sim   leisure_m  \
# count  464.000000  464.0  464.000000   464.000000   464.000000  464.000000
# mean   303.915948    1.0    0.135776    65.659483    63.698276   -0.000342
# std    174.229335    0.0    0.342920     4.757215     3.162195    2.121254
# min      1.000000    1.0    0.000000    54.000000    55.000000   -4.258207
# 25%    155.750000    1.0    0.000000    62.000000    62.000000   -1.785333
# 50%    300.500000    1.0    0.000000    65.000000    63.500000   -0.073968
# 75%    454.250000    1.0    0.000000    70.000000    66.000000    1.709326
# max    604.000000    1.0    1.000000    80.000000    80.000000    7.042243
#
#         leisure_f   rage    rcollege      hwho_m  ...     rhlth62     shlth62  \
# count  464.000000  464.0  464.000000  464.000000  ...  464.000000  464.000000
# mean     0.001493    0.0    0.441810    0.538793  ...    0.400431    0.395948
# std      1.508041    0.0    0.497139    0.499031  ...    0.277485    0.265845
# min     -3.060087    0.0    0.000000    0.000000  ...    0.000000    0.000000
# 25%     -1.244203    0.0    0.000000    0.000000  ...    0.200000    0.200000
# 50%     -0.073540    0.0    0.000000    1.000000  ...    0.400000    0.400000
# 75%      1.216572    0.0    1.000000    1.000000  ...    0.500000    0.500000
# max      5.010234    0.0    1.000000    1.000000  ...    1.000000    1.000000
#
#           rliv75r     sliv75r       rwage       swage      rhours      shours  \
# count  464.000000  464.000000  464.000000  464.000000  464.000000  464.000000
# mean     0.962090    0.912592   32.615540   25.620789   42.728448   35.831897
# std      0.322436    0.245628   35.582619   60.577724   10.666330   12.125414
# min      0.137999    0.062038    0.000000    0.000000    2.000000    1.000000
# 25%      0.720568    0.744456   16.347501   12.967500   40.000000   30.000000
# 50%      1.012476    0.968663   25.092495   18.000000   40.000000   40.000000
# 75%      1.175370    1.065559   36.758401   27.415630   50.000000   40.000000
# max      1.491040    1.291550  365.000000  916.666687   80.000000   75.000000
#
#            rexpret      sexpret
# count   200.000000   257.000000
# mean   2019.150000  2019.669261
# std       5.325345     5.157249
# min    2010.000000  2010.000000
# 25%    2015.000000  2016.000000
# 50%    2019.000000  2019.000000
# 75%    2022.000000  2023.000000
# max    2040.000000  2034.000000
#
# [8 rows x 147 columns]

# %% [markdown]
# ### Model without Complementarity

# %%
nocomp = sp('nocomp')
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F

# %%
nocomp.chgoption('idiscount','T')
nocomp.chgoption('icomplement','F')
nocomp.chgoption('iload','T')
# Out:
# changed item  idiscount  with value F  to  T  ...
# changed item  icomplement  with value T  to  F  ...
# changed item  iload  with value F  to  T  ...

# %%
nocomp.estimate()

# %%
nocomp.loglike
# Out:
# -2855.766144666341

# %%
nocomp.params
# Out:
#                                        par                       se
# alpha_c            6.7639537548317807E-002  2.1113570002769633E-002
# alpha_lm_cons          -1.2175380683809069      0.40081739779548564
# alpha_lm_age           0.45508516501726465  6.7790689658967229E-002
# alpha_lm_hlim           1.3604465625575779      0.52279719751829834
# alpha_lm_college   9.3970552027401941E-002      0.25667621470127633
# alpha_lm_male          0.54237031624880516      0.30396525640205219
# alpha_lm_job           0.12302557866238828      0.30474871012115412
# alpha_lf                0.0000000000000000       0.0000000000000000
# alpha_lm_lf             0.0000000000000000       0.0000000000000000
# beta_c             6.4124414126491711E-002  2.0745579291347249E-002
# beta_lf_cons          -0.43337542174240101      0.29744930057528901
# beta_lf_age            0.45713627952133379  8.0752421673224842E-002
# beta_lf_hlim            1.2412571212323149      0.44742021495210654
# beta_lf_college       -0.18991085313111664      0.21077753345794270
# beta_lf_male            1.1697842810177086      0.32331419931278021
# beta_lf_job           -0.15210110338346727      0.22640270602902904
# beta_lm                 0.0000000000000000       0.0000000000000000
# beta_lm_lf              0.0000000000000000       0.0000000000000000
# mu                -6.3651768288679328E-002      0.32042369378953861
# wageratio              0.53293054513688065      0.29007819736612295
# log_rho_m          4.4068695203806268E-002  1.1749307704111261E-002
# log_rho_f          2.9375617823842227E-002  1.2281422894165766E-002
# tau_m_0                -3.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# tau_f_0                -3.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_sig_m               0.0000000000000000       0.0000000000000000
# log_sig_f               0.0000000000000000       0.0000000000000000
# L_nm_nm                 2.4621534776489193      0.33738100208387750
# L_nf_nm                 1.7112486331039205      0.26206571184990640
# L_nf_nf                0.15827445315196600      0.33799330592924859
# LJ_nm_nm                0.0000000000000000       0.0000000000000000
# LJ_nf_nm                0.0000000000000000       0.0000000000000000
# LJ_nf_nf                0.0000000000000000       0.0000000000000000
# scale_m                 1.0000000000000000       0.0000000000000000
# scale_f                 1.0000000000000000       0.0000000000000000
# scale_h                 1.0000000000000000       0.0000000000000000

# %%
nocomp.sim.describe()
# Out:
#            hhidpn  insim       jprob  rexpret_sim  sexpret_sim   leisure_m  \
# count  464.000000  464.0  464.000000   464.000000   464.000000  464.000000
# mean   303.915948    1.0    0.118534    65.788793    64.478448   -0.006188
# std    174.229335    0.0    0.323589     4.161767     2.939191    2.042025
# min      1.000000    1.0    0.000000    57.000000    56.000000   -4.148567
# 25%    155.750000    1.0    0.000000    62.000000    62.000000   -1.690494
# 50%    300.500000    1.0    0.000000    66.000000    65.000000   -0.080165
# 75%    454.250000    1.0    0.000000    69.000000    67.000000    1.687002
# max    604.000000    1.0    1.000000    80.000000    79.000000    5.436133
#
#         leisure_f   rage    rcollege      hwho_m  ...     rhlth62     shlth62  \
# count  464.000000  464.0  464.000000  464.000000  ...  464.000000  464.000000
# mean    -0.002614    0.0    0.441810    0.538793  ...    0.400431    0.395948
# std      1.427059    0.0    0.497139    0.499031  ...    0.277485    0.265845
# min     -2.878053    0.0    0.000000    0.000000  ...    0.000000    0.000000
# 25%     -1.162273    0.0    0.000000    0.000000  ...    0.200000    0.200000
# 50%     -0.075612    0.0    0.000000    1.000000  ...    0.400000    0.400000
# 75%      1.162104    0.0    1.000000    1.000000  ...    0.500000    0.500000
# max      3.830775    0.0    1.000000    1.000000  ...    1.000000    1.000000
#
#           rliv75r     sliv75r       rwage       swage      rhours      shours  \
# count  464.000000  464.000000  464.000000  464.000000  464.000000  464.000000
# mean     0.962090    0.912592   32.615540   25.620789   42.728448   35.831897
# std      0.322436    0.245628   35.582619   60.577724   10.666330   12.125414
# min      0.137999    0.062038    0.000000    0.000000    2.000000    1.000000
# 25%      0.720568    0.744456   16.347501   12.967500   40.000000   30.000000
# 50%      1.012476    0.968663   25.092495   18.000000   40.000000   40.000000
# 75%      1.175370    1.065559   36.758401   27.415630   50.000000   40.000000
# max      1.491040    1.291550  365.000000  916.666687   80.000000   75.000000
#
#            rexpret      sexpret
# count   200.000000   257.000000
# mean   2019.150000  2019.669261
# std       5.325345     5.157249
# min    2010.000000  2010.000000
# 25%    2015.000000  2016.000000
# 50%    2019.000000  2019.000000
# 75%    2022.000000  2023.000000
# max    2040.000000  2034.000000
#
# [8 rows x 147 columns]

# %% [markdown]
# ### Unitary Model

# %%
unitary = sp('unitary')
unitary.chgoption('iunitary','T')
unitary.chgoption('idiscount','T')
unitary.chgoption('iload','T')
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F
# changed item  iunitary  with value F  to  T  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  iload  with value F  to  T  ...

# %%
unitary.estimate()
unitary.loglike
# Out:
# -2821.128180156101

# %%
unitary.params
# Out:
#                                       par                       se
# alpha_c               0.15199361896534705  3.6541583401715698E-002
# alpha_lm_cons         -1.6341964334141730      0.47936716906678711
# alpha_lm_age          0.44016661067449575  6.5701813700773673E-002
# alpha_lm_hlim          1.6023827977621241      0.58007315550744154
# alpha_lm_college      0.18900628807877082      0.29523775052637496
# alpha_lm_male         0.17226466946000216      0.35322161044758132
# alpha_lm_job      3.1154213416701361E-002      0.35140871342002905
# alpha_lf               0.0000000000000000       0.0000000000000000
# alpha_lm_lf           0.13169791948179960  2.2230384219873233E-002
# beta_c                0.11652535388926551  3.7506375455204487E-002
# beta_lf_cons         -0.76174285094862715      0.35434826501939920
# beta_lf_age           0.47575565520289326  8.7290754356661296E-002
# beta_lf_hlim           1.4001238402192433      0.50244844529846489
# beta_lf_college      -0.18983541940286650      0.24038668791425255
# beta_lf_male          0.95487202372298385      0.35745868975947703
# beta_lf_job          -0.19987394577203199      0.25974508727789586
# beta_lm                0.0000000000000000       0.0000000000000000
# beta_lm_lf        8.3459803372934502E-002  2.2067100350811365E-002
# mu                5.4181446262807478E-002      0.31435337576617767
# wageratio              0.0000000000000000       0.0000000000000000
# log_rho_m         3.0486616915977666E-002  9.7782633007668981E-003
# log_rho_f         1.7538177882464642E-002  1.2422180140016835E-002
# tau_m_0               -3.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# tau_f_0               -3.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_sig_m              0.0000000000000000       0.0000000000000000
# log_sig_f              0.0000000000000000       0.0000000000000000
# L_nm_nm                2.8183128121816892      0.33263123534728450
# L_nf_nm                1.9344794959029663      0.29592600840307332
# L_nf_nf               0.19506885980693248      0.38805249147840737
# LJ_nm_nm               0.0000000000000000       0.0000000000000000
# LJ_nf_nm               0.0000000000000000       0.0000000000000000
# LJ_nf_nf               0.0000000000000000       0.0000000000000000
# scale_m                1.0000000000000000       0.0000000000000000
# scale_f                1.0000000000000000       0.0000000000000000
# scale_h                1.0000000000000000       0.0000000000000000

# %%
unitary.sim.describe()
# Out:
#            hhidpn  insim       jprob  rexpret_sim  sexpret_sim   leisure_m  \
# count  464.000000  464.0  464.000000   464.000000   464.000000  464.000000
# mean   303.915948    1.0    0.127155    65.635776    63.903017   -0.000708
# std    174.229335    0.0    0.333506     4.632369     3.098329    2.336054
# min      1.000000    1.0    0.000000    55.000000    55.000000   -4.760325
# 25%    155.750000    1.0    0.000000    62.000000    62.000000   -1.966034
# 50%    300.500000    1.0    0.000000    65.000000    64.000000   -0.073442
# 75%    454.250000    1.0    0.000000    69.000000    66.000000    1.902407
# max    604.000000    1.0    1.000000    80.000000    78.000000    7.353905
#
#         leisure_f   rage    rcollege      hwho_m  ...     rhlth62     shlth62  \
# count  464.000000  464.0  464.000000  464.000000  ...  464.000000  464.000000
# mean     0.001403    0.0    0.441810    0.538793  ...    0.400431    0.395948
# std      1.613655    0.0    0.497139    0.499031  ...    0.277485    0.265845
# min     -3.293885    0.0    0.000000    0.000000  ...    0.000000    0.000000
# 25%     -1.348246    0.0    0.000000    0.000000  ...    0.200000    0.200000
# 50%     -0.055092    0.0    0.000000    1.000000  ...    0.400000    0.400000
# 75%      1.310819    0.0    1.000000    1.000000  ...    0.500000    0.500000
# max      5.092399    0.0    1.000000    1.000000  ...    1.000000    1.000000
#
#           rliv75r     sliv75r       rwage       swage      rhours      shours  \
# count  464.000000  464.000000  464.000000  464.000000  464.000000  464.000000
# mean     0.962090    0.912592   32.615540   25.620789   42.728448   35.831897
# std      0.322436    0.245628   35.582619   60.577724   10.666330   12.125414
# min      0.137999    0.062038    0.000000    0.000000    2.000000    1.000000
# 25%      0.720568    0.744456   16.347501   12.967500   40.000000   30.000000
# 50%      1.012476    0.968663   25.092495   18.000000   40.000000   40.000000
# 75%      1.175370    1.065559   36.758401   27.415630   50.000000   40.000000
# max      1.491040    1.291550  365.000000  916.666687   80.000000   75.000000
#
#            rexpret      sexpret
# count   200.000000   257.000000
# mean   2019.150000  2019.669261
# std       5.325345     5.157249
# min    2010.000000  2010.000000
# 25%    2015.000000  2016.000000
# 50%    2019.000000  2019.000000
# 75%    2022.000000  2023.000000
# max    2040.000000  2034.000000
#
# [8 rows x 147 columns]

# %% [markdown]
# ### Table with LR Tests

# %%
import pandas as pd
data = [disc.loglike,base.loglike,uncor.loglike,nocomp.loglike,unitary.loglike]
lr = [0]
for i in range(1,len(data)):
    lr.append(-2.0*(data[i]-data[0]))
names = ['Baseline','Fixed Discount Rates (2)','No Correlation UH (1)','No Complementarity (2)','Unitary (1)']
table = pd.DataFrame(data=list(zip(data,lr)),index=names,columns=['Loglikehood Value','LR Statistic'])
def f(x):
    return '{:1.3f}'.format(x)
with open('../tex/tables/lrtests.tex','w') as tf:
    tf.write(table.to_latex(formatters=[f,f]))
table
# Out:
#                           Loglikehood Value  LR Statistic
# Baseline                       -2818.345096      0.000000
# Fixed Discount Rates (2)       -2821.767581      6.844971
# No Correlation UH (1)          -2899.353096    162.016000
# No Complementarity (2)         -2855.766145     74.842097
# Unitary (1)                    -2821.128180      5.566168

# %% [markdown]
# Critical values at 5% for these tests:

# %%
from scipy.stats import chi2
[chi2(1).ppf(0.95),chi2(2).ppf(0.95)]
# Out:
# [3.841458820694124, 5.991464547107979]

# %% [markdown]
# ## Correlation with Expected Retirement in HRS

# %%
disc.sim['rexpret'] = disc.sim['rage_mod'] + (disc.sim['rexpret']-2011)
disc.sim['sexpret'] = disc.sim['sage_mod'] + (disc.sim['sexpret']-2011)

# %%
disc.sim[['rexpret','sexpret']].describe()
# Out:
#           rexpret     sexpret
# count  200.000000  257.000000
# mean    64.870000   64.459144
# std      4.203743    4.221328
# min     54.000000   54.000000
# 25%     62.000000   62.000000
# 50%     65.000000   64.000000
# 75%     68.000000   66.000000
# max     84.000000   80.000000

# %% [markdown]
# Correlations with simulated expected retirement age

# %%
print('Males   : ',disc.sim[['rexpret','rexpret_sim']].corr())
print('Females : ',disc.sim[['sexpret','sexpret_sim']].corr())
# Out:
# Males   :                rexpret  rexpret_sim
# rexpret      1.000000     0.208299
# rexpret_sim  0.208299     1.000000
# Females :                sexpret  sexpret_sim
# sexpret      1.000000     0.245102
# sexpret_sim  0.245102     1.000000

# %% [markdown]
# We will do a figure to check correlation

# %%
from scipy.stats import linregress
data = disc.sim[['rexpret_sim','rexpret']].dropna()
x = data['rexpret_sim']
y = data['rexpret']
slope, intercept, r_value, p_value, std_err = linregress(x,y)
line = slope*x+intercept
plt.figure()
plt.scatter(x,y,label='')
plt.plot(x, line, 'r', label='y={:.2f}x+{:.2f}: $R^2$={:.2f}'.format(slope,intercept,r_value))
plt.xlabel('expected retirement age (Model)')
plt.ylabel('expected retirement age (HRS)')
plt.legend(loc=4)
plt.savefig('../tex/figures/match_males.eps')
plt.show()

# %%
from scipy.stats import linregress
data = disc.sim[['sexpret_sim','sexpret']].dropna()
x = data['sexpret_sim']
y = data['sexpret']
slope, intercept, r_value, p_value, std_err = linregress(x,y)
line = slope*x+intercept
plt.figure()
plt.scatter(x,y,label='')
plt.plot(x, line, 'r', label='y={:.2f}x+{:.2f}: $R^2$={:.2f}'.format(slope,intercept,r_value))
plt.xlabel('expected retirement age (Model)')
plt.ylabel('expected retirement age (HRS)')
plt.legend(loc=4)
plt.savefig('../tex/figures/match_females.eps')
plt.show()

# %% [markdown]
# ## Distribution of Retirement Ages

# %%
# %matplotlib inline
from scipy.stats import gaussian_kde
from numba import jit
import numpy as np
x = disc.sim['rexpret_sim'].tolist()
y = disc.sim['sexpret_sim'].tolist()
print(disc.sim[['rexpret_sim','sexpret_sim']].describe())
print('correlation : ', disc.sim[['rexpret_sim','sexpret_sim']].corr())
X, Y = np.mgrid[60:69:10j, 60:69:10j]
positions = np.vstack([X.ravel(), Y.ravel()])
values = np.vstack([x, y])
kernel = gaussian_kde(values)
Z = np.reshape(kernel(positions).T, X.shape)
plt.figure()
plt.contour(X,Y,Z)
plt.xlabel('Expected Retirement Age Husband')
plt.ylabel('Expected Retirement Age Wife')
plt.savefig('../tex/figures/retages.eps')
# Out:
#        rexpret_sim  sexpret_sim
# count   464.000000   464.000000
# mean     65.730603    63.831897
# std       4.676887     3.127557
# min      55.000000    54.000000
# 25%      62.000000    62.000000
# 50%      65.000000    64.000000
# 75%      70.000000    66.000000
# max      80.000000    80.000000
# correlation :               rexpret_sim  sexpret_sim
# rexpret_sim     1.000000     0.741241
# sexpret_sim     0.741241     1.000000

# %%
disc.sim['distance_m'] = disc.sim['rexpret_sim'] - disc.sim['rage_mod']
disc.sim['distance_f'] = disc.sim['sexpret_sim'] - disc.sim['sage_mod']
print(disc.sim[['distance_m','distance_f']].describe())
print('correlation: ', disc.sim[['distance_m','distance_f']].corr())

# %matplotlib inline
from scipy.stats import gaussian_kde
from numba import jit
import numpy as np
x = disc.sim['distance_m'].tolist()
y = disc.sim['distance_f'].tolist()

X, Y = np.mgrid[0:20:20j, 0:20:20j]
positions = np.vstack([X.ravel(), Y.ravel()])
values = np.vstack([x, y])
kernel = gaussian_kde(values)
Z = np.reshape(kernel(positions).T, X.shape)
plt.figure()
plt.contour(X,Y,Z)
xx = np.linspace(0,20,20)
plt.fill_between(xx, xx-1, xx+1, color='grey', alpha='0.1')
plt.xlim([0,20])
plt.ylim([0,20])
plt.xlabel('Expected Distance (yrs) to Retirement Husband')
plt.ylabel('Expected Distance (yrs) to Retirement Wife')
plt.savefig('../tex/figures/distances.eps',dpi=600)
# Out:
#        distance_m  distance_f
# count  464.000000  464.000000
# mean     9.094828    8.170259
# std      5.647650    4.579405
# min      0.000000    0.000000
# 25%      5.000000    5.000000
# 50%      9.000000    8.000000
# 75%     13.000000   11.000000
# max     23.000000   23.000000
# correlation:              distance_m  distance_f
# distance_m    1.000000    0.766253
# distance_f    0.766253    1.000000

# %% [markdown]
# ## Joint Retirement

# %% [markdown]
# We will now re-rerun the discount model (baseline) with three scenarios: reshuffling heterogeneity, reshuffling wages and shutting down complementarity.

# %%
wages = sp('discount')
wages.chgoption('iload','T')
wages.chgoption('idiscount','T')
wages.chgoption('ishufwages','T')
wages.estimate()
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F
# changed item  iload  with value F  to  T  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  ishufwages  with value F  to  T  ...

# %%
heter = sp('discount')
heter.chgoption('iload','T')
heter.chgoption('idiscount','T')
heter.chgoption('ishufheter','T')
heter.estimate()
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F
# changed item  iload  with value F  to  T  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  ishufheter  with value F  to  T  ...

# %%
comp = sp('discount')
comp.chgoption('iload','T')
comp.chgoption('idiscount','T')
comp.chgoption('iblockcomp','T')
comp.estimate()
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F
# changed item  iload  with value F  to  T  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  iblockcomp  with value F  to  T  ...

# %%
specs = [disc,wages,heter,comp]
names =  ['Baseline','Shuffling Wages','Shuffling UH','No Complementarity']
data = []
plt.figure()
for i,s in enumerate(specs):
    s.sim['distance_m'] = s.sim['rexpret_sim'] - s.sim['rage_mod']
    s.sim['distance_f'] = s.sim['sexpret_sim'] - s.sim['sage_mod']
    s.sim['joint'] = np.abs(s.sim['distance_m'] - s.sim['distance_f'])<=1.0
    s.sim['joint_yrs'] = s.sim['distance_m'] - s.sim['distance_f']
    x = s.sim['joint_yrs'].values
    x.sort()
    ff = gaussian_kde(x)
    plt.plot(x,ff(x),label=names[i])
    data.append([s.sim['rexpret_sim'].mean(),s.sim['sexpret_sim'].mean(),s.sim['joint'].mean()])
table = pd.DataFrame(data=data,index=names,columns=['Ret Age Males','Ret Age Females','Fraction Joint'])  
def f(x):
    return '{:1.3f}'.format(x)
with open('../tex/tables/joint.tex','w') as tf:
    tf.write(table.to_latex(formatters=[f,f,f]))
plt.legend(loc=2)
plt.xlabel('difference in distance to retirement')
plt.ylabel('density')
plt.xlim([-15,15])
plt.savefig('../tex/figures/compare_distances.eps')
plt.show()
table
# Out:
#                     Ret Age Males  Ret Age Females  Fraction Joint
# Baseline                65.730603        63.831897        0.336207
# Shuffling Wages         65.637931        63.801724        0.366379
# Shuffling UH            65.765086        63.892241        0.176724
# No Complementarity      66.142241        64.467672        0.303879

# %%
# %matplotlib inline
from scipy.stats import gaussian_kde
from numba import jit
import numpy as np
x = comp.sim['distance_m'].tolist()
y = comp.sim['distance_f'].tolist()

X, Y = np.mgrid[0:20:20j, 0:20:20j]
positions = np.vstack([X.ravel(), Y.ravel()])
values = np.vstack([x, y])
kernel = gaussian_kde(values)
Z = np.reshape(kernel(positions).T, X.shape)
plt.figure()
plt.contour(X,Y,Z)
xx = np.linspace(0,20,20)
plt.fill_between(xx, xx-1, xx+1, color='grey', alpha='0.1')
plt.xlim([0,20])
plt.ylim([0,20])
plt.xlabel('Expected Distance (yrs) to Retirement Husband')
plt.ylabel('Expected Distance (yrs) to Retirement Wife')
plt.savefig('../tex/figures/distances_nocomp.eps',dpi=600)

# %%
disc.sim['agediff'] = disc.sim['rage_mod']- disc.sim['sage_mod']
print(comp.sim[['distance_m','distance_f']].describe())
print(disc.sim[['distance_m','distance_f']].describe())
# Out:
#        distance_m  distance_f
# count  464.000000  464.000000
# mean     9.506466    8.806034
# std      5.702483    4.648450
# min      0.000000    0.000000
# 25%      5.000000    5.000000
# 50%     10.000000    8.500000
# 75%     13.000000   12.000000
# max     23.000000   23.000000
#        distance_m  distance_f
# count  464.000000  464.000000
# mean     9.094828    8.170259
# std      5.647650    4.579405
# min      0.000000    0.000000
# 25%      5.000000    5.000000
# 50%      9.000000    8.000000
# 75%     13.000000   11.000000
# max     23.000000   23.000000

# %% [markdown]
# # Policy Simulation

# %% [markdown]
# Finally, we have to check what happens when we do policy simulations. We will do policy simulations over two parameters, the ARF (actuarial reduction factor) and the generosity of the pension (replacement rate).

# %%
arf = [0,0.09]
drc = [0,0.11]
rep = [0.4,0.8]
factors = zip(arf,drc)
experiments = [disc]
for a,d in factors:
    this = sp('discount')
    this.chgoption('iload','T')
    this.chgoption('idiscount','T')
    this.chgoption('arf',a)
    this.chgoption('drc',d)
    this.estimate()
    this.sim['distance_m'] = this.sim['rexpret_sim'] - this.sim['rage_mod']
    this.sim['distance_f'] = this.sim['sexpret_sim'] - this.sim['sage_mod']
    this.sim['joint'] = np.abs(this.sim['distance_m'] - this.sim['distance_f'])<=1.0    
    experiments.append(this)
for r in rep:
    this = sp('discount')
    this.chgoption('iload','T')
    this.chgoption('idiscount','T')
    this.chgoption('reprate',r)
    this.estimate()
    this.sim['distance_m'] = this.sim['rexpret_sim'] - this.sim['rage_mod']
    this.sim['distance_f'] = this.sim['sexpret_sim'] - this.sim['sage_mod']
    this.sim['joint'] = np.abs(this.sim['distance_m'] - this.sim['distance_f'])<=1.0    
    experiments.append(this)
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F
# changed item  iload  with value F  to  T  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  arf  with value 0.06  to  0  ...
# changed item  drc  with value 0.08  to  0  ...
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F
# changed item  iload  with value F  to  T  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  arf  with value 0.06  to  0.09  ...
# changed item  drc  with value 0.08  to  0.11  ...
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F
# changed item  iload  with value F  to  T  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  reprate  with value 0.6  to  0.4  ...
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F
# changed item  iload  with value F  to  T  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  reprate  with value 0.6  to  0.8  ...

# %%
data = [[e.sim['rexpret_sim'].mean(),e.sim['sexpret_sim'].mean(),e.sim['joint'].mean()] for e in experiments]
names = ['Baseline','No Penalty','High Penalty','Low Generosity','High Generosity']
table = pd.DataFrame(data=data,columns=['Ret Age Males','Ret Age Females','Fraction Retiring Jointly'],index=names)
print(table)
def f(x):
    return '{:1.3f}'.format(x)
with open('../tex/tables/policy.tex','w') as tf:
    tf.write(table.to_latex(formatters=[f,f,f]))
# Out:
#                  Ret Age Males  Ret Age Females  Fraction Retiring Jointly
# Baseline             65.730603        63.831897                   0.336207
# No Penalty           63.760776        62.243534                   0.435345
# High Penalty         66.480603        64.398707                   0.275862
# Low Generosity       66.157328        64.092672                   0.267241
# High Generosity      65.452586        63.603448                   0.362069

# %% [markdown]
# ## Testing fixed correlation coefficients

# %%
listofrho = np.linspace(0,1.1,12)
listofrho[listofrho==1.] = 0.995
listofrho[listofrho==1.1] = 0.9999


#listofrho = [0,0.1,0.25,0.5,0.75,0.9]

# %%
# %matplotlib inline
from scipy.stats import gaussian_kde
from numba import jit
import numpy as np
import copy as cp

fixed = sp('fixcorr')
fixed.chgoption('idiscount','T')
fixed.chgoption('iload','T')
fixed.chgoption('ifixcorr','T')
fixed.chgoption('icomplement','F')

lsloglik = []
#lsparams = []

dctresults = {}

for rho in listofrho:    
    print(rho)
    fixed.chgoption('dfixrho',rho)
    fixed.estimate()
    dctresults[rho] = cp.copy(fixed)
    lsloglik.append(fixed.loglike)
    #lsparams.append(fixed.params)
    
    #Graph of the joint distance
    fixed.sim['distance_m'] = fixed.sim['rexpret_sim'] - fixed.sim['rage_mod']
    fixed.sim['distance_f'] = fixed.sim['sexpret_sim'] - fixed.sim['sage_mod']
    fixed.sim['joint'] = np.abs(fixed.sim['distance_m'] - fixed.sim['distance_f'])<=1.0  
    x = fixed.sim['distance_m'].tolist()
    y = fixed.sim['distance_f'].tolist()

    X, Y = np.mgrid[0:20:20j, 0:20:20j]
    positions = np.vstack([X.ravel(), Y.ravel()])
    values = np.vstack([x, y])
    kernel = gaussian_kde(values)
    Z = np.reshape(kernel(positions).T, X.shape)
    plt.figure()
    plt.contour(X,Y,Z)
    xx = np.linspace(0,20,20)
    plt.fill_between(xx, xx-1, xx+1, color='grey', alpha='0.1')
    plt.xlim([0,20])
    plt.ylim([0,20])
    plt.xlabel('Expected Distance (yrs) to Retirement Husband')
    plt.ylabel('Expected Distance (yrs) to Retirement Wife')
    plt.savefig('../tex/figures/distances_nocomp%d.eps' %rho,dpi=600)
    plt.show()
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# ijointhetero  =  F
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F
# changed item  idiscount  with value F  to  T  ...
# changed item  iload  with value F  to  T  ...
# changed item  ifixcorr  with value F  to  T  ...
# changed item  icomplement  with value T  to  F  ...
# 0.0
# changed item  dfixrho  with value 0.5  to  0.0  ...
# 0.1
# changed item  dfixrho  with value 0.0  to  0.1  ...
# 0.2
# changed item  dfixrho  with value 0.1  to  0.2  ...
# 0.30000000000000004
# changed item  dfixrho  with value 0.2  to  0.30000000000000004  ...
# 0.4
# changed item  dfixrho  with value 0.30000000000000004  to  0.4  ...
# 0.5
# changed item  dfixrho  with value 0.4  to  0.5  ...
# 0.6000000000000001
# changed item  dfixrho  with value 0.5  to  0.6000000000000001  ...
# 0.7000000000000001
# changed item  dfixrho  with value 0.6000000000000001  to  0.7000000000000001  ...
# 0.8
# changed item  dfixrho  with value 0.7000000000000001  to  0.8  ...
# 0.9
# changed item  dfixrho  with value 0.8  to  0.9  ...
# 0.995
# changed item  dfixrho  with value 0.9  to  0.995  ...
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3265, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-52-7472a586b890>", line 21, in <module>
#     fixed.estimate()
#   File "/Users/lubis/Documents/github/joint/runtime/tools/models.py", line 53, in estimate
#     self.buff = subprocess.check_output(['./runestimation',self.scenario])
#   File "/anaconda3/lib/python3.6/subprocess.py", line 356, in check_output
#     **kwargs).stdout
#   File "/anaconda3/lib/python3.6/subprocess.py", line 425, in run
#     stdout, stderr = process.communicate(input, timeout=timeout)
#   File "/anaconda3/lib/python3.6/subprocess.py", line 850, in communicate
#     stdout = self.stdout.read()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2016, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1095, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 313, in wrapped
#     return f(*args, **kwargs)
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 347, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/anaconda3/lib/python3.6/inspect.py", line 1490, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/anaconda3/lib/python3.6/inspect.py", line 1448, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/anaconda3/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/anaconda3/lib/python3.6/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/anaconda3/lib/python3.6/site-packages/py/_vendored_packages/apipkg.py", line 195, in __getattribute__
#     return getattr(getmod(), name)
#   File "/anaconda3/lib/python3.6/site-packages/py/_vendored_packages/apipkg.py", line 179, in getmod
#     x = importobj(modpath, None)
#   File "/anaconda3/lib/python3.6/site-packages/py/_vendored_packages/apipkg.py", line 69, in importobj
#     module = __import__(modpath, None, None, ['__doc__'])
#   File "/anaconda3/lib/python3.6/site-packages/pytest.py", line 9, in <module>
#     from _pytest.config import main, UsageError, cmdline, hookspec, hookimpl
#   File "/anaconda3/lib/python3.6/site-packages/_pytest/config/__init__.py", line 18, in <module>
#     import _pytest._code
#   File "/anaconda3/lib/python3.6/site-packages/_pytest/_code/__init__.py", line 3, in <module>
#     from .code import Code  # noqa
#   File "/anaconda3/lib/python3.6/site-packages/_pytest/_code/code.py", line 8, in <module>
#     import attr
#   File "/anaconda3/lib/python3.6/site-packages/attr/__init__.py", line 5, in <module>
#     from . import converters, exceptions, filters, validators
#   File "/anaconda3/lib/python3.6/site-packages/attr/converters.py", line 7, in <module>
#     from ._make import NOTHING, Factory
#   File "/anaconda3/lib/python3.6/site-packages/attr/_make.py", line 1918, in <module>
#     class Factory(object):
#   File "/anaconda3/lib/python3.6/site-packages/attr/_make.py", line 855, in wrap
#     cache_hash,
#   File "/anaconda3/lib/python3.6/site-packages/attr/_make.py", line 471, in __init__
#     cls, these, auto_attribs, kw_only
#   File "/anaconda3/lib/python3.6/site-packages/attr/_make.py", line 380, in _transform_attrs
#     AttrsClass = _make_attr_tuple_class(cls.__name__, attr_names)
#   File "/anaconda3/lib/python3.6/site-packages/attr/_make.py", line 245, in _make_attr_tuple_class
#     eval(compile("\n".join(attr_class_template), "", "exec"), globs)
#   File "", line 1, in <module>
# KeyboardInterrupt
# ---------------------------------------------------------------------------

# %%
listofdens = []
listofx    = []

data = []
plt.figure()

for key in dctresults:
    this = dctresults[key]
    #print(this.sim.describe())
    this.sim['distance_m'] = this.sim['rexpret_sim'] - this.sim['rage_mod']
    this.sim['distance_f'] = this.sim['sexpret_sim'] - this.sim['sage_mod']
    this.sim['joint'] = np.abs(this.sim['distance_m'] - this.sim['distance_f'])<=1.0
    this.sim['joint_yrs'] = this.sim['distance_m'] - this.sim['distance_f']
    x = this.sim['joint_yrs'].values
    x.sort()
    ff = gaussian_kde(x)
    listofx.append(x)
    listofdens.append(ff(x))
    plt.plot(x,ff(x)) #,label=key)
        #data.append([this.sim['rexpret_sim'].mean(),this.sim['sexpret_sim'].mean(),this.sim['joint'].mean()])
        #table = pd.DataFrame(data=data,index=names,columns=['Ret Age Males','Ret Age Females','Fraction Joint'])  
        #def f(x):
        #    return '{:1.3f}'.format(x)
        #with open('../tex/tables/joint.tex','w') as tf:
        #    tf.write(table.to_latex(formatters=[f,f,f]))

# plt.plot(listofx,listofdens, label=dctresults.keys())

plt.legend(loc=2, labels=dctresults.keys())
plt.xlabel('difference in distance to retirement')
plt.ylabel('density')
plt.xlim([-15,15])
plt.savefig('../tex/figures/compare_distances_multiples_rho.eps')
#plt.show()
#table

plt.show()

# %%
listofjoin = []
listofval = []
for key in dctresults:
    this = dctresults[key]
    listofjoin.append(this.sim['joint'].mean())
    listofval.append(key)
    
plt.plot(listofval, listofjoin)

# %% [markdown]
# ### No complementarity, moving correlation.

# %%
comp = sp('discount')
comp.chgoption('iload','T')
comp.chgoption('idiscount','T')
#comp.chgoption('icomplement','F')
comp.chgoption('iblockcomp','T')
comp.estimate()
comp.sim.describe()

# %%
### Creating a fake scenario and escaping estimation ####
drho = 0.5

lsloglik = []
#lsparams = []

dct_new_results = {}

nocomp_varrho = cp.copy(comp)
nocomp_varrho.scenario = "nocomp_varrho"
nocomp_varrho.chgoption('inoestim','T')

for drho in listofrho:

    ## Computing the var cov matrix
    M11 = pd.to_numeric(nocomp_varrho.params['par'].loc['L_nm_nm'])
    M12 = pd.to_numeric(nocomp_varrho.params['par'].loc['L_nf_nm'])
    M22 = pd.to_numeric(nocomp_varrho.params['par'].loc['L_nf_nf'])

    M = np.array([[M11, 0],[M12,  M22]])
    varcov = np.matmul(M,M.T)

    # Maintaining var cst, changing only the correlation. 
    newvarcov = varcov
    newvarcov[0,1] = drho * (np.sqrt(varcov[0,0])*np.sqrt(varcov[1,1]))
    newvarcov[1,0] = newvarcov[0,1]

    # Writing in the table.
    newchol = np.linalg.cholesky(newvarcov)
    
    print(newchol)

    nocomp_varrho.params['par'].loc['L_nf_nm'] = newchol[1,0] 
    nocomp_varrho.params['par'].loc['L_nf_nf'] = newchol[1,1] 

    ## Dumping the table first
    nocomp_varrho.params.to_csv('../params/temp.csv', header = False, sep = '\t')
    
    # Putting the content back in memory
    f = open('../params/'+ 'temp' +'.csv')
    buff = f.read()
    f.close()
    buff = buff.split('\n')

    # Adding the two lines
    f = open('../params/parms_%s.csv'%nocomp_varrho.scenario, "w+")
    f.write(str(comp.loglike)+"\n")
    f.write('48')

    ##Rewriting the parameters
    for line in buff:
        f.write("\n" + line)

    f.close()
    nocomp_varrho.estimate()
    nocomp_varrho.sim['distance_m'] = nocomp_varrho.sim['rexpret_sim'] - nocomp_varrho.sim['rage_mod']
    nocomp_varrho.sim['distance_f'] = nocomp_varrho.sim['sexpret_sim'] - nocomp_varrho.sim['sage_mod']
    nocomp_varrho.sim['joint'] = np.abs(nocomp_varrho.sim['distance_m'] - nocomp_varrho.sim['distance_f'])<=1.0
    nocomp_varrho.sim['joint_yrs'] = nocomp_varrho.sim['distance_m'] - nocomp_varrho.sim['distance_f']
    dct_new_results[drho] = cp.copy(nocomp_varrho)

# %%
listofjoin = []
listofval = []
for key in dct_new_results:
    this = dct_new_results[key]
    listofjoin.append(this.sim['joint'].mean())
    listofval.append(key)
    
plt.plot(listofval, listofjoin)

# %%
comp.params

# %%
dct_new_results[0.995].sim['joint_num'] = dct_new_results[0.995].sim['joint']*1.0
dct_new_results[0.995].sim[['joint_yrs', 'joint_num']].groupby('joint_yrs').sum()

# %%
try:
    del dfbyage
except:
    pass

for key in dct_new_results:
    dct_new_results[key].sim['diffage'] = np.abs(dct_new_results[key].sim['rage_mod'] 
                                               - dct_new_results[key].sim['sage_mod'])
    thisdict = dct_new_results[key].sim[['diffage', 'joint']].groupby('diffage').mean()
    thisdict['rho'] = key
    
    try:
        dfbyage = dfbyage.append(thisdict)
    except:
        dfbyage = thisdict.copy()

# %%
dfbyage.pivot(columns='rho').plot()
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
dfbyage.pivot(columns='rho')
