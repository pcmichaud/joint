# %% [markdown]
# # Obtaining Estimation and Simulation Results

# %%
import os
from matplotlib import pyplot as plt
from tools import models

# %% [markdown]
# We now create a base instance of the model (constant discount rates). This is useful for starting other specifications

# %%
sp = models.sp
base = sp('ref')
base.chgoption('iload','T')
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F
# changed item  iload  with value F  to  T  ...

# %% [markdown]
# We estimate parameters and simulate data post estimation

# %%
base.estimate()
base.loglike
# Out:
# -2846.7196966521715

# %%
base.params
# Out:
#                                        par                       se
# alpha_c                0.66593328529437712  5.6127812468679074E-002
# alpha_lm_cons          -3.0018247386777750      0.90469015371604822
# alpha_lm_age           0.69667654262963818      0.11058745895534414
# alpha_lm_hlim           2.9460120925180329       1.0227802804697588
# alpha_lm_college       0.35898226737447986      0.55539519583838670
# alpha_lm_male          0.44060602843304675      0.68713944131178784
# alpha_lm_job           0.20815875516156007      0.68962870461150805
# alpha_lf                0.0000000000000000       0.0000000000000000
# alpha_lm_lf            0.30961924431040988  3.8089935635482609E-002
# beta_c                 0.42916644782729685  4.2104877792775927E-002
# beta_lf_cons           -1.0261047417155940      0.69118986031542462
# beta_lf_age            0.90625671329955204      0.12552600543469580
# beta_lf_hlim            2.5273004735748854      0.94484037275325616
# beta_lf_college       -0.44273166202345166      0.46664563813711435
# beta_lf_male            1.7529395951532170      0.64099200519331023
# beta_lf_job           -0.61254569016688187      0.51089851008457177
# beta_lm                 0.0000000000000000       0.0000000000000000
# beta_lm_lf             0.16767385613805008  3.3461774693469649E-002
# mu                 5.6901813057952813E-003      0.32765318369911883
# wageratio              0.52039989731362124      0.29420090808662785
# log_rho_m         -5.1293294387550578E-002       0.0000000000000000
# log_rho_f         -5.1293294387550578E-002       0.0000000000000000
# tau_m_0                -3.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# tau_f_0                -3.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_sig_m               0.0000000000000000       0.0000000000000000
# log_sig_f               0.0000000000000000       0.0000000000000000
# L_nm_nm                 5.1792891986005012      0.45650658740748495
# L_nf_nm                 3.7581067497894862      0.34955142488809005
# L_nf_nf                0.18958785159722200      0.80168539219104118
# scale_m                 1.0000000000000000       0.0000000000000000
# scale_f                 1.0000000000000000       0.0000000000000000
# scale_h                 1.0000000000000000       0.0000000000000000

# %% [markdown]
# Here are some stats on the simulations:

# %%
base.sim.describe()
# Out:
#            hhidpn  insim       jprob  rexpret_sim  sexpret_sim   leisure_m  \
# count  464.000000  464.0  464.000000   464.000000   464.000000  464.000000
# mean   303.915948    1.0    0.084052    65.974138    63.663793    0.094630
# std    174.229335    0.0    0.277765     4.989771     3.130548    4.308638
# min      1.000000    1.0    0.000000    54.000000    54.000000   -9.093933
# 25%    155.750000    1.0    0.000000    62.000000    62.000000   -3.402525
# 50%    300.500000    1.0    0.000000    67.000000    64.000000   -0.073440
# 75%    454.250000    1.0    0.000000    70.000000    66.000000    3.325793
# max    604.000000    1.0    1.000000    80.000000    78.000000   15.361784
#
#         leisure_f   rage    rcollege      hwho_m  ...     rhlth62     shlth62  \
# count  464.000000  464.0  464.000000  464.000000  ...  464.000000  464.000000
# mean     0.070172    0.0    0.441810    0.538793  ...    0.400431    0.395948
# std      3.133413    0.0    0.497139    0.499031  ...    0.277485    0.265845
# min     -6.580638    0.0    0.000000    0.000000  ...    0.000000    0.000000
# 25%     -2.461075    0.0    0.000000    0.000000  ...    0.200000    0.200000
# 50%     -0.024311    0.0    0.000000    1.000000  ...    0.400000    0.400000
# 75%      2.391973    0.0    1.000000    1.000000  ...    0.500000    0.500000
# max     11.169944    0.0    1.000000    1.000000  ...    1.000000    1.000000
#
#           rliv75r     sliv75r       rwage       swage      rhours      shours  \
# count  464.000000  464.000000  464.000000  464.000000  464.000000  464.000000
# mean     0.962090    0.912592   32.615540   25.620789   42.728448   35.831897
# std      0.322436    0.245628   35.582619   60.577724   10.666330   12.125414
# min      0.137999    0.062038    0.000000    0.000000    2.000000    1.000000
# 25%      0.720568    0.744456   16.347501   12.967500   40.000000   30.000000
# 50%      1.012476    0.968663   25.092495   18.000000   40.000000   40.000000
# 75%      1.175370    1.065559   36.758401   27.415630   50.000000   40.000000
# max      1.491040    1.291550  365.000000  916.666687   80.000000   75.000000
#
#            rexpret      sexpret
# count   200.000000   257.000000
# mean   2019.150000  2019.669261
# std       5.325345     5.157249
# min    2010.000000  2010.000000
# 25%    2015.000000  2016.000000
# 50%    2019.000000  2019.000000
# 75%    2022.000000  2023.000000
# max    2040.000000  2034.000000
#
# [8 rows x 147 columns]

# %% [markdown]
# As per referee request, the same model with discount rate fixed to 1.

# %%
sp = models.sp
base = sp('ref')
base.chgoption('iload','T')
base.chgoption('ddiscount',1.0)
base.estimate()
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F
# changed item  iload  with value F  to  T  ...
# changed item  ddiscount  with value 0.95  to  1.0  ...

# %%
base.loglike
# Out:
# -2821.7676117972765

# %%
base.sim.describe()
# Out:
#            hhidpn  insim       jprob  rexpret_sim  sexpret_sim   leisure_m  \
# count  464.000000  464.0  464.000000   464.000000   464.000000  464.000000
# mean   303.915948    1.0    0.096983    65.834052    63.728448    0.029322
# std    174.229335    0.0    0.296254     4.775347     3.139584    2.917824
# min      1.000000    1.0    0.000000    54.000000    54.000000   -6.035136
# 25%    155.750000    1.0    0.000000    62.000000    62.000000   -2.404077
# 50%    300.500000    1.0    0.000000    66.000000    64.000000   -0.067106
# 75%    454.250000    1.0    0.000000    70.000000    66.000000    2.386701
# max    604.000000    1.0    1.000000    80.000000    79.000000    9.757249
#
#         leisure_f   rage    rcollege      hwho_m  ...     rhlth62     shlth62  \
# count  464.000000  464.0  464.000000  464.000000  ...  464.000000  464.000000
# mean     0.021183    0.0    0.441810    0.538793  ...    0.400431    0.395948
# std      1.941537    0.0    0.497139    0.499031  ...    0.277485    0.265845
# min     -3.989057    0.0    0.000000    0.000000  ...    0.000000    0.000000
# 25%     -1.582079    0.0    0.000000    0.000000  ...    0.200000    0.200000
# 50%     -0.032873    0.0    0.000000    1.000000  ...    0.400000    0.400000
# 75%      1.573930    0.0    1.000000    1.000000  ...    0.500000    0.500000
# max      6.496192    0.0    1.000000    1.000000  ...    1.000000    1.000000
#
#           rliv75r     sliv75r       rwage       swage      rhours      shours  \
# count  464.000000  464.000000  464.000000  464.000000  464.000000  464.000000
# mean     0.962090    0.912592   32.615540   25.620789   42.728448   35.831897
# std      0.322436    0.245628   35.582619   60.577724   10.666330   12.125414
# min      0.137999    0.062038    0.000000    0.000000    2.000000    1.000000
# 25%      0.720568    0.744456   16.347501   12.967500   40.000000   30.000000
# 50%      1.012476    0.968663   25.092495   18.000000   40.000000   40.000000
# 75%      1.175370    1.065559   36.758401   27.415630   50.000000   40.000000
# max      1.491040    1.291550  365.000000  916.666687   80.000000   75.000000
#
#            rexpret      sexpret
# count   200.000000   257.000000
# mean   2019.150000  2019.669261
# std       5.325345     5.157249
# min    2010.000000  2010.000000
# 25%    2015.000000  2016.000000
# 50%    2019.000000  2019.000000
# 75%    2022.000000  2023.000000
# max    2040.000000  2034.000000
#
# [8 rows x 147 columns]

# %% [markdown]
# We will now create a model that estimates discount rates

# %%
disc = sp('discount')
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F

# %% [markdown]
# We need to flag that we want to estimate discount rates

# %%
disc.chgoption('idiscount','T')
disc.chgoption('iload','T')
# Out:
# changed item  idiscount  with value F  to  T  ...
# changed item  iload  with value F  to  T  ...

# %% [markdown]
# We now estimate parameters

# %%
disc.estimate()
disc.loglike
# Out:
# -2818.3448710260486

# %%
disc.params
# Out:
#                                       par                       se
# alpha_c               0.15380593428005318  3.6868070834583412E-002
# alpha_lm_cons         -1.6856021139243946      0.47626280873886934
# alpha_lm_age          0.43392213241575722  6.4712415354901895E-002
# alpha_lm_hlim          1.6092263995469689      0.58107775391987182
# alpha_lm_college      0.16824652097352358      0.29411880028885923
# alpha_lm_male         0.18781546724291590      0.35008549271195999
# alpha_lm_job      9.4716912728931263E-002      0.34833558947128318
# alpha_lf               0.0000000000000000       0.0000000000000000
# alpha_lm_lf           0.13429136711986076  2.2565311932536143E-002
# beta_c                0.11484750824152970  3.6718649683564183E-002
# beta_lf_cons         -0.73834274763057295      0.35302474540791595
# beta_lf_age           0.47235256352084692  8.4960873593182162E-002
# beta_lf_hlim           1.4110365493103585      0.50161439223125737
# beta_lf_college      -0.19834066420050803      0.23843024115749559
# beta_lf_male          0.98610514381172798      0.35689690928378115
# beta_lf_job          -0.20853730107608237      0.25750718595583633
# beta_lm                0.0000000000000000       0.0000000000000000
# beta_lm_lf        8.0448724276796543E-002  2.1847336970423483E-002
# mu                1.4212237237507848E-002      0.33004662143827224
# wageratio             0.51733726539980884      0.30799187393828364
# log_rho_m         2.9899363977748762E-002  9.8539015763354932E-003
# log_rho_f         1.8250608854944731E-002  1.2313167617212607E-002
# tau_m_0               -3.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# tau_f_0               -3.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_sig_m              0.0000000000000000       0.0000000000000000
# log_sig_f              0.0000000000000000       0.0000000000000000
# L_nm_nm                2.8009322339266380      0.33089967320775432
# L_nf_nm                1.9209049685165895      0.29135905628966208
# L_nf_nf               0.19379883310906251      0.38543784414874649
# scale_m                1.0000000000000000       0.0000000000000000
# scale_f                1.0000000000000000       0.0000000000000000
# scale_h                1.0000000000000000       0.0000000000000000

# %% [markdown]
# Some stats again on types

# %%
disc.sim.describe()
# Out:
#            hhidpn  insim       jprob  rexpret_sim  sexpret_sim   leisure_m  \
# count  464.000000  464.0  464.000000   464.000000   464.000000  464.000000
# mean   303.915948    1.0    0.101293    65.728448    63.829741    0.002440
# std    174.229335    0.0    0.302042     4.670523     3.130547    2.323479
# min      1.000000    1.0    0.000000    55.000000    54.000000   -4.755254
# 25%    155.750000    1.0    0.000000    62.000000    62.000000   -1.981282
# 50%    300.500000    1.0    0.000000    65.000000    64.000000   -0.072989
# 75%    454.250000    1.0    0.000000    69.000000    66.000000    1.905007
# max    604.000000    1.0    1.000000    80.000000    80.000000    7.262445
#
#         leisure_f   rage    rcollege      hwho_m  ...     rhlth62     shlth62  \
# count  464.000000  464.0  464.000000  464.000000  ...  464.000000  464.000000
# mean     0.003617    0.0    0.441810    0.538793  ...    0.400431    0.395948
# std      1.603925    0.0    0.497139    0.499031  ...    0.277485    0.265845
# min     -3.287384    0.0    0.000000    0.000000  ...    0.000000    0.000000
# 25%     -1.329485    0.0    0.000000    0.000000  ...    0.200000    0.200000
# 50%     -0.036860    0.0    0.000000    1.000000  ...    0.400000    0.400000
# 75%      1.306675    0.0    1.000000    1.000000  ...    0.500000    0.500000
# max      5.025898    0.0    1.000000    1.000000  ...    1.000000    1.000000
#
#           rliv75r     sliv75r       rwage       swage      rhours      shours  \
# count  464.000000  464.000000  464.000000  464.000000  464.000000  464.000000
# mean     0.962090    0.912592   32.615540   25.620789   42.728448   35.831897
# std      0.322436    0.245628   35.582619   60.577724   10.666330   12.125414
# min      0.137999    0.062038    0.000000    0.000000    2.000000    1.000000
# 25%      0.720568    0.744456   16.347501   12.967500   40.000000   30.000000
# 50%      1.012476    0.968663   25.092495   18.000000   40.000000   40.000000
# 75%      1.175370    1.065559   36.758401   27.415630   50.000000   40.000000
# max      1.491040    1.291550  365.000000  916.666687   80.000000   75.000000
#
#            rexpret      sexpret
# count   200.000000   257.000000
# mean   2019.150000  2019.669261
# std       5.325345     5.157249
# min    2010.000000  2010.000000
# 25%    2015.000000  2016.000000
# 50%    2019.000000  2019.000000
# 75%    2022.000000  2023.000000
# max    2040.000000  2034.000000
#
# [8 rows x 147 columns]

# %% [markdown]
# ## Robustness of Specification

# %% [markdown]
# We will collect a few loglikelihoods to do LR tests (Table in main text). We will also present some results in the appendix for these alternative models.

# %% [markdown]
# ### Model with uncorrelated types

# %%
uncor = sp('nocorr')
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F

# %%
uncor.chgoption('icorr','F')
uncor.chgoption('idiscount','T')
uncor.chgoption('iload','T')
# Out:
# changed item  icorr  with value T  to  F  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  iload  with value F  to  T  ...

# %%
uncor.estimate()
uncor.loglike
# Out:
# -2899.3526833827486

# %%
uncor.params
# Out:
#                                        par                       se
# alpha_c                0.12745200052387740  3.0818592371887048E-002
# alpha_lm_cons          -1.5349822168549017      0.47957888390004821
# alpha_lm_age           0.39973624569234811  5.8668930196917421E-002
# alpha_lm_hlim           1.4800887932930447      0.60739998727684563
# alpha_lm_college       0.21895678955999578      0.29869984804375943
# alpha_lm_male          0.22302173780296441      0.35167730220701110
# alpha_lm_job           0.12902652085745617      0.34179435960588667
# alpha_lf                0.0000000000000000       0.0000000000000000
# alpha_lm_lf            0.11904812221755924  2.1124086028223289E-002
# beta_c             9.4188791981093978E-002  3.1459732633420084E-002
# beta_lf_cons          -0.84231934722944646      0.37787167860593923
# beta_lf_age            0.44547833780284757  8.1366808425434950E-002
# beta_lf_hlim            1.2692976452520299      0.49483484403753902
# beta_lf_college   -7.5728683765764623E-002      0.22823922512894484
# beta_lf_male           0.80688038791205030      0.33903562084357713
# beta_lf_job           -0.22030784654753802      0.26161282643386558
# beta_lm                 0.0000000000000000       0.0000000000000000
# beta_lm_lf         7.5192247788526650E-002  2.0579257903367943E-002
# mu                 9.2004691831202703E-002      0.33511966257926568
# wageratio              0.39051325950713728      0.29063987493386528
# log_rho_m          3.7762066828727639E-002  9.3437290095047480E-003
# log_rho_f          2.5824905248893616E-002  1.2145763475518800E-002
# tau_m_0                -3.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# tau_f_0                -3.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_sig_m               0.0000000000000000       0.0000000000000000
# log_sig_f               0.0000000000000000       0.0000000000000000
# L_nm_nm                 2.6894812197138265      0.32264395172567101
# L_nf_nm                 0.0000000000000000       0.0000000000000000
# L_nf_nf                 1.7607193056297787      0.27808582182138597
# scale_m                 1.0000000000000000       0.0000000000000000
# scale_f                 1.0000000000000000       0.0000000000000000
# scale_h                 1.0000000000000000       0.0000000000000000

# %%
uncor.sim.describe()
# Out:
#            hhidpn  insim       jprob  rexpret_sim  sexpret_sim   leisure_m  \
# count  464.000000  464.0  464.000000   464.000000   464.000000  464.000000
# mean   303.915948    1.0    0.088362    65.646552    63.905172   -0.079485
# std    174.229335    0.0    0.284127     4.561089     2.695420    2.043867
# min      1.000000    1.0    0.000000    54.000000    58.000000   -4.380325
# 25%    155.750000    1.0    0.000000    62.000000    62.000000   -1.757242
# 50%    300.500000    1.0    0.000000    65.000000    64.000000   -0.070085
# 75%    454.250000    1.0    0.000000    70.000000    65.000000    1.501391
# max    604.000000    1.0    1.000000    80.000000    80.000000    5.756556
#
#         leisure_f   rage    rcollege      hwho_m  ...     rhlth62     shlth62  \
# count  464.000000  464.0  464.000000  464.000000  ...  464.000000  464.000000
# mean     0.060048    0.0    0.441810    0.538793  ...    0.400431    0.395948
# std      1.103819    0.0    0.497139    0.499031  ...    0.277485    0.265845
# min     -2.489203    0.0    0.000000    0.000000  ...    0.000000    0.000000
# 25%     -0.688346    0.0    0.000000    0.000000  ...    0.200000    0.200000
# 50%      0.045337    0.0    0.000000    1.000000  ...    0.400000    0.400000
# 75%      0.794216    0.0    1.000000    1.000000  ...    0.500000    0.500000
# max      2.776467    0.0    1.000000    1.000000  ...    1.000000    1.000000
#
#           rliv75r     sliv75r       rwage       swage      rhours      shours  \
# count  464.000000  464.000000  464.000000  464.000000  464.000000  464.000000
# mean     0.962090    0.912592   32.615540   25.620789   42.728448   35.831897
# std      0.322436    0.245628   35.582619   60.577724   10.666330   12.125414
# min      0.137999    0.062038    0.000000    0.000000    2.000000    1.000000
# 25%      0.720568    0.744456   16.347501   12.967500   40.000000   30.000000
# 50%      1.012476    0.968663   25.092495   18.000000   40.000000   40.000000
# 75%      1.175370    1.065559   36.758401   27.415630   50.000000   40.000000
# max      1.491040    1.291550  365.000000  916.666687   80.000000   75.000000
#
#            rexpret      sexpret
# count   200.000000   257.000000
# mean   2019.150000  2019.669261
# std       5.325345     5.157249
# min    2010.000000  2010.000000
# 25%    2015.000000  2016.000000
# 50%    2019.000000  2019.000000
# 75%    2022.000000  2023.000000
# max    2040.000000  2034.000000
#
# [8 rows x 147 columns]

# %% [markdown]
# ### Model without Survival Risk

# %%
nosurv = sp('nosurv')
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F

# %%
nosurv.chgoption('isurvival','F')
nosurv.chgoption('idiscount','T')
nosurv.chgoption('iload','T')
# Out:
# changed item  isurvival  with value T  to  F  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  iload  with value F  to  T  ...

# %%
nosurv.estimate()
nosurv.loglike
# Out:
# -2818.1201559652686

# %%
nosurv.params
# Out:
#                                       par                       se
# alpha_c           5.7958154741898554E-002  1.8685689464979158E-002
# alpha_lm_cons         -1.5570315415399303      0.44537137282681005
# alpha_lm_age          0.39754555139763159  6.3778880233480731E-002
# alpha_lm_hlim          1.3339034355817654      0.52874157849756209
# alpha_lm_college      0.18761249202057301      0.26595589619123028
# alpha_lm_male         0.14620065740591651      0.30974519338432133
# alpha_lm_job          0.12592669379578852      0.31753694498266111
# alpha_lf               0.0000000000000000       0.0000000000000000
# alpha_lm_lf           0.10555069919287093  1.9629337389837256E-002
# beta_c            6.7625459904655641E-002  2.5585859889939267E-002
# beta_lf_cons         -0.68139547784498034      0.33386654674517696
# beta_lf_age           0.44133596305696665  8.1728426533132434E-002
# beta_lf_hlim           1.2824754989441944      0.47504509944748485
# beta_lf_college      -0.15842558020753256      0.22227614383011493
# beta_lf_male          0.90444774879513312      0.32952940634479366
# beta_lf_job          -0.19153946333666491      0.24125185315335076
# beta_lm                0.0000000000000000       0.0000000000000000
# beta_lm_lf        7.3958220932353450E-002  1.9623427342003091E-002
# mu                1.3718943865985466E-002      0.32613503719433307
# wageratio             0.46012028906810126      0.29601154571407018
# log_rho_m         3.0347069520584892E-002  1.0381821025825548E-002
# log_rho_f         1.6697716039251846E-002  1.2432251272338839E-002
# tau_m_0               -3.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# tau_f_0               -3.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_sig_m              0.0000000000000000       0.0000000000000000
# log_sig_f              0.0000000000000000       0.0000000000000000
# L_nm_nm                2.5519970437936661      0.31068223565020059
# L_nf_nm                1.8030106125317964      0.27669624772313733
# L_nf_nf               0.18434480298517494      0.35154416710972297
# scale_m                1.0000000000000000       0.0000000000000000
# scale_f                1.0000000000000000       0.0000000000000000
# scale_h                1.0000000000000000       0.0000000000000000

# %%
nosurv.sim.describe()
# Out:
#            hhidpn  insim       jprob  rexpret_sim  sexpret_sim   leisure_m  \
# count  464.000000  464.0  464.000000   464.000000   464.000000  464.000000
# mean   303.915948    1.0    0.135776    65.659483    63.698276   -0.000342
# std    174.229335    0.0    0.342920     4.757215     3.162195    2.121288
# min      1.000000    1.0    0.000000    54.000000    55.000000   -4.258279
# 25%    155.750000    1.0    0.000000    62.000000    62.000000   -1.785366
# 50%    300.500000    1.0    0.000000    65.000000    63.500000   -0.073969
# 75%    454.250000    1.0    0.000000    70.000000    66.000000    1.709351
# max    604.000000    1.0    1.000000    80.000000    80.000000    7.042340
#
#         leisure_f   rage    rcollege      hwho_m  ...     rhlth62     shlth62  \
# count  464.000000  464.0  464.000000  464.000000  ...  464.000000  464.000000
# mean     0.001492    0.0    0.441810    0.538793  ...    0.400431    0.395948
# std      1.508021    0.0    0.497139    0.499031  ...    0.277485    0.265845
# min     -3.060035    0.0    0.000000    0.000000  ...    0.000000    0.000000
# 25%     -1.244197    0.0    0.000000    0.000000  ...    0.200000    0.200000
# 50%     -0.073540    0.0    0.000000    1.000000  ...    0.400000    0.400000
# 75%      1.216555    0.0    1.000000    1.000000  ...    0.500000    0.500000
# max      5.010157    0.0    1.000000    1.000000  ...    1.000000    1.000000
#
#           rliv75r     sliv75r       rwage       swage      rhours      shours  \
# count  464.000000  464.000000  464.000000  464.000000  464.000000  464.000000
# mean     0.962090    0.912592   32.615540   25.620789   42.728448   35.831897
# std      0.322436    0.245628   35.582619   60.577724   10.666330   12.125414
# min      0.137999    0.062038    0.000000    0.000000    2.000000    1.000000
# 25%      0.720568    0.744456   16.347501   12.967500   40.000000   30.000000
# 50%      1.012476    0.968663   25.092495   18.000000   40.000000   40.000000
# 75%      1.175370    1.065559   36.758401   27.415630   50.000000   40.000000
# max      1.491040    1.291550  365.000000  916.666687   80.000000   75.000000
#
#            rexpret      sexpret
# count   200.000000   257.000000
# mean   2019.150000  2019.669261
# std       5.325345     5.157249
# min    2010.000000  2010.000000
# 25%    2015.000000  2016.000000
# 50%    2019.000000  2019.000000
# 75%    2022.000000  2023.000000
# max    2040.000000  2034.000000
#
# [8 rows x 147 columns]

# %% [markdown]
# ### Model without Complementarity

# %%
nocomp = sp('nocomp')
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F

# %%
nocomp.chgoption('idiscount','T')
nocomp.chgoption('icomplement','F')
nocomp.chgoption('iload','T')
# Out:
# changed item  idiscount  with value F  to  T  ...
# changed item  icomplement  with value T  to  F  ...
# changed item  iload  with value F  to  T  ...

# %%
nocomp.estimate()

# %%
nocomp.loglike
# Out:
# -2855.7661494108265

# %%
nocomp.params
# Out:
#                                        par                       se
# alpha_c            6.7638002805994774E-002  2.1119370455988853E-002
# alpha_lm_cons          -1.2174670815841542      0.40086247218867405
# alpha_lm_age           0.45506145126023434  6.7793740203479308E-002
# alpha_lm_hlim           1.3604207755685727      0.52285285877964405
# alpha_lm_college   9.3952552366701220E-002      0.25670630636714070
# alpha_lm_male          0.54234320626184263      0.30400834207282335
# alpha_lm_job           0.12301121182609667      0.30478468458454661
# alpha_lf                0.0000000000000000       0.0000000000000000
# alpha_lm_lf             0.0000000000000000       0.0000000000000000
# beta_c             6.4125200403508387E-002  2.0745330484614643E-002
# beta_lf_cons          -0.43339302425859733      0.29742380339063207
# beta_lf_age            0.45714416178824457  8.0742117139835867E-002
# beta_lf_hlim            1.2413217631042999      0.44738187912542327
# beta_lf_college       -0.18991343959500481      0.21076145106636973
# beta_lf_male            1.1698191411952876      0.32328928729792600
# beta_lf_job           -0.15210392229598596      0.22638601282928014
# beta_lm                 0.0000000000000000       0.0000000000000000
# beta_lm_lf              0.0000000000000000       0.0000000000000000
# mu                -6.3418409975214141E-002      0.32039775096805034
# wageratio              0.53299347888764026      0.29005471378831388
# log_rho_m          4.4068118664407546E-002  1.1749367097791622E-002
# log_rho_f          2.9376595447701940E-002  1.2280729544760954E-002
# tau_m_0                -3.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# tau_f_0                -3.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_sig_m               0.0000000000000000       0.0000000000000000
# log_sig_f               0.0000000000000000       0.0000000000000000
# L_nm_nm                 2.4620609060720682      0.33742613271188404
# L_nf_nm                 1.7112850272128945      0.26203443587983760
# L_nf_nf                0.15828757858405232      0.33796631597968957
# scale_m                 1.0000000000000000       0.0000000000000000
# scale_f                 1.0000000000000000       0.0000000000000000
# scale_h                 1.0000000000000000       0.0000000000000000

# %%
nocomp.sim.describe()
# Out:
#            hhidpn  insim       jprob  rexpret_sim  sexpret_sim   leisure_m  \
# count  464.000000  464.0  464.000000   464.000000   464.000000  464.000000
# mean   303.915948    1.0    0.118534    65.788793    64.478448   -0.006189
# std    174.229335    0.0    0.323589     4.161767     2.939191    2.041947
# min      1.000000    1.0    0.000000    57.000000    56.000000   -4.148398
# 25%    155.750000    1.0    0.000000    62.000000    62.000000   -1.690428
# 50%    300.500000    1.0    0.000000    66.000000    65.000000   -0.080171
# 75%    454.250000    1.0    0.000000    69.000000    67.000000    1.686947
# max    604.000000    1.0    1.000000    80.000000    79.000000    5.435878
#
#         leisure_f   rage    rcollege      hwho_m  ...     rhlth62     shlth62  \
# count  464.000000  464.0  464.000000  464.000000  ...  464.000000  464.000000
# mean    -0.002615    0.0    0.441810    0.538793  ...    0.400431    0.395948
# std      1.427089    0.0    0.497139    0.499031  ...    0.277485    0.265845
# min     -2.878106    0.0    0.000000    0.000000  ...    0.000000    0.000000
# 25%     -1.162306    0.0    0.000000    0.000000  ...    0.200000    0.200000
# 50%     -0.075626    0.0    0.000000    1.000000  ...    0.400000    0.400000
# 75%      1.162124    0.0    1.000000    1.000000  ...    0.500000    0.500000
# max      3.830825    0.0    1.000000    1.000000  ...    1.000000    1.000000
#
#           rliv75r     sliv75r       rwage       swage      rhours      shours  \
# count  464.000000  464.000000  464.000000  464.000000  464.000000  464.000000
# mean     0.962090    0.912592   32.615540   25.620789   42.728448   35.831897
# std      0.322436    0.245628   35.582619   60.577724   10.666330   12.125414
# min      0.137999    0.062038    0.000000    0.000000    2.000000    1.000000
# 25%      0.720568    0.744456   16.347501   12.967500   40.000000   30.000000
# 50%      1.012476    0.968663   25.092495   18.000000   40.000000   40.000000
# 75%      1.175370    1.065559   36.758401   27.415630   50.000000   40.000000
# max      1.491040    1.291550  365.000000  916.666687   80.000000   75.000000
#
#            rexpret      sexpret
# count   200.000000   257.000000
# mean   2019.150000  2019.669261
# std       5.325345     5.157249
# min    2010.000000  2010.000000
# 25%    2015.000000  2016.000000
# 50%    2019.000000  2019.000000
# 75%    2022.000000  2023.000000
# max    2040.000000  2034.000000
#
# [8 rows x 147 columns]

# %% [markdown]
# ### Unitary Model

# %%
unitary = sp('unitary')
unitary.chgoption('iunitary','T')
unitary.chgoption('idiscount','T')
unitary.chgoption('iload','T')
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F
# changed item  iunitary  with value F  to  T  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  iload  with value F  to  T  ...

# %%
unitary.estimate()
unitary.loglike
# Out:
# -2821.128182196533

# %%
unitary.params
# Out:
#                                       par                       se
# alpha_c               0.15198923677495801  3.6540444575004612E-002
# alpha_lm_cons         -1.6341460288122596      0.47935202865630450
# alpha_lm_age          0.44015107403525833  6.5699263127553045E-002
# alpha_lm_hlim          1.6023588452737574      0.58005603329645461
# alpha_lm_college      0.18899711679769071      0.29522774818673292
# alpha_lm_male         0.17225343338722837      0.35320969325836649
# alpha_lm_job      3.1143869050884405E-002      0.35139713299422087
# alpha_lf               0.0000000000000000       0.0000000000000000
# alpha_lm_lf           0.13169450721020468  2.2229760722876985E-002
# beta_c                0.11652354249124902  3.7506365577949188E-002
# beta_lf_cons         -0.76175967432449421      0.35435594032326523
# beta_lf_age           0.47575573002041727  8.7292217883353063E-002
# beta_lf_hlim           1.4001578377111663      0.50245964092684614
# beta_lf_college      -0.18983799044306177      0.24039129983090296
# beta_lf_male          0.95488443180673099      0.35746558268107975
# beta_lf_job          -0.19987409537474071      0.25974974586863309
# beta_lm                0.0000000000000000       0.0000000000000000
# beta_lm_lf        8.3459063377195136E-002  2.2067342924922951E-002
# mu                5.4299890471227963E-002      0.31436401183666807
# wageratio              0.0000000000000000       0.0000000000000000
# log_rho_m         3.0486811726331844E-002  9.7783033807042705E-003
# log_rho_f         1.7538977357465218E-002  1.2422305844096683E-002
# tau_m_0               -3.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# log_tau_m              1.0000000000000000       0.0000000000000000
# tau_f_0               -3.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_tau_f              1.0000000000000000       0.0000000000000000
# log_sig_m              0.0000000000000000       0.0000000000000000
# log_sig_f              0.0000000000000000       0.0000000000000000
# L_nm_nm                2.8182520948896181      0.33261973774340292
# L_nf_nm                1.9344951985235488      0.29593380214262999
# L_nf_nf               0.19508435766777393      0.38805334818330972
# scale_m                1.0000000000000000       0.0000000000000000
# scale_f                1.0000000000000000       0.0000000000000000
# scale_h                1.0000000000000000       0.0000000000000000

# %%
unitary.sim.describe()
# Out:
#            hhidpn  insim       jprob  rexpret_sim  sexpret_sim   leisure_m  \
# count  464.000000  464.0  464.000000   464.000000   464.000000  464.000000
# mean   303.915948    1.0    0.127155    65.635776    63.903017   -0.000706
# std    174.229335    0.0    0.333506     4.632369     3.098329    2.336001
# min      1.000000    1.0    0.000000    55.000000    55.000000   -4.760199
# 25%    155.750000    1.0    0.000000    62.000000    62.000000   -1.965979
# 50%    300.500000    1.0    0.000000    65.000000    64.000000   -0.073441
# 75%    454.250000    1.0    0.000000    69.000000    66.000000    1.902360
# max    604.000000    1.0    1.000000    80.000000    78.000000    7.353701
#
#         leisure_f   rage    rcollege      hwho_m  ...     rhlth62     shlth62  \
# count  464.000000  464.0  464.000000  464.000000  ...  464.000000  464.000000
# mean     0.001405    0.0    0.441810    0.538793  ...    0.400431    0.395948
# std      1.613667    0.0    0.497139    0.499031  ...    0.277485    0.265845
# min     -3.293917    0.0    0.000000    0.000000  ...    0.000000    0.000000
# 25%     -1.348245    0.0    0.000000    0.000000  ...    0.200000    0.200000
# 50%     -0.055103    0.0    0.000000    1.000000  ...    0.400000    0.400000
# 75%      1.310822    0.0    1.000000    1.000000  ...    0.500000    0.500000
# max      5.092413    0.0    1.000000    1.000000  ...    1.000000    1.000000
#
#           rliv75r     sliv75r       rwage       swage      rhours      shours  \
# count  464.000000  464.000000  464.000000  464.000000  464.000000  464.000000
# mean     0.962090    0.912592   32.615540   25.620789   42.728448   35.831897
# std      0.322436    0.245628   35.582619   60.577724   10.666330   12.125414
# min      0.137999    0.062038    0.000000    0.000000    2.000000    1.000000
# 25%      0.720568    0.744456   16.347501   12.967500   40.000000   30.000000
# 50%      1.012476    0.968663   25.092495   18.000000   40.000000   40.000000
# 75%      1.175370    1.065559   36.758401   27.415630   50.000000   40.000000
# max      1.491040    1.291550  365.000000  916.666687   80.000000   75.000000
#
#            rexpret      sexpret
# count   200.000000   257.000000
# mean   2019.150000  2019.669261
# std       5.325345     5.157249
# min    2010.000000  2010.000000
# 25%    2015.000000  2016.000000
# 50%    2019.000000  2019.000000
# 75%    2022.000000  2023.000000
# max    2040.000000  2034.000000
#
# [8 rows x 147 columns]

# %% [markdown]
# ### Table with LR Tests

# %%
import pandas as pd
data = [disc.loglike,base.loglike,uncor.loglike,nocomp.loglike,unitary.loglike]
lr = [0]
for i in range(1,len(data)):
    lr.append(-2.0*(data[i]-data[0]))
names = ['Baseline','Fixed Discount Rates (2)','No Correlation UH (1)','No Complementarity (2)','Unitary (1)']
table = pd.DataFrame(data=list(zip(data,lr)),index=names,columns=['Loglikehood Value','LR Statistic'])
def f(x):
    return '{:1.3f}'.format(x)
with open('../tex/tables/lrtests.tex','w') as tf:
    tf.write(table.to_latex(formatters=[f,f]))
table
# Out:
#                           Loglikehood Value  LR Statistic
# Baseline                       -2818.344871      0.000000
# Fixed Discount Rates (2)       -2821.767612      6.845482
# No Correlation UH (1)          -2899.352683    162.015625
# No Complementarity (2)         -2855.766149     74.842557
# Unitary (1)                    -2821.128182      5.566622

# %% [markdown]
# Critical values at 5% for these tests:

# %%
from scipy.stats import chi2
[chi2(1).ppf(0.95),chi2(2).ppf(0.95)]
# Out:
# [3.841458820694124, 5.991464547107979]

# %% [markdown]
# ## Correlation with Expected Retirement in HRS

# %%
disc.sim['rexpret'] = disc.sim['rage_mod'] + (disc.sim['rexpret']-2011)
disc.sim['sexpret'] = disc.sim['sage_mod'] + (disc.sim['sexpret']-2011)

# %%
disc.sim[['rexpret','sexpret']].describe()
# Out:
#           rexpret     sexpret
# count  200.000000  257.000000
# mean    64.870000   64.459144
# std      4.203743    4.221328
# min     54.000000   54.000000
# 25%     62.000000   62.000000
# 50%     65.000000   64.000000
# 75%     68.000000   66.000000
# max     84.000000   80.000000

# %% [markdown]
# Correlations with simulated expected retirement age

# %%
print('Males   : ',disc.sim[['rexpret','rexpret_sim']].corr())
print('Females : ',disc.sim[['sexpret','sexpret_sim']].corr())
# Out:
# Males   :                rexpret  rexpret_sim
# rexpret      1.000000     0.208299
# rexpret_sim  0.208299     1.000000
# Females :                sexpret  sexpret_sim
# sexpret      1.000000     0.245102
# sexpret_sim  0.245102     1.000000

# %% [markdown]
# We will do a figure to check correlation

# %%
from scipy.stats import linregress
data = disc.sim[['rexpret_sim','rexpret']].dropna()
x = data['rexpret_sim']
y = data['rexpret']
slope, intercept, r_value, p_value, std_err = linregress(x,y)
line = slope*x+intercept
plt.figure()
plt.scatter(x,y,label='')
plt.plot(x, line, 'r', label='y={:.2f}x+{:.2f}: $R^2$={:.2f}'.format(slope,intercept,r_value))
plt.xlabel('expected retirement age (Model)')
plt.ylabel('expected retirement age (HRS)')
plt.legend(loc=4)
plt.savefig('../tex/figures/match_males.eps')
plt.show()

# %%
from scipy.stats import linregress
data = disc.sim[['sexpret_sim','sexpret']].dropna()
x = data['sexpret_sim']
y = data['sexpret']
slope, intercept, r_value, p_value, std_err = linregress(x,y)
line = slope*x+intercept
plt.figure()
plt.scatter(x,y,label='')
plt.plot(x, line, 'r', label='y={:.2f}x+{:.2f}: $R^2$={:.2f}'.format(slope,intercept,r_value))
plt.xlabel('expected retirement age (Model)')
plt.ylabel('expected retirement age (HRS)')
plt.legend(loc=4)
plt.savefig('../tex/figures/match_females.eps')
plt.show()

# %% [markdown]
# ## Distribution of Retirement Ages

# %%
# %matplotlib inline
from scipy.stats import gaussian_kde
from numba import jit
import numpy as np
x = disc.sim['rexpret_sim'].tolist()
y = disc.sim['sexpret_sim'].tolist()
print(disc.sim[['rexpret_sim','sexpret_sim']].describe())
print('correlation : ', disc.sim[['rexpret_sim','sexpret_sim']].corr())
X, Y = np.mgrid[60:69:10j, 60:69:10j]
positions = np.vstack([X.ravel(), Y.ravel()])
values = np.vstack([x, y])
kernel = gaussian_kde(values)
Z = np.reshape(kernel(positions).T, X.shape)
plt.figure()
plt.contour(X,Y,Z)
plt.xlabel('Expected Retirement Age Husband')
plt.ylabel('Expected Retirement Age Wife')
plt.savefig('../tex/figures/retages.eps')
# Out:
#        rexpret_sim  sexpret_sim
# count   464.000000   464.000000
# mean     65.728448    63.829741
# std       4.670523     3.130547
# min      55.000000    54.000000
# 25%      62.000000    62.000000
# 50%      65.000000    64.000000
# 75%      69.000000    66.000000
# max      80.000000    80.000000
# correlation :               rexpret_sim  sexpret_sim
# rexpret_sim     1.000000     0.741182
# sexpret_sim     0.741182     1.000000

# %%
disc.sim['distance_m'] = disc.sim['rexpret_sim'] - disc.sim['rage_mod']
disc.sim['distance_f'] = disc.sim['sexpret_sim'] - disc.sim['sage_mod']
print(disc.sim[['distance_m','distance_f']].describe())
print('correlation: ', disc.sim[['distance_m','distance_f']].corr())

# %matplotlib inline
from scipy.stats import gaussian_kde
from numba import jit
import numpy as np
x = disc.sim['distance_m'].tolist()
y = disc.sim['distance_f'].tolist()

X, Y = np.mgrid[0:20:20j, 0:20:20j]
positions = np.vstack([X.ravel(), Y.ravel()])
values = np.vstack([x, y])
kernel = gaussian_kde(values)
Z = np.reshape(kernel(positions).T, X.shape)
plt.figure()
plt.contour(X,Y,Z)
xx = np.linspace(0,20,20)
plt.fill_between(xx, xx-1, xx+1, color='grey', alpha='0.1')
plt.xlim([0,20])
plt.ylim([0,20])
plt.xlabel('Expected Distance (yrs) to Retirement Husband')
plt.ylabel('Expected Distance (yrs) to Retirement Wife')
plt.savefig('../tex/figures/distances.eps',dpi=600)
# Out:
#        distance_m  distance_f
# count  464.000000  464.000000
# mean     9.092672    8.168103
# std      5.640990    4.582549
# min      0.000000    0.000000
# 25%      5.000000    5.000000
# 50%      9.000000    8.000000
# 75%     13.000000   11.000000
# max     23.000000   23.000000
# correlation:              distance_m  distance_f
# distance_m    1.000000    0.766069
# distance_f    0.766069    1.000000

# %% [markdown]
# ## Joint Retirement

# %% [markdown]
# We will now re-rerun the discount model (baseline) with three scenarios: reshuffling heterogeneity, reshuffling wages and shutting down complementarity.

# %%
wages = sp('discount')
wages.chgoption('iload','T')
wages.chgoption('idiscount','T')
wages.chgoption('ishufwages','T')
wages.estimate()
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F
# changed item  iload  with value F  to  T  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  ishufwages  with value F  to  T  ...

# %%
heter = sp('discount')
heter.chgoption('iload','T')
heter.chgoption('idiscount','T')
heter.chgoption('ishufheter','T')
heter.estimate()
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F
# changed item  iload  with value F  to  T  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  ishufheter  with value F  to  T  ...

# %%
comp = sp('discount')
comp.chgoption('iload','T')
comp.chgoption('idiscount','T')
comp.chgoption('iblockcomp','T')
comp.estimate()
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F
# changed item  iload  with value F  to  T  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  iblockcomp  with value F  to  T  ...

# %%
specs = [disc,wages,heter,comp]
names =  ['Baseline','Shuffling Wages','Shuffling UH','No Complementarity']
data = []
plt.figure()
for i,s in enumerate(specs):
    s.sim['distance_m'] = s.sim['rexpret_sim'] - s.sim['rage_mod']
    s.sim['distance_f'] = s.sim['sexpret_sim'] - s.sim['sage_mod']
    s.sim['joint'] = np.abs(s.sim['distance_m'] - s.sim['distance_f'])<=1.0
    s.sim['joint_yrs'] = s.sim['distance_m'] - s.sim['distance_f']
    x = s.sim['joint_yrs'].values
    x.sort()
    ff = gaussian_kde(x)
    plt.plot(x,ff(x),label=names[i])
    data.append([s.sim['rexpret_sim'].mean(),s.sim['sexpret_sim'].mean(),s.sim['joint'].mean()])
table = pd.DataFrame(data=data,index=names,columns=['Ret Age Males','Ret Age Females','Fraction Joint'])  
def f(x):
    return '{:1.3f}'.format(x)
with open('../tex/tables/joint.tex','w') as tf:
    tf.write(table.to_latex(formatters=[f,f,f]))
plt.legend(loc=2)
plt.xlabel('difference in distance to retirement')
plt.ylabel('density')
plt.xlim([-15,15])
plt.savefig('../tex/figures/compare_distances.eps')
plt.show()
table
# Out:
#                     Ret Age Males  Ret Age Females  Fraction Joint
# Baseline                65.728448        63.829741        0.336207
# Shuffling Wages         65.629310        63.803879        0.368534
# Shuffling UH            65.765086        63.892241        0.176724
# No Complementarity      66.142241        64.471983        0.303879

# %%
# %matplotlib inline
from scipy.stats import gaussian_kde
from numba import jit
import numpy as np
x = comp.sim['distance_m'].tolist()
y = comp.sim['distance_f'].tolist()

X, Y = np.mgrid[0:20:20j, 0:20:20j]
positions = np.vstack([X.ravel(), Y.ravel()])
values = np.vstack([x, y])
kernel = gaussian_kde(values)
Z = np.reshape(kernel(positions).T, X.shape)
plt.figure()
plt.contour(X,Y,Z)
xx = np.linspace(0,20,20)
plt.fill_between(xx, xx-1, xx+1, color='grey', alpha='0.1')
plt.xlim([0,20])
plt.ylim([0,20])
plt.xlabel('Expected Distance (yrs) to Retirement Husband')
plt.ylabel('Expected Distance (yrs) to Retirement Wife')
plt.savefig('../tex/figures/distances_nocomp.eps',dpi=600)

# %%
disc.sim['agediff'] = disc.sim['rage_mod']- disc.sim['sage_mod']
print(comp.sim[['distance_m','distance_f']].describe())
print(disc.sim[['distance_m','distance_f']].describe())
# Out:
#        distance_m  distance_f
# count  464.000000  464.000000
# mean     9.506466    8.810345
# std      5.702483    4.646769
# min      0.000000    0.000000
# 25%      5.000000    5.000000
# 50%     10.000000    9.000000
# 75%     13.000000   12.000000
# max     23.000000   23.000000
#        distance_m  distance_f
# count  464.000000  464.000000
# mean     9.092672    8.168103
# std      5.640990    4.582549
# min      0.000000    0.000000
# 25%      5.000000    5.000000
# 50%      9.000000    8.000000
# 75%     13.000000   11.000000
# max     23.000000   23.000000

# %% [markdown]
# # Policy Simulation

# %% [markdown]
# Finally, we have to check what happens when we do policy simulations. We will do policy simulations over two parameters, the ARF (actuarial reduction factor) and the generosity of the pension (replacement rate).

# %%
arf = [0,0.09]
drc = [0,0.11]
rep = [0.4,0.8]
factors = zip(arf,drc)
experiments = [disc]
for a,d in factors:
    this = sp('discount')
    this.chgoption('iload','T')
    this.chgoption('idiscount','T')
    this.chgoption('arf',a)
    this.chgoption('drc',d)
    this.estimate()
    this.sim['distance_m'] = this.sim['rexpret_sim'] - this.sim['rage_mod']
    this.sim['distance_f'] = this.sim['sexpret_sim'] - this.sim['sage_mod']
    this.sim['joint'] = np.abs(this.sim['distance_m'] - this.sim['distance_f'])<=1.0    
    experiments.append(this)
for r in rep:
    this = sp('discount')
    this.chgoption('iload','T')
    this.chgoption('idiscount','T')
    this.chgoption('reprate',r)
    this.estimate()
    this.sim['distance_m'] = this.sim['rexpret_sim'] - this.sim['rage_mod']
    this.sim['distance_f'] = this.sim['sexpret_sim'] - this.sim['sage_mod']
    this.sim['joint'] = np.abs(this.sim['distance_m'] - this.sim['distance_f'])<=1.0    
    experiments.append(this)
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F
# changed item  iload  with value F  to  T  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  arf  with value 0.06  to  0  ...
# changed item  drc  with value 0.08  to  0  ...
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F
# changed item  iload  with value F  to  T  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  arf  with value 0.06  to  0.09  ...
# changed item  drc  with value 0.08  to  0.11  ...
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F
# changed item  iload  with value F  to  T  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  reprate  with value 0.6  to  0.4  ...
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F
# changed item  iload  with value F  to  T  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  reprate  with value 0.6  to  0.8  ...

# %%
data = [[e.sim['rexpret_sim'].mean(),e.sim['sexpret_sim'].mean(),e.sim['joint'].mean()] for e in experiments]
names = ['Baseline','No Penalty','High Penalty','Low Generosity','High Generosity']
table = pd.DataFrame(data=data,columns=['Ret Age Males','Ret Age Females','Fraction Retiring Jointly'],index=names)
print(table)
def f(x):
    return '{:1.3f}'.format(x)
with open('../tex/tables/policy.tex','w') as tf:
    tf.write(table.to_latex(formatters=[f,f,f]))
# Out:
#                  Ret Age Males  Ret Age Females  Fraction Retiring Jointly
# Baseline             65.728448        63.829741                   0.336207
# No Penalty           63.758621        62.243534                   0.435345
# High Penalty         66.478448        64.398707                   0.275862
# Low Generosity       66.155172        64.094828                   0.267241
# High Generosity      65.452586        63.603448                   0.362069

# %% [markdown]
# ## Testing fixed correlation coefficients

# %%
listofrho = np.linspace(0,1.1,12)
listofrho[listofrho==1.] = 0.995
listofrho[listofrho==1.1] = 0.9999


#listofrho = [0,0.1,0.25,0.5,0.75,0.9]

# %%
# %matplotlib inline
from scipy.stats import gaussian_kde
from numba import jit
import numpy as np
import copy as cp

fixed = sp('fixcorr')
fixed.chgoption('idiscount','T')
fixed.chgoption('iload','T')
fixed.chgoption('ifixcorr','T')
fixed.chgoption('icomplement','F')

lsloglik = []
#lsparams = []

dctresults = {}

for rho in listofrho:    
    print(rho)
    fixed.chgoption('dfixrho',rho)
    fixed.estimate()
    dctresults[rho] = cp.copy(fixed)
    lsloglik.append(fixed.loglike)
    #lsparams.append(fixed.params)
    
    #Graph of the joint distance
    fixed.sim['distance_m'] = fixed.sim['rexpret_sim'] - fixed.sim['rage_mod']
    fixed.sim['distance_f'] = fixed.sim['sexpret_sim'] - fixed.sim['sage_mod']
    fixed.sim['joint'] = np.abs(fixed.sim['distance_m'] - fixed.sim['distance_f'])<=1.0  
    x = fixed.sim['distance_m'].tolist()
    y = fixed.sim['distance_f'].tolist()

    X, Y = np.mgrid[0:20:20j, 0:20:20j]
    positions = np.vstack([X.ravel(), Y.ravel()])
    values = np.vstack([x, y])
    kernel = gaussian_kde(values)
    Z = np.reshape(kernel(positions).T, X.shape)
    plt.figure()
    plt.contour(X,Y,Z)
    xx = np.linspace(0,20,20)
    plt.fill_between(xx, xx-1, xx+1, color='grey', alpha='0.1')
    plt.xlim([0,20])
    plt.ylim([0,20])
    plt.xlabel('Expected Distance (yrs) to Retirement Husband')
    plt.ylabel('Expected Distance (yrs) to Retirement Wife')
    plt.savefig('../tex/figures/distances_nocomp%d.eps' %rho,dpi=600)
    plt.show()
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F
# changed item  idiscount  with value F  to  T  ...
# changed item  iload  with value F  to  T  ...
# changed item  ifixcorr  with value F  to  T  ...
# changed item  icomplement  with value T  to  F  ...
# 0.0
# changed item  dfixrho  with value 0.5  to  0.0  ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-29398b69d6b7> in <module>
#      44     plt.xlabel('Expected Distance (yrs) to Retirement Husband')
#      45     plt.ylabel('Expected Distance (yrs) to Retirement Wife')
# ---> 46     plt.savefig('../tex/figures/distances_nocomp%d.eps' %irho,dpi=600)
#      47     plt.show()
#      48
#
# NameError: name 'irho' is not defined

# %%
listofdens = []
listofx    = []

data = []
plt.figure()

for key in dctresults:
    this = dctresults[key]
    #print(this.sim.describe())
    this.sim['distance_m'] = this.sim['rexpret_sim'] - this.sim['rage_mod']
    this.sim['distance_f'] = this.sim['sexpret_sim'] - this.sim['sage_mod']
    this.sim['joint'] = np.abs(this.sim['distance_m'] - this.sim['distance_f'])<=1.0
    this.sim['joint_yrs'] = this.sim['distance_m'] - this.sim['distance_f']
    x = this.sim['joint_yrs'].values
    x.sort()
    ff = gaussian_kde(x)
    listofx.append(x)
    listofdens.append(ff(x))
    plt.plot(x,ff(x)) #,label=key)
        #data.append([this.sim['rexpret_sim'].mean(),this.sim['sexpret_sim'].mean(),this.sim['joint'].mean()])
        #table = pd.DataFrame(data=data,index=names,columns=['Ret Age Males','Ret Age Females','Fraction Joint'])  
        #def f(x):
        #    return '{:1.3f}'.format(x)
        #with open('../tex/tables/joint.tex','w') as tf:
        #    tf.write(table.to_latex(formatters=[f,f,f]))

# plt.plot(listofx,listofdens, label=dctresults.keys())

plt.legend(loc=2, labels=dctresults.keys())
plt.xlabel('difference in distance to retirement')
plt.ylabel('density')
plt.xlim([-15,15])
plt.savefig('../tex/figures/compare_distances_multiples_rho.eps')
#plt.show()
#table

plt.show()

# %%
listofjoin = []
listofval = []
for key in dctresults:
    this = dctresults[key]
    listofjoin.append(this.sim['joint'].mean())
    listofval.append(key)
    
plt.plot(listofval, listofjoin)

# %% [markdown]
# ### No complementarity, moving correlation.

# %%
comp = sp('discount')
comp.chgoption('iload','T')
comp.chgoption('idiscount','T')
#comp.chgoption('icomplement','F')
comp.chgoption('iblockcomp','T')
comp.estimate()
comp.sim.describe()
# Out:
# Default options:
# isurvival  =  T
# iload  =  F
# iestimate  =  T
# data  =  hrs_final_ref.csv
# info  =  info_ref.dat
# includeratings  =  F
# icomplement  =  T
# ihetero  =  T
# icorr  =  T
# iunitary  =  F
# idiscount  =  F
# ddiscount  =  0.95
# idirect  =  F
# arf  =  0.06
# drc  =  0.08
# reprate  =  0.6
# ishufheter  =  F
# ishufwages  =  F
# iblockcomp  =  F
# ifixcorr  =  F
# dfixrho  =  0.5
# inoestim  =  F
# changed item  iload  with value F  to  T  ...
# changed item  idiscount  with value F  to  T  ...
# changed item  iblockcomp  with value F  to  T  ...
#            hhidpn  insim       jprob  rexpret_sim  sexpret_sim   leisure_m  \
# count  464.000000  464.0  464.000000   464.000000   464.000000  464.000000
# mean   303.915948    1.0    0.101293    66.140086    64.471983    0.002072
# std    174.229335    0.0    0.302042     4.781149     3.279505    2.322654
# min      1.000000    1.0    0.000000    55.000000    53.000000   -4.753696
# 25%    155.750000    1.0    0.000000    62.000000    62.000000   -1.980787
# 50%    300.500000    1.0    0.000000    67.000000    64.000000   -0.072966
# 75%    454.250000    1.0    0.000000    70.000000    67.000000    1.903876
# max    604.000000    1.0    1.000000    80.000000    80.000000    7.256402
#
#         leisure_f   rage    rcollege      hwho_m  ...     rhlth62     shlth62  \
# count  464.000000  464.0  464.000000  464.000000  ...  464.000000  464.000000
# mean     0.003354    0.0    0.441810    0.538793  ...    0.400431    0.395948
# std      1.603372    0.0    0.497139    0.499031  ...    0.277485    0.265845
# min     -3.285985    0.0    0.000000    0.000000  ...    0.000000    0.000000
# 25%     -1.329383    0.0    0.000000    0.000000  ...    0.200000    0.200000
# 50%     -0.037437    0.0    0.000000    1.000000  ...    0.400000    0.400000
# 75%      1.306029    0.0    1.000000    1.000000  ...    0.500000    0.500000
# max      5.021882    0.0    1.000000    1.000000  ...    1.000000    1.000000
#
#           rliv75r     sliv75r       rwage       swage      rhours      shours  \
# count  464.000000  464.000000  464.000000  464.000000  464.000000  464.000000
# mean     0.962090    0.912592   32.615540   25.620789   42.728448   35.831897
# std      0.322436    0.245628   35.582619   60.577724   10.666330   12.125414
# min      0.137999    0.062038    0.000000    0.000000    2.000000    1.000000
# 25%      0.720568    0.744456   16.347501   12.967500   40.000000   30.000000
# 50%      1.012476    0.968663   25.092495   18.000000   40.000000   40.000000
# 75%      1.175370    1.065559   36.758401   27.415630   50.000000   40.000000
# max      1.491040    1.291550  365.000000  916.666687   80.000000   75.000000
#
#            rexpret      sexpret
# count   200.000000   257.000000
# mean   2019.150000  2019.669261
# std       5.325345     5.157249
# min    2010.000000  2010.000000
# 25%    2015.000000  2016.000000
# 50%    2019.000000  2019.000000
# 75%    2022.000000  2023.000000
# max    2040.000000  2034.000000
#
# [8 rows x 147 columns]

# %%
### Creating a fake scenario and escaping estimation ####
drho = 0.5

lsloglik = []
#lsparams = []

dct_new_results = {}

nocomp_varrho = cp.copy(comp)
nocomp_varrho.scenario = "nocomp_varrho"
nocomp_varrho.chgoption('inoestim','T')

for drho in listofrho:

    ## Computing the var cov matrix
    M11 = pd.to_numeric(nocomp_varrho.params['par'].loc['L_nm_nm'])
    M12 = pd.to_numeric(nocomp_varrho.params['par'].loc['L_nf_nm'])
    M22 = pd.to_numeric(nocomp_varrho.params['par'].loc['L_nf_nf'])

    M = np.array([[M11, 0],[M12,  M22]])
    varcov = np.matmul(M,M.T)

    # Maintaining var cst, changing only the correlation. 
    newvarcov = varcov
    newvarcov[0,1] = drho * (np.sqrt(varcov[0,0])*np.sqrt(varcov[1,1]))
    newvarcov[1,0] = newvarcov[0,1]

    # Writing in the table.
    newchol = np.linalg.cholesky(newvarcov)
    
    print(newchol)

    nocomp_varrho.params['par'].loc['L_nf_nm'] = newchol[1,0] 
    nocomp_varrho.params['par'].loc['L_nf_nf'] = newchol[1,1] 

    ## Dumping the table first
    nocomp_varrho.params.to_csv('../params/temp.csv', header = False, sep = '\t')
    
    # Putting the content back in memory
    f = open('../params/'+ 'temp' +'.csv')
    buff = f.read()
    f.close()
    buff = buff.split('\n')

    # Adding the two lines
    f = open('../params/parms_%s.csv'%nocomp_varrho.scenario, "w+")
    f.write(str(comp.loglike)+"\n")
    f.write('48')

    ##Rewriting the parameters
    for line in buff:
        f.write("\n" + line)

    f.close()
    nocomp_varrho.estimate()
    nocomp_varrho.sim['distance_m'] = nocomp_varrho.sim['rexpret_sim'] - nocomp_varrho.sim['rage_mod']
    nocomp_varrho.sim['distance_f'] = nocomp_varrho.sim['sexpret_sim'] - nocomp_varrho.sim['sage_mod']
    nocomp_varrho.sim['joint'] = np.abs(nocomp_varrho.sim['distance_m'] - nocomp_varrho.sim['distance_f'])<=1.0
    nocomp_varrho.sim['joint_yrs'] = nocomp_varrho.sim['distance_m'] - nocomp_varrho.sim['distance_f']
    dct_new_results[drho] = cp.copy(nocomp_varrho)
# Out:
# changed item  inoestim  with value F  to  T  ...
# [[2.800037   0.        ]
#  [0.         1.93006329]]
# [[2.800037   0.        ]
#  [0.19300633 1.92038873]]
# [[2.800037   0.        ]
#  [0.38601266 1.8910681 ]]
# [[2.800037   0.        ]
#  [0.57901899 1.84116304]]
# [[2.800037   0.        ]
#  [0.77202532 1.76893223]]
# [[2.800037   0.        ]
#  [0.96503165 1.67148384]]
# [[2.800037   0.        ]
#  [1.15803798 1.54405064]]
# [[2.800037   0.        ]
#  [1.35104431 1.37834089]]
# [[2.800037   0.        ]
#  [1.54405064 1.15803798]]
# [[2.800037   0.        ]
#  [1.73705697 0.84129509]]
# [[2.800037   0.        ]
#  [1.92041298 0.19276492]]
# [[2.800037   0.        ]
#  [1.92987029 0.02729453]]

# %%
listofjoin = []
listofval = []
for key in dct_new_results:
    this = dct_new_results[key]
    listofjoin.append(this.sim['joint'].mean())
    listofval.append(key)
    
plt.plot(listofval, listofjoin)

# %%
comp.params
# Out:
#                                        par                       se
# alpha_c            6.7792543395369831E-002  2.1155736125217182E-002
# alpha_lm_cons          -1.2165479603849927      0.40091755470208967
# alpha_lm_age           0.45440876714215322  6.7746227774603082E-002
# alpha_lm_hlim           1.3607305194707042      0.52293982586785892
# alpha_lm_college   9.3998133120504715E-002      0.25676217291247527
# alpha_lm_male          0.54368667753571087      0.30412127063069155
# alpha_lm_job           0.12338780360697356      0.30486270056212789
# alpha_lf                0.0000000000000000       0.0000000000000000
# alpha_lm_lf             0.0000000000000000       0.0000000000000000
# beta_c             6.4179794950777691E-002  2.0750483413618265E-002
# beta_lf_cons          -0.43306284555724711      0.29735065107911240
# beta_lf_age            0.45677890011933148  8.0673635308120051E-002
# beta_lf_hlim            1.2415775569995793      0.44726287294569572
# beta_lf_college       -0.18977609556497138      0.21070782049108419
# beta_lf_male            1.1701046002860731      0.32320487428792599
# beta_lf_job           -0.15205366883110577      0.22633104765543746
# beta_lm                 0.0000000000000000       0.0000000000000000
# beta_lm_lf              0.0000000000000000       0.0000000000000000
# mu                -6.4824974010405434E-002      0.32036437865377260
# wageratio              0.53298537822463166      0.29001337845156117
# log_rho_m          4.4036863145323818E-002  1.1746701806999264E-002
# log_rho_f          2.9391731780985621E-002  1.2272936525851961E-002
# tau_m_0                -3.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# log_tau_m               1.0000000000000000       0.0000000000000000
# tau_f_0                -3.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_tau_f               1.0000000000000000       0.0000000000000000
# log_sig_m               0.0000000000000000       0.0000000000000000
# log_sig_f               0.0000000000000000       0.0000000000000000
# L_nm_nm                 2.4622953346222531      0.33745064315618728
# L_nf_nm                                  0      0.26183867369129016
# L_nf_nf                            1.71805      0.33782407653292579
# scale_m                 1.0000000000000000       0.0000000000000000
# scale_f                 1.0000000000000000       0.0000000000000000
# scale_h                 1.0000000000000000       0.0000000000000000

# %%
dct_new_results[0.995].sim['joint_num'] = dct_new_results[0.995].sim['joint']*1.0
dct_new_results[0.995].sim[['joint_yrs', 'joint_num']].groupby('joint_yrs').sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-268-0ce69ebcb63a> in <module>
#       1 dct_new_results[0.995].sim['joint_num'] = dct_new_results[0.995].sim['joint']*1.0
# ----> 2 dct_new_results[0.0].sim[['joint_yrs', 'joint_num']].groupby('joint_yrs').sum()
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# -> 1354                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1355         else:
#    1356             try:
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1159         self._validate_read_indexer(keyarr, indexer,
#    1160                                     o._get_axis_number(axis),
# -> 1161                                     raise_missing=raise_missing)
#    1162         return keyarr, indexer
#    1163
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1250             if not(self.name == 'loc' and not raise_missing):
#    1251                 not_found = list(set(key) - set(ax))
# -> 1252                 raise KeyError("{} not in index".format(not_found))
#    1253
#    1254             # we skip the warning on Categorical/Interval
#
# KeyError: "['joint_num'] not in index"

# %%
try:
    del dfbyage
except:
    pass

for key in dct_new_results:
    dct_new_results[key].sim['diffage'] = np.abs(dct_new_results[key].sim['rage_mod'] 
                                               - dct_new_results[key].sim['sage_mod'])
    thisdict = dct_new_results[key].sim[['diffage', 'joint']].groupby('diffage').mean()
    thisdict['rho'] = key
    
    try:
        dfbyage = dfbyage.append(thisdict)
    except:
        dfbyage = thisdict.copy()

# %%
dfbyage.pivot(columns='rho').plot()
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
dfbyage.pivot(columns='rho')
# Out:
#             joint                                                              \
# rho        0.0000    0.1000    0.2000    0.3000    0.4000    0.5000    0.6000
# diffage
# 0        0.315789  0.302632  0.289474  0.302632  0.328947  0.328947  0.342105
# 1        0.361538  0.346154  0.338462  0.353846  0.323077  0.346154  0.353846
# 2        0.200000  0.200000  0.188235  0.176471  0.200000  0.211765  0.223529
# 3        0.234568  0.246914  0.246914  0.271605  0.283951  0.259259  0.246914
# 4        0.133333  0.155556  0.200000  0.177778  0.222222  0.222222  0.222222
# 5        0.127660  0.127660  0.170213  0.212766  0.212766  0.170213  0.170213
#
#
# rho        0.7000    0.8000    0.9000    0.9950    0.9999
# diffage
# 0        0.342105  0.355263  0.315789  0.276316  0.276316
# 1        0.361538  0.376923  0.369231  0.361538  0.361538
# 2        0.223529  0.176471  0.247059  0.282353  0.305882
# 3        0.271605  0.246914  0.308642  0.296296  0.296296
# 4        0.333333  0.288889  0.288889  0.311111  0.311111
# 5        0.148936  0.191489  0.255319  0.234043  0.234043
